# %%
# Global imports
import hatchet as ht
import pandas as pd
import os

# %%
# Local imports
from CallFlow.single import SingleCallFlow
from CallFlow.pipeline import ConfigFileReader

# %%
pd.options.display.max_rows = 10
pd.options.display.float_format = '{:,.2f}'.format

# %%
path = os.getcwd().split('CallFlow')[0] + 'CallFlow'

# %%
experiment = 'lulesh-8-runs'
dataset = '1-core'
configFileName = 'Lulesh-Scaling-8-runs.json'

# %%
configPath = path + '/config_files' + '/' + configFileName
dataPath = path + '/' + experiment
dotPath = path + '/data/processed'
experimentPath = dataPath + '/' + experiment
experimentDotPath = dotPath + '/' + experiment

# %%
config = ConfigFileReader(configPath)

# %%
callflow = SingleCallFlow(config=config, process=True)
# Out:
#  #  #########################################
#  #  Run: 1-core
#  #  #########################################
#  #  Creating graphframes: 1-core
#  #  Data path: /home/suraj/Work/llnl/CallFlow/data/lulesh-8-runs/1-core.json
#  #  Number of call sites in CCT (From dataframe): 29
#  #  Create GraphFrame: 0.0374281401745975
#  #  -----------------------------------------
#  #  Preprocessing : add_time_columns
#  #  Preprocessing : add_rank_column
#  #  Preprocessing : add_callers_and_callees
#  #  Preprocessing : add_dataset_name
#  #  Preprocessing : add_imbalance_perc
# /home/suraj/miniconda3/lib/python3.7/site-packages/numpy/core/_methods.py:217: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /home/suraj/miniconda3/lib/python3.7/site-packages/numpy/core/_methods.py:209: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  #  Preprocessing : add_module_name_caliper
#  #  Preprocessing : create_name_module_map
#  #  Preprocessing : add_vis_node_name
#  #  Preprocessing : add_path
#  #  [Validation] Map contains: 29 callsites, graph contains: 29 callsites
#  #  Module: ['Lulesh' 'MPI' 'LeapFrog' 'CalcConstraint' 'CalcLagrange' 'CalcForce'
#  #   'Timer']
#  #  Preprocess GraphFrame: 0.07654628297314048
#  #  -----------------------------------------
#  #  Convert to NetworkX graph: 0.0013675738591700792
#  #  -----------------------------------------
#  #  Group GraphFrame: 0.006262801121920347
#  #  -----------------------------------------
#  #  Write GraphFrame: 0.004338786005973816
#  #  -----------------------------------------
#  #  Module: ['Lulesh' 'MPI' 'LeapFrog' 'CalcConstraint' 'CalcLagrange' 'CalcForce'
#  #   'Timer']
#  #  #########################################
#  #  Run: 8-cores
#  #  #########################################
#  #  Creating graphframes: 8-cores
#  #  Data path: /home/suraj/Work/llnl/CallFlow/data/lulesh-8-runs/8-cores.json
#  #  Number of call sites in CCT (From dataframe): 33
#  #  Create GraphFrame: 0.05671815504319966
#  #  -----------------------------------------
#  #  Preprocessing : add_time_columns
#  #  Preprocessing : add_rank_column
#  #  Preprocessing : add_callers_and_callees
#  #  Preprocessing : add_dataset_name
#  #  Preprocessing : add_imbalance_perc
#  #  Preprocessing : add_module_name_caliper
#  #  Preprocessing : create_name_module_map
#  #  Preprocessing : add_vis_node_name
#  #  Preprocessing : add_path
#  #  [Validation] Map contains: 33 callsites, graph contains: 33 callsites
#  #  Module: ['Lulesh' 'MPI' 'LeapFrog' 'CalcConstraint' 'CalcLagrange' 'CalcForce'
#  #   'Timer']
#  #  Preprocess GraphFrame: 0.09139522514306009
#  #  -----------------------------------------
#  #  Convert to NetworkX graph: 0.0017522838898003101
#  #  -----------------------------------------
#  #  Group GraphFrame: 0.008378359954804182
#  #  -----------------------------------------
#  #  Write GraphFrame: 0.013584400992840528
#  #  -----------------------------------------
#  #  Module: ['Lulesh' 'MPI' 'LeapFrog' 'CalcConstraint' 'CalcLagrange' 'CalcForce'
#  #   'Timer']
#  #  #########################################
#  #  Run: 27-cores
#  #  #########################################
#  #  Creating graphframes: 27-cores
#  #  Data path: /home/suraj/Work/llnl/CallFlow/data/lulesh-8-runs/27-cores.json
#  #  Number of call sites in CCT (From dataframe): 33
#  #  Create GraphFrame: 0.06601436017081141
#  #  -----------------------------------------
#  #  Preprocessing : add_time_columns
#  #  Preprocessing : add_rank_column
#  #  Preprocessing : add_callers_and_callees
#  #  Preprocessing : add_dataset_name
#  #  Preprocessing : add_imbalance_perc
#  #  Preprocessing : add_module_name_caliper
#  #  Preprocessing : create_name_module_map
#  #  Preprocessing : add_vis_node_name
#  #  Preprocessing : add_path
#  #  [Validation] Map contains: 33 callsites, graph contains: 33 callsites
#  #  Module: ['Lulesh' 'MPI' 'LeapFrog' 'CalcConstraint' 'CalcLagrange' 'CalcForce'
#  #   'Timer']
#  #  Preprocess GraphFrame: 0.0993774349335581
#  #  -----------------------------------------
#  #  Convert to NetworkX graph: 0.0017719080206006765
#  #  -----------------------------------------
#  #  Group GraphFrame: 0.01003368804231286
#  #  -----------------------------------------
#  #  Write GraphFrame: 0.031180368969216943
#  #  -----------------------------------------
#  #  Module: ['Lulesh' 'MPI' 'LeapFrog' 'CalcConstraint' 'CalcLagrange' 'CalcForce'
#  #   'Timer']
#  #  #########################################
#  #  Run: 64-cores
#  #  #########################################
#  #  Creating graphframes: 64-cores
#  #  Data path: /home/suraj/Work/llnl/CallFlow/data/lulesh-8-runs/64-cores.json
#  #  Number of call sites in CCT (From dataframe): 33
#  #  Create GraphFrame: 0.08072652504779398
#  #  -----------------------------------------
#  #  Preprocessing : add_time_columns
#  #  Preprocessing : add_rank_column
#  #  Preprocessing : add_callers_and_callees
#  #  Preprocessing : add_dataset_name
#  #  Preprocessing : add_imbalance_perc
#  #  Preprocessing : add_module_name_caliper
#  #  Preprocessing : create_name_module_map
#  #  Preprocessing : add_vis_node_name
#  #  Preprocessing : add_path
#  #  [Validation] Map contains: 33 callsites, graph contains: 33 callsites
#  #  Module: ['Lulesh' 'MPI' 'LeapFrog' 'CalcConstraint' 'CalcLagrange' 'CalcForce'
#  #   'Timer']
#  #  Preprocess GraphFrame: 0.13336023804731667
#  #  -----------------------------------------
#  #  Convert to NetworkX graph: 0.0022696098312735558
#  #  -----------------------------------------
#  #  Group GraphFrame: 0.026316941948607564
#  #  -----------------------------------------
#  #  Write GraphFrame: 0.11190455709584057
#  #  -----------------------------------------
#  #  Module: ['Lulesh' 'MPI' 'LeapFrog' 'CalcConstraint' 'CalcLagrange' 'CalcForce'
#  #   'Timer']
#  #  #########################################
#  #  Run: 125-cores
#  #  #########################################
#  #  Creating graphframes: 125-cores
#  #  Data path: /home/suraj/Work/llnl/CallFlow/data/lulesh-8-runs/125-cores.json
#  #  Number of call sites in CCT (From dataframe): 33
#  #  Create GraphFrame: 0.11013875110074878
#  #  -----------------------------------------
#  #  Preprocessing : add_time_columns
#  #  Preprocessing : add_rank_column
#  #  Preprocessing : add_callers_and_callees
#  #  Preprocessing : add_dataset_name
#  #  Preprocessing : add_imbalance_perc
#  #  Preprocessing : add_module_name_caliper
#  #  Preprocessing : create_name_module_map
#  #  Preprocessing : add_vis_node_name
#  #  Preprocessing : add_path
#  #  [Validation] Map contains: 33 callsites, graph contains: 33 callsites
#  #  Module: ['Lulesh' 'MPI' 'LeapFrog' 'CalcConstraint' 'CalcLagrange' 'CalcForce'
#  #   'Timer']
#  #  Preprocess GraphFrame: 0.1295118648558855
#  #  -----------------------------------------
#  #  Convert to NetworkX graph: 0.0012816230300813913
#  #  -----------------------------------------
#  #  Group GraphFrame: 0.02049441309645772
#  #  -----------------------------------------
#  #  Write GraphFrame: 0.1121210278943181
#  #  -----------------------------------------
#  #  Module: ['Lulesh' 'MPI' 'LeapFrog' 'CalcConstraint' 'CalcLagrange' 'CalcForce'
#  #   'Timer']
#  #  #########################################
#  #  Run: 216-cores
#  #  #########################################
#  #  Creating graphframes: 216-cores
#  #  Data path: /home/suraj/Work/llnl/CallFlow/data/lulesh-8-runs/216-cores.json
#  #  Number of call sites in CCT (From dataframe): 33
#  #  Create GraphFrame: 0.08819058910012245
#  #  -----------------------------------------
#  #  Preprocessing : add_time_columns
#  #  Preprocessing : add_rank_column
#  #  Preprocessing : add_callers_and_callees
#  #  Preprocessing : add_dataset_name
#  #  Preprocessing : add_imbalance_perc
#  #  Preprocessing : add_module_name_caliper
#  #  Preprocessing : create_name_module_map
#  #  Preprocessing : add_vis_node_name
#  #  Preprocessing : add_path
#  #  [Validation] Map contains: 33 callsites, graph contains: 33 callsites
#  #  Module: ['Lulesh' 'MPI' 'LeapFrog' 'CalcConstraint' 'CalcLagrange' 'CalcForce'
#  #   'Timer']
#  #  Preprocess GraphFrame: 0.14370221784338355
#  #  -----------------------------------------
#  #  Convert to NetworkX graph: 0.0015457700937986374
#  #  -----------------------------------------
#  #  Group GraphFrame: 0.029429901856929064
#  #  -----------------------------------------
#  #  Write GraphFrame: 0.1934038212057203
#  #  -----------------------------------------
#  #  Module: ['Lulesh' 'MPI' 'LeapFrog' 'CalcConstraint' 'CalcLagrange' 'CalcForce'
#  #   'Timer']
#  #  #########################################
#  #  Run: 343-cores
#  #  #########################################
#  #  Creating graphframes: 343-cores
#  #  Data path: /home/suraj/Work/llnl/CallFlow/data/lulesh-8-runs/343-cores.json
#  #  Number of call sites in CCT (From dataframe): 33
#  #  Create GraphFrame: 0.11381157790310681
#  #  -----------------------------------------
#  #  Preprocessing : add_time_columns
#  #  Preprocessing : add_rank_column
#  #  Preprocessing : add_callers_and_callees
#  #  Preprocessing : add_dataset_name
#  #  Preprocessing : add_imbalance_perc
#  #  Preprocessing : add_module_name_caliper
#  #  Preprocessing : create_name_module_map
#  #  Preprocessing : add_vis_node_name
#  #  Preprocessing : add_path
#  #  [Validation] Map contains: 33 callsites, graph contains: 33 callsites
#  #  Module: ['Lulesh' 'MPI' 'LeapFrog' 'CalcConstraint' 'CalcLagrange' 'CalcForce'
#  #   'Timer']
#  #  Preprocess GraphFrame: 0.17586660315282643
#  #  -----------------------------------------
#  #  Convert to NetworkX graph: 0.0016409920062869787
#  #  -----------------------------------------
#  #  Group GraphFrame: 0.047882270999252796
#  #  -----------------------------------------
#  #  Write GraphFrame: 0.3421706040389836
#  #  -----------------------------------------
#  #  Module: ['Lulesh' 'MPI' 'LeapFrog' 'CalcConstraint' 'CalcLagrange' 'CalcForce'
#  #   'Timer']
#  #  #########################################
#  #  Run: 512-cores
#  #  #########################################
#  #  Creating graphframes: 512-cores
#  #  Data path: /home/suraj/Work/llnl/CallFlow/data/lulesh-8-runs/512-cores.json
#  #  Number of call sites in CCT (From dataframe): 33
#  #  Create GraphFrame: 0.29269594396464527
#  #  -----------------------------------------
#  #  Preprocessing : add_time_columns
#  #  Preprocessing : add_rank_column
#  #  Preprocessing : add_callers_and_callees
#  #  Preprocessing : add_dataset_name
#  #  Preprocessing : add_imbalance_perc
#  #  Preprocessing : add_module_name_caliper
#  #  Preprocessing : create_name_module_map
#  #  Preprocessing : add_vis_node_name
#  #  Preprocessing : add_path
#  #  [Validation] Map contains: 33 callsites, graph contains: 33 callsites
#  #  Module: ['Lulesh' 'MPI' 'LeapFrog' 'CalcConstraint' 'CalcLagrange' 'CalcForce'
#  #   'Timer']
#  #  Preprocess GraphFrame: 0.29193217889405787
#  #  -----------------------------------------
#  #  Convert to NetworkX graph: 0.0013649971224367619
#  #  -----------------------------------------
#  #  Group GraphFrame: 0.061930089024826884
#  #  -----------------------------------------
#  #  Write GraphFrame: 0.49277577293105423
#  #  -----------------------------------------
#  #  Module: ['Lulesh' 'MPI' 'LeapFrog' 'CalcConstraint' 'CalcLagrange' 'CalcForce'
#  #   'Timer']
