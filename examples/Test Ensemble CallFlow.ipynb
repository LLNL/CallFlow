# %%
# Global imports
import hatchet as ht
import pandas as pd
import os

# %%
# Local imports
from CallFlow.ensemble import EnsembleCallFlow
from CallFlow.pipeline import ConfigFileReader

# %%
pd.options.display.max_rows = 10
pd.options.display.float_format = '{:,.2f}'.format

# %%
path = os.getcwd().split('CallFlow')[0] + 'CallFlow'

# %%
experiment = 'lulesh-8-runs'
dataset = '1-core'
configFileName = 'Lulesh-Scaling-8-runs.json'

# %%
configPath = path + '/config_files' + '/' + configFileName
dataPath = path + '/' + experiment
dotPath = path + '/data/processed'
experimentPath = dataPath + '/' + experiment
experimentDotPath = dotPath + '/' + experiment

# %%
config = ConfigFileReader(configPath)

# %%
callflow = EnsembleCallFlow(config=config, process=True)
# Out:
#  #  [Ensemble] Process Mode.
#  #  #########################################
#  #  Run: 1-core
#  #  #########################################
#  #  Creating graphframes: 1-core
#  #  Data path: /home/suraj/Work/llnl/CallFlow/data/lulesh-8-runs/1-core.json
#  #  Number of call sites in CCT (From dataframe): 29
#  #  Create GraphFrame: 0.03658870607614517
#  #  -----------------------------------------
#  #  Preprocessing : add_time_columns
#  #  Preprocessing : add_rank_column
#  #  Preprocessing : add_callers_and_callees
#  #  Preprocessing : add_dataset_name
#  #  Preprocessing : add_imbalance_perc
# /home/suraj/miniconda3/lib/python3.7/site-packages/numpy/core/_methods.py:217: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /home/suraj/miniconda3/lib/python3.7/site-packages/numpy/core/_methods.py:209: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  #  Preprocessing : add_module_name_caliper
#  #  Preprocessing : create_name_module_map
#  #  Preprocessing : add_vis_node_name
#  #  Preprocessing : add_path
#  #  [Validation] Map contains: 29 callsites, graph contains: 29 callsites
#  #  Preprocess GraphFrame: 0.08786011603660882
#  #  -----------------------------------------
#  #  Convert to NetworkX graph: 0.002026630099862814
#  #  -----------------------------------------
#  #  Convert to NetworkX graph: 0.002026630099862814
#  #  -----------------------------------------
#  #  Write GraphFrame: 0.0061579179018735886
#  #  -----------------------------------------
#  #  #########################################
#  #  Run: 8-cores
#  #  #########################################
#  #  Creating graphframes: 8-cores
#  #  Data path: /home/suraj/Work/llnl/CallFlow/data/lulesh-8-runs/8-cores.json
#  #  Number of call sites in CCT (From dataframe): 33
#  #  Create GraphFrame: 0.0571880720090121
#  #  -----------------------------------------
#  #  Preprocessing : add_time_columns
#  #  Preprocessing : add_rank_column
#  #  Preprocessing : add_callers_and_callees
#  #  Preprocessing : add_dataset_name
#  #  Preprocessing : add_imbalance_perc
#  #  Preprocessing : add_module_name_caliper
#  #  Preprocessing : create_name_module_map
#  #  Preprocessing : add_vis_node_name
#  #  Preprocessing : add_path
#  #  [Validation] Map contains: 33 callsites, graph contains: 33 callsites
#  #  Preprocess GraphFrame: 0.09602386178448796
#  #  -----------------------------------------
#  #  Convert to NetworkX graph: 0.0013463781215250492
#  #  -----------------------------------------
#  #  Convert to NetworkX graph: 0.0013463781215250492
#  #  -----------------------------------------
#  #  Write GraphFrame: 0.010643231915310025
#  #  -----------------------------------------
#  #  #########################################
#  #  Run: 27-cores
#  #  #########################################
#  #  Creating graphframes: 27-cores
#  #  Data path: /home/suraj/Work/llnl/CallFlow/data/lulesh-8-runs/27-cores.json
#  #  Number of call sites in CCT (From dataframe): 33
#  #  Create GraphFrame: 0.09236186696216464
#  #  -----------------------------------------
#  #  Preprocessing : add_time_columns
#  #  Preprocessing : add_rank_column
#  #  Preprocessing : add_callers_and_callees
#  #  Preprocessing : add_dataset_name
#  #  Preprocessing : add_imbalance_perc
#  #  Preprocessing : add_module_name_caliper
#  #  Preprocessing : create_name_module_map
#  #  Preprocessing : add_vis_node_name
#  #  Preprocessing : add_path
#  #  [Validation] Map contains: 33 callsites, graph contains: 33 callsites
#  #  Preprocess GraphFrame: 0.16960941115394235
#  #  -----------------------------------------
#  #  Convert to NetworkX graph: 0.0036241458728909492
#  #  -----------------------------------------
#  #  Convert to NetworkX graph: 0.0036241458728909492
#  #  -----------------------------------------
#  #  Write GraphFrame: 0.0521417420823127
#  #  -----------------------------------------
#  #  #########################################
#  #  Run: 64-cores
#  #  #########################################
#  #  Creating graphframes: 64-cores
#  #  Data path: /home/suraj/Work/llnl/CallFlow/data/lulesh-8-runs/64-cores.json
#  #  Number of call sites in CCT (From dataframe): 33
#  #  Create GraphFrame: 0.06547149689868093
#  #  -----------------------------------------
#  #  Preprocessing : add_time_columns
#  #  Preprocessing : add_rank_column
#  #  Preprocessing : add_callers_and_callees
#  #  Preprocessing : add_dataset_name
#  #  Preprocessing : add_imbalance_perc
#  #  Preprocessing : add_module_name_caliper
#  #  Preprocessing : create_name_module_map
#  #  Preprocessing : add_vis_node_name
#  #  Preprocessing : add_path
#  #  [Validation] Map contains: 33 callsites, graph contains: 33 callsites
#  #  Preprocess GraphFrame: 0.12199203111231327
#  #  -----------------------------------------
#  #  Convert to NetworkX graph: 0.001701077912002802
#  #  -----------------------------------------
#  #  Convert to NetworkX graph: 0.001701077912002802
#  #  -----------------------------------------
#  #  Write GraphFrame: 0.07540925010107458
#  #  -----------------------------------------
#  #  #########################################
#  #  Run: 125-cores
#  #  #########################################
#  #  Creating graphframes: 125-cores
#  #  Data path: /home/suraj/Work/llnl/CallFlow/data/lulesh-8-runs/125-cores.json
#  #  Number of call sites in CCT (From dataframe): 33
#  #  Create GraphFrame: 0.11242732382379472
#  #  -----------------------------------------
#  #  Preprocessing : add_time_columns
#  #  Preprocessing : add_rank_column
#  #  Preprocessing : add_callers_and_callees
#  #  Preprocessing : add_dataset_name
#  #  Preprocessing : add_imbalance_perc
#  #  Preprocessing : add_module_name_caliper
#  #  Preprocessing : create_name_module_map
#  #  Preprocessing : add_vis_node_name
#  #  Preprocessing : add_path
#  #  [Validation] Map contains: 33 callsites, graph contains: 33 callsites
#  #  Preprocess GraphFrame: 0.14017484616488218
#  #  -----------------------------------------
#  #  Convert to NetworkX graph: 0.004756101872771978
#  #  -----------------------------------------
#  #  Convert to NetworkX graph: 0.004756101872771978
#  #  -----------------------------------------
#  #  Write GraphFrame: 0.11672851000912488
#  #  -----------------------------------------
#  #  #########################################
#  #  Run: 216-cores
#  #  #########################################
#  #  Creating graphframes: 216-cores
#  #  Data path: /home/suraj/Work/llnl/CallFlow/data/lulesh-8-runs/216-cores.json
#  #  Number of call sites in CCT (From dataframe): 33
#  #  Create GraphFrame: 0.09147506696172059
#  #  -----------------------------------------
#  #  Preprocessing : add_time_columns
#  #  Preprocessing : add_rank_column
#  #  Preprocessing : add_callers_and_callees
#  #  Preprocessing : add_dataset_name
#  #  Preprocessing : add_imbalance_perc
#  #  Preprocessing : add_module_name_caliper
#  #  Preprocessing : create_name_module_map
#  #  Preprocessing : add_vis_node_name
#  #  Preprocessing : add_path
#  #  [Validation] Map contains: 33 callsites, graph contains: 33 callsites
#  #  Preprocess GraphFrame: 0.16816341294907033
#  #  -----------------------------------------
#  #  Convert to NetworkX graph: 0.0018658109474927187
#  #  -----------------------------------------
#  #  Convert to NetworkX graph: 0.0018658109474927187
#  #  -----------------------------------------
#  #  Write GraphFrame: 0.1946094708982855
#  #  -----------------------------------------
#  #  #########################################
#  #  Run: 343-cores
#  #  #########################################
#  #  Creating graphframes: 343-cores
#  #  Data path: /home/suraj/Work/llnl/CallFlow/data/lulesh-8-runs/343-cores.json
#  #  Number of call sites in CCT (From dataframe): 33
#  #  Create GraphFrame: 0.19796901498921216
#  #  -----------------------------------------
#  #  Preprocessing : add_time_columns
#  #  Preprocessing : add_rank_column
#  #  Preprocessing : add_callers_and_callees
#  #  Preprocessing : add_dataset_name
#  #  Preprocessing : add_imbalance_perc
#  #  Preprocessing : add_module_name_caliper
#  #  Preprocessing : create_name_module_map
#  #  Preprocessing : add_vis_node_name
#  #  Preprocessing : add_path
#  #  [Validation] Map contains: 33 callsites, graph contains: 33 callsites
#  #  Preprocess GraphFrame: 0.1817315430380404
#  #  -----------------------------------------
#  #  Convert to NetworkX graph: 0.0016648529563099146
#  #  -----------------------------------------
#  #  Convert to NetworkX graph: 0.0016648529563099146
#  #  -----------------------------------------
#  #  Write GraphFrame: 0.3129791778046638
#  #  -----------------------------------------
#  #  #########################################
#  #  Run: 512-cores
#  #  #########################################
#  #  Creating graphframes: 512-cores
#  #  Data path: /home/suraj/Work/llnl/CallFlow/data/lulesh-8-runs/512-cores.json
#  #  Number of call sites in CCT (From dataframe): 33
#  #  Create GraphFrame: 0.18108919984661043
#  #  -----------------------------------------
#  #  Preprocessing : add_time_columns
#  #  Preprocessing : add_rank_column
#  #  Preprocessing : add_callers_and_callees
#  #  Preprocessing : add_dataset_name
#  #  Preprocessing : add_imbalance_perc
#  #  Preprocessing : add_module_name_caliper
#  #  Preprocessing : create_name_module_map
#  #  Preprocessing : add_vis_node_name
#  #  Preprocessing : add_path
#  #  [Validation] Map contains: 33 callsites, graph contains: 33 callsites
#  #  Preprocess GraphFrame: 0.2237325361929834
#  #  -----------------------------------------
#  #  Convert to NetworkX graph: 0.0017997329123318195
#  #  -----------------------------------------
#  #  Convert to NetworkX graph: 0.0017997329123318195
#  #  -----------------------------------------
#  #  Write GraphFrame: 0.48647969402372837
#  #  -----------------------------------------
#  #  [Process] Reading the dataframe and graph of state: 1-core
#  #  [Process] Reading the dataframe and graph of state: 8-cores
#  #  [Process] Reading the dataframe and graph of state: 27-cores
#  #  [Process] Reading the dataframe and graph of state: 64-cores
#  #  [Process] Reading the dataframe and graph of state: 125-cores
#  #  [Process] Reading the dataframe and graph of state: 216-cores
#  #  [Process] Reading the dataframe and graph of state: 343-cores
#  #  [Process] Reading the dataframe and graph of state: 512-cores
#  #  Done with Union.
#  #  Number of callsites in dataframe: 33
#  #  Number of callsites in the graph: 33
#  #  Number of modules in the graph: 7
#  #  Union GraphFrame: 0.1083287219516933
#  #  -----------------------------------------
# [('main', {'1-core': 1}), ('MPI_Barrier', {'1-core': 1}), ('MPI_Finalize', {'1-core': 1}), ('MPI_Reduce', {'1-core': 1}), ('lulesh.cycle', {'1-core': 1}), ('LagrangeLeapFrog', {'1-core': 1}), ('CalcTimeConstraintsForElems', {'1-core': 1}), ('CalcCourantConstraintForElems', {'1-core': 1}), ('CalcHydroConstraintForElems', {'1-core': 1}), ('LagrangeElements', {'1-core': 1}), ('ApplyMaterialPropertiesForElems', {'1-core': 1}), ('EvalEOSForElems', {'1-core': 1}), ('CalcEnergyForElems', {'1-core': 1}), ('CalcPressureForElems', {'1-core': 1}), ('CalcSoundSpeedForElems', {'1-core': 1}), ('CalcLagrangeElements', {'1-core': 1}), ('CalcKinematicsForElems', {'1-core': 1}), ('CalcQForElems', {'1-core': 1}), ('CalcMonotonicQGradientsForElems', {'1-core': 1}), ('CalcMonotonicQRegionForElems', {'1-core': 1}), ('UpdateVolumesForElems', {'1-core': 1}), ('LagrangeNodal', {'1-core': 1}), ('CalcForceForNodes', {'1-core': 1}), ('CalcVolumeForceForElems', {'1-core': 1}), ('CalcHourglassControlForElems', {'1-core': 1}), ('CalcFBHourglassForceForElems', {'1-core': 1}), ('IntegrateStressForElems', {'1-core': 1}), ('TimeIncrement', {'1-core': 1}), ('MPI_Allreduce', {'1-core': 1})]
# [('main', {'1-core': 1, '8-cores': 1}), ('MPI_Barrier', {'1-core': 1, '8-cores': 1}), ('MPI_Finalize', {'1-core': 1, '8-cores': 1}), ('MPI_Reduce', {'1-core': 1, '8-cores': 1}), ('lulesh.cycle', {'1-core': 1, '8-cores': 1}), ('LagrangeLeapFrog', {'1-core': 1, '8-cores': 1}), ('CalcTimeConstraintsForElems', {'1-core': 1, '8-cores': 1}), ('CalcCourantConstraintForElems', {'1-core': 1, '8-cores': 1}), ('CalcHydroConstraintForElems', {'1-core': 1, '8-cores': 1}), ('LagrangeElements', {'1-core': 1, '8-cores': 1}), ('ApplyMaterialPropertiesForElems', {'1-core': 1, '8-cores': 1}), ('EvalEOSForElems', {'1-core': 1, '8-cores': 1}), ('CalcEnergyForElems', {'1-core': 1, '8-cores': 1}), ('CalcPressureForElems', {'1-core': 1, '8-cores': 1}), ('CalcSoundSpeedForElems', {'1-core': 1, '8-cores': 1}), ('CalcLagrangeElements', {'1-core': 1, '8-cores': 1}), ('CalcKinematicsForElems', {'1-core': 1, '8-cores': 1}), ('CalcQForElems', {'1-core': 1, '8-cores': 1}), ('CalcMonotonicQGradientsForElems', {'1-core': 1, '8-cores': 1}), ('CalcMonotonicQRegionForElems', {'1-core': 1, '8-cores': 1}), ('UpdateVolumesForElems', {'1-core': 1, '8-cores': 1}), ('LagrangeNodal', {'1-core': 1, '8-cores': 1}), ('CalcForceForNodes', {'1-core': 1, '8-cores': 1}), ('CalcVolumeForceForElems', {'1-core': 1, '8-cores': 1}), ('CalcHourglassControlForElems', {'1-core': 1, '8-cores': 1}), ('CalcFBHourglassForceForElems', {'1-core': 1, '8-cores': 1}), ('IntegrateStressForElems', {'1-core': 1, '8-cores': 1}), ('TimeIncrement', {'1-core': 1, '8-cores': 1}), ('MPI_Allreduce', {'1-core': 1, '8-cores': 1}), ('MPI_Irecv', {'8-cores': 1}), ('MPI_Isend', {'8-cores': 1}), ('MPI_Wait', {'8-cores': 1}), ('MPI_Waitall', {'8-cores': 1})]
# [('main', {'1-core': 1, '8-cores': 1, '27-cores': 1}), ('MPI_Barrier', {'1-core': 1, '8-cores': 1, '27-cores': 1}), ('MPI_Finalize', {'1-core': 1, '8-cores': 1, '27-cores': 1}), ('MPI_Reduce', {'1-core': 1, '8-cores': 1, '27-cores': 1}), ('lulesh.cycle', {'1-core': 1, '8-cores': 1, '27-cores': 1}), ('LagrangeLeapFrog', {'1-core': 1, '8-cores': 1, '27-cores': 1}), ('CalcTimeConstraintsForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1}), ('CalcCourantConstraintForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1}), ('CalcHydroConstraintForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1}), ('LagrangeElements', {'1-core': 1, '8-cores': 1, '27-cores': 1}), ('ApplyMaterialPropertiesForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1}), ('EvalEOSForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1}), ('CalcEnergyForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1}), ('CalcPressureForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1}), ('CalcSoundSpeedForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1}), ('CalcLagrangeElements', {'1-core': 1, '8-cores': 1, '27-cores': 1}), ('CalcKinematicsForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1}), ('CalcQForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1}), ('CalcMonotonicQGradientsForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1}), ('CalcMonotonicQRegionForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1}), ('UpdateVolumesForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1}), ('LagrangeNodal', {'1-core': 1, '8-cores': 1, '27-cores': 1}), ('CalcForceForNodes', {'1-core': 1, '8-cores': 1, '27-cores': 1}), ('CalcVolumeForceForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1}), ('CalcHourglassControlForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1}), ('CalcFBHourglassForceForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1}), ('IntegrateStressForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1}), ('TimeIncrement', {'1-core': 1, '8-cores': 1, '27-cores': 1}), ('MPI_Allreduce', {'1-core': 1, '8-cores': 1, '27-cores': 1}), ('MPI_Irecv', {'8-cores': 1, '27-cores': 1}), ('MPI_Isend', {'8-cores': 1, '27-cores': 1}), ('MPI_Wait', {'8-cores': 1, '27-cores': 1}), ('MPI_Waitall', {'8-cores': 1, '27-cores': 1})]
# [('main', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1}), ('MPI_Barrier', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1}), ('MPI_Finalize', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1}), ('MPI_Reduce', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1}), ('lulesh.cycle', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1}), ('LagrangeLeapFrog', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1}), ('CalcTimeConstraintsForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1}), ('CalcCourantConstraintForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1}), ('CalcHydroConstraintForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1}), ('LagrangeElements', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1}), ('ApplyMaterialPropertiesForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1}), ('EvalEOSForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1}), ('CalcEnergyForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1}), ('CalcPressureForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1}), ('CalcSoundSpeedForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1}), ('CalcLagrangeElements', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1}), ('CalcKinematicsForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1}), ('CalcQForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1}), ('CalcMonotonicQGradientsForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1}), ('CalcMonotonicQRegionForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1}), ('UpdateVolumesForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1}), ('LagrangeNodal', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1}), ('CalcForceForNodes', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1}), ('CalcVolumeForceForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1}), ('CalcHourglassControlForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1}), ('CalcFBHourglassForceForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1}), ('IntegrateStressForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1}), ('TimeIncrement', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1}), ('MPI_Allreduce', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1}), ('MPI_Irecv', {'8-cores': 1, '27-cores': 1, '64-cores': 1}), ('MPI_Isend', {'8-cores': 1, '27-cores': 1, '64-cores': 1}), ('MPI_Wait', {'8-cores': 1, '27-cores': 1, '64-cores': 1}), ('MPI_Waitall', {'8-cores': 1, '27-cores': 1, '64-cores': 1})]
# [('main', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1}), ('MPI_Barrier', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1}), ('MPI_Finalize', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1}), ('MPI_Reduce', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1}), ('lulesh.cycle', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1}), ('LagrangeLeapFrog', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1}), ('CalcTimeConstraintsForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1}), ('CalcCourantConstraintForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1}), ('CalcHydroConstraintForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1}), ('LagrangeElements', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1}), ('ApplyMaterialPropertiesForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1}), ('EvalEOSForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1}), ('CalcEnergyForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1}), ('CalcPressureForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1}), ('CalcSoundSpeedForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1}), ('CalcLagrangeElements', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1}), ('CalcKinematicsForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1}), ('CalcQForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1}), ('CalcMonotonicQGradientsForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1}), ('CalcMonotonicQRegionForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1}), ('UpdateVolumesForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1}), ('LagrangeNodal', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1}), ('CalcForceForNodes', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1}), ('CalcVolumeForceForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1}), ('CalcHourglassControlForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1}), ('CalcFBHourglassForceForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1}), ('IntegrateStressForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1}), ('TimeIncrement', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1}), ('MPI_Allreduce', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1}), ('MPI_Irecv', {'8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1}), ('MPI_Isend', {'8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1}), ('MPI_Wait', {'8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1}), ('MPI_Waitall', {'8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1})]
# [('main', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1}), ('MPI_Barrier', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1}), ('MPI_Finalize', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1}), ('MPI_Reduce', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1}), ('lulesh.cycle', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1}), ('LagrangeLeapFrog', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1}), ('CalcTimeConstraintsForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1}), ('CalcCourantConstraintForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1}), ('CalcHydroConstraintForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1}), ('LagrangeElements', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1}), ('ApplyMaterialPropertiesForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1}), ('EvalEOSForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1}), ('CalcEnergyForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1}), ('CalcPressureForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1}), ('CalcSoundSpeedForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1}), ('CalcLagrangeElements', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1}), ('CalcKinematicsForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1}), ('CalcQForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1}), ('CalcMonotonicQGradientsForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1}), ('CalcMonotonicQRegionForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1}), ('UpdateVolumesForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1}), ('LagrangeNodal', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1}), ('CalcForceForNodes', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1}), ('CalcVolumeForceForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1}), ('CalcHourglassControlForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1}), ('CalcFBHourglassForceForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1}), ('IntegrateStressForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1}), ('TimeIncrement', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1}), ('MPI_Allreduce', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1}), ('MPI_Irecv', {'8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1}), ('MPI_Isend', {'8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1}), ('MPI_Wait', {'8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1}), ('MPI_Waitall', {'8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1})]
# [('main', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1, '343-cores': 1}), ('MPI_Barrier', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1, '343-cores': 1}), ('MPI_Finalize', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1, '343-cores': 1}), ('MPI_Reduce', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1, '343-cores': 1}), ('lulesh.cycle', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1, '343-cores': 1}), ('LagrangeLeapFrog', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1, '343-cores': 1}), ('CalcTimeConstraintsForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1, '343-cores': 1}), ('CalcCourantConstraintForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1, '343-cores': 1}), ('CalcHydroConstraintForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1, '343-cores': 1}), ('LagrangeElements', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1, '343-cores': 1}), ('ApplyMaterialPropertiesForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1, '343-cores': 1}), ('EvalEOSForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1, '343-cores': 1}), ('CalcEnergyForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1, '343-cores': 1}), ('CalcPressureForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1, '343-cores': 1}), ('CalcSoundSpeedForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1, '343-cores': 1}), ('CalcLagrangeElements', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1, '343-cores': 1}), ('CalcKinematicsForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1, '343-cores': 1}), ('CalcQForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1, '343-cores': 1}), ('CalcMonotonicQGradientsForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1, '343-cores': 1}), ('CalcMonotonicQRegionForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1, '343-cores': 1}), ('UpdateVolumesForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1, '343-cores': 1}), ('LagrangeNodal', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1, '343-cores': 1}), ('CalcForceForNodes', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1, '343-cores': 1}), ('CalcVolumeForceForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1, '343-cores': 1}), ('CalcHourglassControlForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1, '343-cores': 1}), ('CalcFBHourglassForceForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1, '343-cores': 1}), ('IntegrateStressForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1, '343-cores': 1}), ('TimeIncrement', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1, '343-cores': 1}), ('MPI_Allreduce', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1, '343-cores': 1}), ('MPI_Irecv', {'8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1, '343-cores': 1}), ('MPI_Isend', {'8-cores': 1, '27-cores': 1, '64-co ...
# [('main', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1, '343-cores': 1, '512-cores': 1}), ('MPI_Barrier', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1, '343-cores': 1, '512-cores': 1}), ('MPI_Finalize', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1, '343-cores': 1, '512-cores': 1}), ('MPI_Reduce', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1, '343-cores': 1, '512-cores': 1}), ('lulesh.cycle', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1, '343-cores': 1, '512-cores': 1}), ('LagrangeLeapFrog', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1, '343-cores': 1, '512-cores': 1}), ('CalcTimeConstraintsForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1, '343-cores': 1, '512-cores': 1}), ('CalcCourantConstraintForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1, '343-cores': 1, '512-cores': 1}), ('CalcHydroConstraintForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1, '343-cores': 1, '512-cores': 1}), ('LagrangeElements', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1, '343-cores': 1, '512-cores': 1}), ('ApplyMaterialPropertiesForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1, '343-cores': 1, '512-cores': 1}), ('EvalEOSForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1, '343-cores': 1, '512-cores': 1}), ('CalcEnergyForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1, '343-cores': 1, '512-cores': 1}), ('CalcPressureForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1, '343-cores': 1, '512-cores': 1}), ('CalcSoundSpeedForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1, '343-cores': 1, '512-cores': 1}), ('CalcLagrangeElements', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1, '343-cores': 1, '512-cores': 1}), ('CalcKinematicsForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1, '343-cores': 1, '512-cores': 1}), ('CalcQForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1, '343-cores': 1, '512-cores': 1}), ('CalcMonotonicQGradientsForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1, '343-cores': 1, '512-cores': 1}), ('CalcMonotonicQRegionForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1, '343-cores': 1, '512-cores': 1}), ('UpdateVolumesForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1, '343-cores': 1, '512-cores': 1}), ('LagrangeNodal', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1, '343-cores': 1, '512-cores': 1}), ('CalcForceForNodes', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1, '343-cores': 1, '512-cores': 1}), ('CalcVolumeForceForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1, '343-cores': 1, '512-cores': 1}), ('CalcHourglassControlForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1, '343-cores': 1, '512-cores': 1}), ('CalcFBHourglassForceForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1, '343-cores': 1, '512-cores': 1}), ('IntegrateStressForElems', {'1-core': 1, '8-cores': 1, '27-cores': 1, '64-cores': 1, '125-cores': 1, '216-cores': 1, '343-cores':  ...
#  #  Writing ensemble graph: 1.293554020114243
#  #  -----------------------------------------
#  #  Dataset idx:
#  #  Min. time (inc): [8. 0. 0. 0. 0. 0. 0. 0.]
#  #  Max. time (inc): [27339729. 52585114. 51832362. 50906911. 53788713. 53554315. 51205727.
#  #   43634124.]
#  #  Min. time (exc): [8. 0. 0. 0. 0. 0. 0. 0.]
#  #  Max. time (exc): [ 8523384. 14010050. 14960935. 14069147. 15118423. 15378181. 13548524.
#  #   10202802.]
#  #  [Filter] By Inclusive time : 0
#  #  Done with Filtering the Union graph.
#  #  Number of callsites in dataframe: 33
#  #  Number of callsites in the graph: 33
#  #  Number of modules in the graph: 7
#  #  Filter ensemble graph: 0.0971965070348233
#  #  -----------------------------------------
#  #  Writing ensemble graph: 1.1545416221488267
#  #  -----------------------------------------
#  #  Nodes: 33, Edges: 44
#  #  Done with Ensemb;le supergraph.
#  #  Number of callsites in dataframe: 33
#  #  Number of callsites in the graph: 33
#  #  Modules in the graph: ['Lulesh' 'MPI' 'LeapFrog' 'CalcConstraint' 'CalcLagrange' 'CalcForce'
#  #   'Timer']
#  #  Group ensemble graph: 0.8556400611996651
#  #  -----------------------------------------
#  #  Write group ensemble graph: 1.393378724111244
#  #  -----------------------------------------
#  #  [Process] Reading the union dataframe and graph : ensemble_entire
# Times:
#
# Calculating Gradients, Mean runtime variations, and Distribution.
#  #  Dump Gradient, distribution and variations: 6.729739416157827
#  #  -----------------------------------------
# Times:
#     Process data:        0.05s
#     Collect Callsite data: 4.64s
#     Collect Module data: 1.32s
#     Module callsite map data: 0.03s
#     Writing data:        0.65s
