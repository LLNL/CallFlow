# %%
from hatchet import *
import pandas as pd
import numpy as np
from state import State
import matplotlib.pyplot as plt
import json
import utils

# %%
# %matplotlib inline

# %%
pd.options.display.max_rows = 75
pd.options.display.float_format = '{:,.2f}'.format
plt.rcParams['figure.figsize'] = (16, 12)

# %%
name = 'osu_bw'
dir_name = "/home/vidi/Work/llnl/CallFlow/.callflow/"
# dir_name = "/Users/jarus/ucd/Research/Visualisation/projects/CallFlow/.callflow/"

# %%
def lookup(df, node):
    return df.loc[df['node'] == node]

# %%
def lookup_with_node(df, node):
    return df.loc[df['name'] == node.callpath[-1]]

# %%
def lookup_with_name(df, name):
    return df.loc[df['name'] == name]

# %%
def replace_str_with_Node(df, graph):
        mapper = {}
        def dfs_recurse(root):
            for node in root.children: 
                mapper[node.callpath[-1]] = Node(node.nid, node.callpath, None)
                dfs_recurse(node)
        for root in graph.roots:
            mapper[root.callpath[-1]] = Node(root.nid, root.callpath, None)
            dfs_recurse(root)
        df['node'] = df['node'].apply(lambda node: mapper[node] if node in mapper else '')
        return df

# %%
def read_gf(name):
        state = State()
        path = dir_name + name
        df_filepath = path + '/filter_df.csv'
        entire_df_filepath = path + '/entire_df.csv'
        graph_filepath = path + '/filter_graph.json'
        entire_graph_filepath = path + '/entire_graph.json'   

        with open(graph_filepath, 'r') as graphFile:
            data = json.load(graphFile)

        state.gf = GraphFrame()
        state.gf.from_literal(data)

        with open(entire_graph_filepath, 'r') as entire_graphFile:
            entire_data = json.load(entire_graphFile)
            
        state.entire_gf = GraphFrame()
        state.entire_gf.from_literal(entire_data)

        state.df = pd.read_csv(df_filepath)
        state.entire_df = pd.read_csv(entire_df_filepath)

        state.graph = state.gf.graph
        state.entire_graph = state.entire_gf.graph

        state.map = state.node_hash_mapper()

        # Print the module group by information. 
        # print(state.df.groupby(['module']).agg(['mean','count']))

        # replace df['node'] from str to the Node object.
        state.df = replace_str_with_Node(state.df, state.graph)
        state.entire_df = replace_str_with_Node(state.entire_df, state.entire_graph)

        # add path to the dataframes. 
        # state.df['path'] = state.df['node'].apply(lambda node: node.callpath)
        # state.entire_df['path'] = state.entire_df['node'].apply(lambda node: node.callpath if node else [])

        return state

# %%
states = {}
states[name] = read_gf(name)
df = states['osu_bw'].df
graph = states['osu_bw'].graph

# %%
print(df[['name', 'module', 'path']])
# Out:
#                             name                     module  \
# 0                 <program root>        libmonitor.so.0.0.0
# 1                 <program root>        libmonitor.so.0.0.0
# 2                           main                     osu_bw
# 3                           main                     osu_bw
# 4               157:MPI_Finalize        libmonitor.so.0.0.0
# 5               157:MPI_Finalize        libmonitor.so.0.0.0
# 6                  PMPI_Finalize           libmpi.so.12.0.5
# 7                  PMPI_Finalize           libmpi.so.12.0.5
# 8              294:MPID_Finalize           libmpi.so.12.0.5
# 9              294:MPID_Finalize           libmpi.so.12.0.5
# 10        162:MPIDI_CH3_Finalize           libmpi.so.12.0.5
# 11        162:MPIDI_CH3_Finalize           libmpi.so.12.0.5
# 12            230:psm_dofinalize           libmpi.so.12.0.5
# 13            230:psm_dofinalize           libmpi.so.12.0.5
# 14        36:<unknown procedure>  libpsm_infinipath.so.1.14
# 15        36:<unknown procedure>  libpsm_infinipath.so.1.14
# 16           <unknown procedure>  libpsm_infinipath.so.1.14
# 17           <unknown procedure>  libpsm_infinipath.so.1.14
# 18           <unknown procedure>  libpsm_infinipath.so.1.14
# 19           <unknown procedure>  libpsm_infinipath.so.1.14
# 20           <unknown procedure>  libpsm_infinipath.so.1.14
# 21           <unknown procedure>  libpsm_infinipath.so.1.14
# 22              <unknown file>:0                      Unkno
# 23              <unknown file>:0                      Unkno
# 24              <unknown file>:0                      Unkno
# 25              <unknown file>:0                      Unkno
# 26             Loop@osu_bw.c:112                      Unkno
# 27              122:PMPI_Waitall           libmpi.so.12.0.5
# 28         309:MPIR_Waitall_impl           libmpi.so.12.0.5
# 29  145:MPIDI_CH3_Progress_start           libmpi.so.12.0.5
# 30       189:<unknown procedure>  libpsm_infinipath.so.1.14
# 31           <unknown procedure>  libpsm_infinipath.so.1.14
# 32           <unknown procedure>  libpsm_infinipath.so.1.14
# 33           <unknown procedure>  libpsm_infinipath.so.1.14
# 34           <unknown procedure>  libpsm_infinipath.so.1.14
# 35           <unknown procedure>  libpsm_infinipath.so.1.14
# 36           <unknown procedure>  libpsm_infinipath.so.1.14
# 37           <unknown procedure>       libinfinipath.so.4.0
# 38              <unknown file>:0                      Unkno
# 39   162:MPIDI_CH3_Progress_wait           libmpi.so.12.0.5
# 40         220:psm_progress_wait           libmpi.so.12.0.5
# 41       232:<unknown procedure>  libpsm_infinipath.so.1.14
# 42           <unknown procedure>  libpsm_infinipath.so.1.14
# 43           <unknown procedure>  libpsm_infinipath.so.1.14
# 44           <unknown procedure>  libpsm_infinipath.so.1.14
# 45           <unknown procedure>  libpsm_infinipath.so.1.14
# 46           <unknown procedure>  libpsm_infinipath.so.1.14
# 47           <unknown procedure>  libpsm_infinipath.so.1.14
# 48           <unknown procedure>  libpsm_infinipath.so.1.14
# 49           <unknown procedure>       libinfinipath.so.4.0
# 50              <unknown file>:0                      Unkno
# 51             Loop@osu_bw.c:134                      Unkno
# 52              140:PMPI_Waitall           libmpi.so.12.0.5
# 53         309:MPIR_Waitall_impl           libmpi.so.12.0.5
# 54   162:MPIDI_CH3_Progress_wait           libmpi.so.12.0.5
# 55         220:psm_progress_wait           libmpi.so.12.0.5
# 56       232:<unknown procedure>  libpsm_infinipath.so.1.14
# 57           <unknown procedure>  libpsm_infinipath.so.1.14
# 58           <unknown procedure>  libpsm_infinipath.so.1.14
# 59           <unknown procedure>  libpsm_infinipath.so.1.14
# 60           <unknown procedure>  libpsm_infinipath.so.1.14
# 61           <unknown procedure>  libpsm_infinipath.so.1.14
# 62           <unknown procedure>       libinfinipath.so.4.0
# 63              <unknown file>:0                      Unkno
#
#                                                  path
# 0                                 ('<program root>',)
# 1                                 ('<program root>',)
# 2                          ('<program root>', 'main')
# 3                          ('<program root>', 'main')
# 4   ('<program root>', 'main', 'Loop@osu_bw.c:112'...
# 5   ('<program root>', 'main', 'Loop@osu_bw.c:112'...
# 6   ('<program root>', 'main', 'Loop@osu_bw.c:112'...
# 7   ('<program root>', 'main', 'Loop@osu_bw.c:112'...
# 8   ('<program root>', 'main', 'Loop@osu_bw.c:112'...
# 9   ('<program root>', 'main', 'Loop@osu_bw.c:112'...
# 10  ('<program root>', 'main', 'Loop@osu_bw.c:112'...
# 11  ('<program root>', 'main', 'Loop@osu_bw.c:112'...
# 12  ('<program root>', 'main', 'Loop@osu_bw.c:112'...
# 13  ('<program root>', 'main', 'Loop@osu_bw.c:112'...
# 14  ('<program root>', 'main', 'Loop@osu_bw.c:112'...
# 15  ('<program root>', 'main', 'Loop@osu_bw.c:112'...
# 16  ('<program root>', 'main', 'Loop@osu_bw.c:112'...
# 17  ('<program root>', 'main', 'Loop@osu_bw.c:112'...
# 18  ('<program root>', 'main', 'Loop@osu_bw.c:112'...
# 19  ('<program root>', 'main', 'Loop@osu_bw.c:112'...
# 20  ('<program root>', 'main', 'Loop@osu_bw.c:112'...
# 21  ('<program root>', 'main', 'Loop@osu_bw.c:112'...
# 22  ('<program root>', 'main', 'Loop@osu_bw.c:112'...
# 23  ('<program root>', 'main', 'Loop@osu_bw.c:112'...
# 24  ('<program root>', 'main', 'Loop@osu_bw.c:112'...
# 25  ('<program root>', 'main', 'Loop@osu_bw.c:112'...
# 26    ('<program root>', 'main', 'Loop@osu_bw.c:112')
# 27  ('<program root>', 'main', 'Loop@osu_bw.c:112'...
# 28  ('<program root>', 'main', 'Loop@osu_bw.c:112'...
# 29  ('<program root>', 'main', 'Loop@osu_bw.c:112'...
# 30  ('<program root>', 'main', 'Loop@osu_bw.c:112'...
# 31  ('<program root>', 'main', 'Loop@osu_bw.c:112'...
# 32  ('<program root>', 'main', 'Loop@osu_bw.c:112'...
# 33  ('<program root>', 'main', 'Loop@osu_bw.c:112'...
# 34  ('<program root>', 'main', 'Loop@osu_bw.c:112'...
# 35  ('<program root>', 'main', 'Loop@osu_bw.c:112'...
# 36  ('<program root>', 'main', 'Loop@osu_bw.c:112'...
# 37  ('<program root>', 'main', 'Loop@osu_bw.c:112'...
# 38  ('<program root>', 'main', 'Loop@osu_bw.c:112'...
# 39  ('<program root>', 'main', 'Loop@osu_bw.c:112'...
# 40  ('<program root>', 'main', 'Loop@osu_bw.c:112'...
# 41  ('<program root>', 'main', 'Loop@osu_bw.c:112'...
# 42  ('<program root>', 'main', 'Loop@osu_bw.c:112'...
# 43  ('<program root>', 'main', 'Loop@osu_bw.c:112'...
# 44  ('<program root>', 'main', 'Loop@osu_bw.c:112'...
# 45  ('<program root>', 'main', 'Loop@osu_bw.c:112'...
# 46  ('<program root>', 'main', 'Loop@osu_bw.c:112'...
# 47  ('<program root>', 'main', 'Loop@osu_bw.c:112'...
# 48  ('<program root>', 'main', 'Loop@osu_bw.c:112'...
# 49  ('<program root>', 'main', 'Loop@osu_bw.c:112'...
# 50  ('<program root>', 'main', 'Loop@osu_bw.c:112'...
# 51  ('<program root>', 'main', 'Loop@osu_bw.c:112'...
# 52  ('<program root>', 'main', 'Loop@osu_bw.c:112'...
# 53  ('<program root>', 'main', 'Loop@osu_bw.c:112'...
# 54  ('<program root>', 'main', 'Loop@osu_bw.c:112'...
# 55  ('<program root>', 'main', 'Loop@osu_bw.c:112'...
# 56  ('<program root>', 'main', 'Loop@osu_bw.c:112'...
# 57  ('<program root>', 'main', 'Loop@osu_bw.c:112'...
# 58  ('<program root>', 'main', 'Loop@osu_bw.c:112'...
# 59  ('<program root>', 'main', 'Loop@osu_bw.c:112'...
# 60  ('<program root>', 'main', 'Loop@osu_bw.c:112'...
# 61  ('<program root>', 'main', 'Loop@osu_bw.c:112'...
# 62  ('<program root>', 'main', 'Loop@osu_bw.c:112'...
# 63  ('<program root>', 'main', 'Loop@osu_bw.c:112'...

# %%
def bfs(graph):
    ret = {}
    node_count = 0
    level = 0
    for root in graph.roots:
        print(root)
        node_gen = root.traverse_bf()
        for node in node_gen:
            node_count += 1
            for child in node.children:
                ret[child.callpath[-1] + str(child.df_index)] = {
                    'df_index': child.df_index,
                    'level': len(child.callpath) - 1,
                    'path': child.callpath,
#                     'time (inc)': lookup(df, child.callpath[-1])
                }
                print(ret[child.callpath[-1] + str(child.df_index)])
                level += 1
    return ret

# %%
print(states[name].df[['name', 'module']])
# Out:
#                             name                     module
# 0                 <program root>        libmonitor.so.0.0.0
# 1                 <program root>        libmonitor.so.0.0.0
# 2                           main                     osu_bw
# 3                           main                     osu_bw
# 4               157:MPI_Finalize        libmonitor.so.0.0.0
# 5               157:MPI_Finalize        libmonitor.so.0.0.0
# 6                  PMPI_Finalize           libmpi.so.12.0.5
# 7                  PMPI_Finalize           libmpi.so.12.0.5
# 8              294:MPID_Finalize           libmpi.so.12.0.5
# 9              294:MPID_Finalize           libmpi.so.12.0.5
# 10        162:MPIDI_CH3_Finalize           libmpi.so.12.0.5
# 11        162:MPIDI_CH3_Finalize           libmpi.so.12.0.5
# 12            230:psm_dofinalize           libmpi.so.12.0.5
# 13            230:psm_dofinalize           libmpi.so.12.0.5
# 14        36:<unknown procedure>  libpsm_infinipath.so.1.14
# 15        36:<unknown procedure>  libpsm_infinipath.so.1.14
# 16           <unknown procedure>  libpsm_infinipath.so.1.14
# 17           <unknown procedure>  libpsm_infinipath.so.1.14
# 18           <unknown procedure>  libpsm_infinipath.so.1.14
# 19           <unknown procedure>  libpsm_infinipath.so.1.14
# 20           <unknown procedure>  libpsm_infinipath.so.1.14
# 21           <unknown procedure>  libpsm_infinipath.so.1.14
# 22              <unknown file>:0                      Unkno
# 23              <unknown file>:0                      Unkno
# 24              <unknown file>:0                      Unkno
# 25              <unknown file>:0                      Unkno
# 26             Loop@osu_bw.c:112                      Unkno
# 27              122:PMPI_Waitall           libmpi.so.12.0.5
# 28         309:MPIR_Waitall_impl           libmpi.so.12.0.5
# 29  145:MPIDI_CH3_Progress_start           libmpi.so.12.0.5
# 30       189:<unknown procedure>  libpsm_infinipath.so.1.14
# 31           <unknown procedure>  libpsm_infinipath.so.1.14
# 32           <unknown procedure>  libpsm_infinipath.so.1.14
# 33           <unknown procedure>  libpsm_infinipath.so.1.14
# 34           <unknown procedure>  libpsm_infinipath.so.1.14
# 35           <unknown procedure>  libpsm_infinipath.so.1.14
# 36           <unknown procedure>  libpsm_infinipath.so.1.14
# 37           <unknown procedure>       libinfinipath.so.4.0
# 38              <unknown file>:0                      Unkno
# 39   162:MPIDI_CH3_Progress_wait           libmpi.so.12.0.5
# 40         220:psm_progress_wait           libmpi.so.12.0.5
# 41       232:<unknown procedure>  libpsm_infinipath.so.1.14
# 42           <unknown procedure>  libpsm_infinipath.so.1.14
# 43           <unknown procedure>  libpsm_infinipath.so.1.14
# 44           <unknown procedure>  libpsm_infinipath.so.1.14
# 45           <unknown procedure>  libpsm_infinipath.so.1.14
# 46           <unknown procedure>  libpsm_infinipath.so.1.14
# 47           <unknown procedure>  libpsm_infinipath.so.1.14
# 48           <unknown procedure>  libpsm_infinipath.so.1.14
# 49           <unknown procedure>       libinfinipath.so.4.0
# 50              <unknown file>:0                      Unkno
# 51             Loop@osu_bw.c:134                      Unkno
# 52              140:PMPI_Waitall           libmpi.so.12.0.5
# 53         309:MPIR_Waitall_impl           libmpi.so.12.0.5
# 54   162:MPIDI_CH3_Progress_wait           libmpi.so.12.0.5
# 55         220:psm_progress_wait           libmpi.so.12.0.5
# 56       232:<unknown procedure>  libpsm_infinipath.so.1.14
# 57           <unknown procedure>  libpsm_infinipath.so.1.14
# 58           <unknown procedure>  libpsm_infinipath.so.1.14
# 59           <unknown procedure>  libpsm_infinipath.so.1.14
# 60           <unknown procedure>  libpsm_infinipath.so.1.14
# 61           <unknown procedure>  libpsm_infinipath.so.1.14
# 62           <unknown procedure>       libinfinipath.so.4.0
# 63              <unknown file>:0                      Unkno

# %%
def update_df(df, column, idx_column, idx_of, new_val):
    print(df.loc[df[idx_column] == idx_of][column])
    df.loc[df[idx_column] == idx_of][column] = new_val
    print(df[column])

# %%
def update_vals(row, data):
    row[column] = data
    return row

df.apply(update_vals, axis=1)
# Out:
# ----------------------------------------
# TypeErrorTraceback (most recent call last)
# <ipython-input-72-5263684b71f8> in <module>
#       3     return row
#       4
# ----> 5 df.apply(update_vals, axis=1)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6485                          args=args,
#    6486                          kwds=kwds)
# -> 6487         return op.get_result()
#    6488
#    6489     def applymap(self, func):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/apply.py in get_result(self)
#     149             return self.apply_raw()
#     150
# --> 151         return self.apply_standard()
#     152
#     153     def apply_empty_result(self):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/apply.py in apply_standard(self)
#     255
#     256         # compute the result using the series generator
# --> 257         self.apply_series_generator()
#     258
#     259         # wrap results
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/apply.py in apply_series_generator(self)
#     284             try:
#     285                 for i, v in enumerate(series_gen):
# --> 286                     results[i] = self.f(v)
#     287                     keys.append(v.name)
#     288             except Exception as e:
#
# TypeError: ("update_vals() missing 1 required positional argument: 'data'", 'occurred at index 0')

# %%
update_df(states[name].df, 'module', 'name', 'main', 'main_program')
# Out:
# 2    osu_bw
# 3    osu_bw
# Name: module, dtype: object
# 0           libmonitor.so.0.0.0
# 1           libmonitor.so.0.0.0
# 2                        osu_bw
# 3                        osu_bw
# 4           libmonitor.so.0.0.0
# 5           libmonitor.so.0.0.0
# 6              libmpi.so.12.0.5
# 7              libmpi.so.12.0.5
# 8              libmpi.so.12.0.5
# 9              libmpi.so.12.0.5
# 10             libmpi.so.12.0.5
# 11             libmpi.so.12.0.5
# 12             libmpi.so.12.0.5
# 13             libmpi.so.12.0.5
# 14    libpsm_infinipath.so.1.14
# 15    libpsm_infinipath.so.1.14
# 16    libpsm_infinipath.so.1.14
# 17    libpsm_infinipath.so.1.14
# 18    libpsm_infinipath.so.1.14
# 19    libpsm_infinipath.so.1.14
# 20    libpsm_infinipath.so.1.14
# 21    libpsm_infinipath.so.1.14
# 22                        Unkno
# 23                        Unkno
# 24                        Unkno
# 25                        Unkno
# 26                        Unkno
# 27             libmpi.so.12.0.5
# 28             libmpi.so.12.0.5
# 29             libmpi.so.12.0.5
# 30    libpsm_infinipath.so.1.14
# 31    libpsm_infinipath.so.1.14
# 32    libpsm_infinipath.so.1.14
# 33    libpsm_infinipath.so.1.14
# 34    libpsm_infinipath.so.1.14
# 35    libpsm_infinipath.so.1.14
# 36    libpsm_infinipath.so.1.14
# 37         libinfinipath.so.4.0
# 38                        Unkno
# 39             libmpi.so.12.0.5
# 40             libmpi.so.12.0.5
# 41    libpsm_infinipath.so.1.14
# 42    libpsm_infinipath.so.1.14
# 43    libpsm_infinipath.so.1.14
# 44    libpsm_infinipath.so.1.14
# 45    libpsm_infinipath.so.1.14
# 46    libpsm_infinipath.so.1.14
# 47    libpsm_infinipath.so.1.14
# 48    libpsm_infinipath.so.1.14
# 49         libinfinipath.so.4.0
# 50                        Unkno
# 51                        Unkno
# 52             libmpi.so.12.0.5
# 53             libmpi.so.12.0.5
# 54             libmpi.so.12.0.5
# 55             libmpi.so.12.0.5
# 56    libpsm_infinipath.so.1.14
# 57    libpsm_infinipath.so.1.14
# 58    libpsm_infinipath.so.1.14
# 59    libpsm_infinipath.so.1.14
# 60    libpsm_infinipath.so.1.14
# 61    libpsm_infinipath.so.1.14
# 62         libinfinipath.so.4.0
# 63                        Unkno
# Name: module, dtype: object
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
class groupBy:
    def __init__(self, state, group_by):
        self.state = state
        self.df = self.state.df
        self.group_by = group_by
#         self.eliminate_funcs = ['libmonitor.so.0.0.0']
        self.eliminate_funcs = []
        self.module_func_map = {}
        self.drop_eliminate_funcs()
        self.run()
        
    # Drop all entries user does not want to see. 
    def drop_eliminate_funcs(self):
        for idx, func in enumerate(self.eliminate_funcs):
            self.state.df = self.state.df[self.state.df['module'] != func]
            
    def update_df(self, column, idx_of, new_value):
        print

    # Create a group path for the df.column = group_path.
    def create_group_path(self, path):
        group_path = []
        temp = None
        function = path[-1]        
        module_idx = 0
        change_name = False
        
        for i, elem in enumerate(path):
            grouping = self.state.lookup_with_nodeName(elem)[self.group_by].unique()
            if len(grouping) == 0:
                break
            
            module = grouping[0]
            
            # Add the function to the module map.
            if module not in self.module_func_map:
                self.module_func_map[module] = []
            self.module_func_map[module].append(function)
            
            # Append the module into the group path. 
            if module not in self.eliminate_funcs:
                if temp == None or module != temp:
                    # Append "_" + module_idx if the module exists in the group_path. 
                    if module in group_path:
                        module_idx += 1
                        module = module + '_' + str(module_idx)
                        self.update_df('module', function, module)
                        
                    group_path.append(module)
                    temp = module
        
        group_path = tuple(group_path)
        return (group_path, change_name)

    def create_component_path(self, path, group_path):
        component_path = []
        path = list(path)
        component_module = lookup_with_name(self.state.df, path[-1])[self.group_by].tolist()[0]
        component_path.append(component_module)
        filter_path = [node for node in path if component_module == \
                       lookup_with_name(self.state.df, node)[self.group_by].tolist()[0]]
        for i, elem in enumerate(filter_path):            
             component_path.append(elem)                    
        return tuple(component_path)

    def create_component_level(self, component_path):
        return len(component_path) - 1
            
    def run(self):
        group_path = {}
        component_path = {}
        component_level = {}
        entry_func = {}
        show_node = {}
        node_name = {}    
        module = {}
        change_name = {}
    
        roots = self.state.graph.roots
        if len(roots) > 1:
            print('It is a multi-rooted tree with {0} roots'.format(len(roots)))
        
        for root in roots:
            node_gen = root.traverse()       
            rootdf = lookup_with_name(self.state.df, root.callpath[-1])
            
            if rootdf.empty:
                utils.debug('Not accounting the function: {0}'.format(root))
            # Check if the dataframe exists for the root node. 
            # It might be a function that is eliminated. 
            else: 
                utils.debug('Function: {0}'.format(root))
                temp_group_path_results = self.create_group_path(root.callpath)
                group_path[rootdf.node[0]] = temp_group_path_results[0]
                change_name[rootdf.node[0]] = temp_group_path_results[1]
                node_name[rootdf.node[0]] = lookup_with_node(self.df, root)['module'][0]
                module[rootdf.node[0]] = group_path[rootdf.node[0]][-1]
                entry_func[rootdf.node[0]] = True
                show_node[rootdf.node[0]] = True
                count = 0
            root = next(node_gen)

            try:
                while root.callpath != None:
                    root = next(node_gen)
                    t = lookup_with_name(self.df, root.callpath[-1])
                    parents = root.parents 
                    
                    for idx, parent in enumerate(parents):
                        s = lookup_with_name(self.df, parent.callpath[-1])
                    
                        if s.empty:
                            print("Not considering the Source function {0} [{1}]".format(parent, s['module']))
                        elif t.empty:
                            print("Not considering the Target function {0} [{1}]".format(root, t['path']))
                        elif not s.empty and not t.empty:
                            snode = s.node.tolist()[0]
                            tnode = t.node.tolist()[0]

                            spath = root.callpath
                            tpath = parent.callpath

                            tmodule = t[self.group_by].tolist()[0]
                                                
                            temp_group_path_results = self.create_group_path(tpath)
                            group_path[tnode] = temp_group_path_results[0]
                            change_name[tnode] = temp_group_path_results[1]
                            component_path[tnode] = self.create_component_path(tpath, group_path[tnode])
                            component_level[tnode] = len(component_path[tnode]) - 1
                            module[tnode] = group_path[tnode][-1]
                            
                            if component_level[tnode] == 2:
                                entry_func[tnode] = True
                            else:
                                entry_func[tnode] = False
                                
                            if component_level[tnode] == 1 or change_name[tnode] == True:
                                node_name[tnode] = component_path[tnode][0]
                                show_node[tnode] = True
                            else:
                                node_name[tnode] = "none"
                                show_node[tnode] = False
                            
#                     print("entry function:", entry_func[tnode])
#                     print('Change name:', change_name[tnode])
                    print("node path: ", tpath)                
                    print("group path: ", group_path[tnode])
                    print("component path: ", component_path[tnode])
#                     print("component level: ", component_level[tnode])
#                     print("Show node: ", show_node[tnode])
#                     print("name: ", node_name[tnode])
                
            except StopIteration:
                pass
            finally:
                del root

        self.state.update_df('group_path', group_path)
        self.state.update_df('component_path', component_path)
        self.state.update_df('show_node', entry_func)
        self.state.update_df('vis_node_name', node_name)
        self.state.update_df('component_level', component_level)
#         self.state.update_df('module', module)
        self.state.update_df('change_name', change_name)

# %%
group = groupBy(states[name], 'module')
g_df = group.state.df
g_graph = group.state.graph
# Out:
#  CallFlow:   [callfow.py] Function: <program root>
# node path:  ('<program root>',)
# group path:  ('libmonitor.so.0.0.0',)
# component path:  ('libmonitor.so.0.0.0', '<program root>')
# node path:  ('<program root>', 'main')
# group path:  ('libmonitor.so.0.0.0', 'osu_bw')
# component path:  ('osu_bw', 'main')
# node path:  ('<program root>', 'main', 'Loop@osu_bw.c:134')
# group path:  ('libmonitor.so.0.0.0', 'osu_bw', 'Unkno')
# component path:  ('Unkno', 'Loop@osu_bw.c:134')
# node path:  ('<program root>', 'main', 'Loop@osu_bw.c:134', '140:PMPI_Waitall')
# group path:  ('libmonitor.so.0.0.0', 'osu_bw', 'Unkno', 'libmpi.so.12.0.5')
# component path:  ('libmpi.so.12.0.5', '140:PMPI_Waitall')
# node path:  ('<program root>', 'main', 'Loop@osu_bw.c:134', '140:PMPI_Waitall', '309:MPIR_Waitall_impl')
# group path:  ('libmonitor.so.0.0.0', 'osu_bw', 'Unkno', 'libmpi.so.12.0.5')
# component path:  ('libmpi.so.12.0.5', '140:PMPI_Waitall', '309:MPIR_Waitall_impl')
# node path:  ('<program root>', 'main', 'Loop@osu_bw.c:134', '140:PMPI_Waitall', '309:MPIR_Waitall_impl', '162:MPIDI_CH3_Progress_wait')
# group path:  ('libmonitor.so.0.0.0', 'osu_bw', 'Unkno', 'libmpi.so.12.0.5')
# component path:  ('libmpi.so.12.0.5', '140:PMPI_Waitall', '309:MPIR_Waitall_impl', '162:MPIDI_CH3_Progress_wait')
# node path:  ('<program root>', 'main', 'Loop@osu_bw.c:134', '140:PMPI_Waitall', '309:MPIR_Waitall_impl', '162:MPIDI_CH3_Progress_wait', '220:psm_progress_wait')
# group path:  ('libmonitor.so.0.0.0', 'osu_bw', 'Unkno', 'libmpi.so.12.0.5')
# component path:  ('libmpi.so.12.0.5', '140:PMPI_Waitall', '309:MPIR_Waitall_impl', '162:MPIDI_CH3_Progress_wait', '220:psm_progress_wait')
# node path:  ('<program root>', 'main', 'Loop@osu_bw.c:134', '140:PMPI_Waitall', '309:MPIR_Waitall_impl', '162:MPIDI_CH3_Progress_wait', '220:psm_progress_wait', '232:<unknown procedure>')
# group path:  ('libmonitor.so.0.0.0', 'osu_bw', 'Unkno', 'libmpi.so.12.0.5', 'libpsm_infinipath.so.1.14')
# component path:  ('libpsm_infinipath.so.1.14', '232:<unknown procedure>')
# node path:  ('<program root>', 'main', 'Loop@osu_bw.c:134', '140:PMPI_Waitall', '309:MPIR_Waitall_impl', '162:MPIDI_CH3_Progress_wait', '220:psm_progress_wait', '232:<unknown procedure>', '<unknown procedure>')
# group path:  ('libmonitor.so.0.0.0', 'osu_bw', 'Unkno', 'libmpi.so.12.0.5', 'libpsm_infinipath.so.1.14')
# component path:  ('libpsm_infinipath.so.1.14', '232:<unknown procedure>', '<unknown procedure>')
# node path:  ('<program root>', 'main', 'Loop@osu_bw.c:134', '140:PMPI_Waitall', '309:MPIR_Waitall_impl', '162:MPIDI_CH3_Progress_wait', '220:psm_progress_wait', '232:<unknown procedure>', '<unknown procedure>', '<unknown procedure>')
# group path:  ('libmonitor.so.0.0.0', 'osu_bw', 'Unkno', 'libmpi.so.12.0.5', 'libpsm_infinipath.so.1.14')
# component path:  ('libpsm_infinipath.so.1.14', '232:<unknown procedure>', '<unknown procedure>', '<unknown procedure>')
# node path:  ('<program root>', 'main', 'Loop@osu_bw.c:134', '140:PMPI_Waitall', '309:MPIR_Waitall_impl', '162:MPIDI_CH3_Progress_wait', '220:psm_progress_wait', '232:<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>')
# group path:  ('libmonitor.so.0.0.0', 'osu_bw', 'Unkno', 'libmpi.so.12.0.5', 'libpsm_infinipath.so.1.14')
# component path:  ('libpsm_infinipath.so.1.14', '232:<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>')
# node path:  ('<program root>', 'main', 'Loop@osu_bw.c:134', '140:PMPI_Waitall', '309:MPIR_Waitall_impl', '162:MPIDI_CH3_Progress_wait', '220:psm_progress_wait', '232:<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>')
# group path:  ('libmonitor.so.0.0.0', 'osu_bw', 'Unkno', 'libmpi.so.12.0.5', 'libpsm_infinipath.so.1.14')
# component path:  ('libpsm_infinipath.so.1.14', '232:<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>')
# node path:  ('<program root>', 'main', 'Loop@osu_bw.c:134', '140:PMPI_Waitall', '309:MPIR_Waitall_impl', '162:MPIDI_CH3_Progress_wait', '220:psm_progress_wait', '232:<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>')
# group path:  ('libmonitor.so.0.0.0', 'osu_bw', 'Unkno', 'libmpi.so.12.0.5', 'libpsm_infinipath.so.1.14')
# component path:  ('libpsm_infinipath.so.1.14', '232:<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>')
# node path:  ('<program root>', 'main', 'Loop@osu_bw.c:134', '140:PMPI_Waitall', '309:MPIR_Waitall_impl', '162:MPIDI_CH3_Progress_wait', '220:psm_progress_wait', '232:<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>')
# group path:  ('libmonitor.so.0.0.0', 'osu_bw', 'Unkno', 'libmpi.so.12.0.5', 'libpsm_infinipath.so.1.14')
# component path:  ('libpsm_infinipath.so.1.14', '232:<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>')
# node path:  ('<program root>', 'main')
# group path:  ('libmonitor.so.0.0.0', 'osu_bw')
# component path:  ('osu_bw', 'main')
# node path:  ('<program root>', 'main', '157:MPI_Finalize')
# group path:  ('libmonitor.so.0.0.0', 'osu_bw', 'libmonitor.so.0.0.0_1')
# component path:  ('libmonitor.so.0.0.0', '<program root>', '157:MPI_Finalize')
# node path:  ('<program root>', 'main', '157:MPI_Finalize', 'PMPI_Finalize')
# group path:  ('libmonitor.so.0.0.0', 'osu_bw', 'libmonitor.so.0.0.0_1', 'libmpi.so.12.0.5')
# component path:  ('libmpi.so.12.0.5', 'PMPI_Finalize')
# node path:  ('<program root>', 'main', '157:MPI_Finalize', 'PMPI_Finalize', '294:MPID_Finalize')
# group path:  ('libmonitor.so.0.0.0', 'osu_bw', 'libmonitor.so.0.0.0_1', 'libmpi.so.12.0.5')
# component path:  ('libmpi.so.12.0.5', 'PMPI_Finalize', '294:MPID_Finalize')
# node path:  ('<program root>', 'main', '157:MPI_Finalize', 'PMPI_Finalize', '294:MPID_Finalize', '162:MPIDI_CH3_Finalize')
# group path:  ('libmonitor.so.0.0.0', 'osu_bw', 'libmonitor.so.0.0.0_1', 'libmpi.so.12.0.5')
# component path:  ('libmpi.so.12.0.5', 'PMPI_Finalize', '294:MPID_Finalize', '162:MPIDI_CH3_Finalize')
# node path:  ('<program root>', 'main', '157:MPI_Finalize', 'PMPI_Finalize', '294:MPID_Finalize', '162:MPIDI_CH3_Finalize', '230:psm_dofinalize')
# group path:  ('libmonitor.so.0.0.0', 'osu_bw', 'libmonitor.so.0.0.0_1', 'libmpi.so.12.0.5')
# component path:  ('libmpi.so.12.0.5', 'PMPI_Finalize', '294:MPID_Finalize', '162:MPIDI_CH3_Finalize', '230:psm_dofinalize')
# node path:  ('<program root>', 'main', '157:MPI_Finalize', 'PMPI_Finalize', '294:MPID_Finalize', '162:MPIDI_CH3_Finalize', '230:psm_dofinalize', '36:<unknown procedure>')
# group path:  ('libmonitor.so.0.0.0', 'osu_bw', 'libmonitor.so.0.0.0_1', 'libmpi.so.12.0.5', 'libpsm_infinipath.so.1.14')
# component path:  ('libpsm_infinipath.so.1.14', '36:<unknown procedure>')
# node path:  ('<program root>', 'main', '157:MPI_Finalize', 'PMPI_Finalize', '294:MPID_Finalize', '162:MPIDI_CH3_Finalize', '230:psm_dofinalize', '36:<unknown procedure>', '<unknown procedure>')
# group path:  ('libmonitor.so.0.0.0', 'osu_bw', 'libmonitor.so.0.0.0_1', 'libmpi.so.12.0.5', 'libpsm_infinipath.so.1.14')
# component path:  ('libpsm_infinipath.so.1.14', '36:<unknown procedure>', '<unknown procedure>')
# node path:  ('<program root>', 'main', '157:MPI_Finalize', 'PMPI_Finalize', '294:MPID_Finalize', '162:MPIDI_CH3_Finalize', '230:psm_dofinalize', '36:<unknown procedure>', '<unknown procedure>', '<unknown procedure>')
# group path:  ('libmonitor.so.0.0.0', 'osu_bw', 'libmonitor.so.0.0.0_1', 'libmpi.so.12.0.5', 'libpsm_infinipath.so.1.14')
# component path:  ('libpsm_infinipath.so.1.14', '36:<unknown procedure>', '<unknown procedure>', '<unknown procedure>')
# node path:  ('<program root>', 'main', '157:MPI_Finalize', 'PMPI_Finalize', '294:MPID_Finalize', '162:MPIDI_CH3_Finalize', '230:psm_dofinalize', '36:<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>')
# group path:  ('libmonitor.so.0.0.0', 'osu_bw', 'libmonitor.so.0.0.0_1', 'libmpi.so.12.0.5', 'libpsm_infinipath.so.1.14')
# component path:  ('libpsm_infinipath.so.1.14', '36:<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>')
# node path:  ('<program root>', 'main', '157:MPI_Finalize', 'PMPI_Finalize', '294:MPID_Finalize', '162:MPIDI_CH3_Finalize', '230:psm_dofinalize', '36:<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>')
# group path:  ('libmonitor.so.0.0.0', 'osu_bw', 'libmonitor.so.0.0.0_1', 'libmpi.so.12.0.5', 'libpsm_infinipath.so.1.14')
# component path:  ('libpsm_infinipath.so.1.14', '36:<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>')
# node path:  ('<program root>', 'main')
# group path:  ('libmonitor.so.0.0.0', 'osu_bw')
# component path:  ('osu_bw', 'main')
# node path:  ('<program root>', 'main', 'Loop@osu_bw.c:112')
# group path:  ('libmonitor.so.0.0.0', 'osu_bw', 'Unkno')
# component path:  ('Unkno', 'Loop@osu_bw.c:112')
# node path:  ('<program root>', 'main', 'Loop@osu_bw.c:112', '122:PMPI_Waitall')
# group path:  ('libmonitor.so.0.0.0', 'osu_bw', 'Unkno', 'libmpi.so.12.0.5')
# component path:  ('libmpi.so.12.0.5', '122:PMPI_Waitall')
# node path:  ('<program root>', 'main', 'Loop@osu_bw.c:112', '122:PMPI_Waitall', '309:MPIR_Waitall_impl')
# group path:  ('libmonitor.so.0.0.0', 'osu_bw', 'Unkno', 'libmpi.so.12.0.5')
# component path:  ('libmpi.so.12.0.5', '122:PMPI_Waitall', '309:MPIR_Waitall_impl')
# node path:  ('<program root>', 'main', 'Loop@osu_bw.c:112', '122:PMPI_Waitall', '309:MPIR_Waitall_impl', '145:MPIDI_CH3_Progress_start')
# group path:  ('libmonitor.so.0.0.0', 'osu_bw', 'Unkno', 'libmpi.so.12.0.5')
# component path:  ('libmpi.so.12.0.5', '122:PMPI_Waitall', '309:MPIR_Waitall_impl', '145:MPIDI_CH3_Progress_start')
# node path:  ('<program root>', 'main', 'Loop@osu_bw.c:112', '122:PMPI_Waitall', '309:MPIR_Waitall_impl', '145:MPIDI_CH3_Progress_start', '189:<unknown procedure>')
# group path:  ('libmonitor.so.0.0.0', 'osu_bw', 'Unkno', 'libmpi.so.12.0.5', 'libpsm_infinipath.so.1.14')
# component path:  ('libpsm_infinipath.so.1.14', '189:<unknown procedure>')
# node path:  ('<program root>', 'main', 'Loop@osu_bw.c:112', '122:PMPI_Waitall', '309:MPIR_Waitall_impl', '145:MPIDI_CH3_Progress_start', '189:<unknown procedure>', '<unknown procedure>')
# group path:  ('libmonitor.so.0.0.0', 'osu_bw', 'Unkno', 'libmpi.so.12.0.5', 'libpsm_infinipath.so.1.14')
# component path:  ('libpsm_infinipath.so.1.14', '189:<unknown procedure>', '<unknown procedure>')
# node path:  ('<program root>', 'main', 'Loop@osu_bw.c:112', '122:PMPI_Waitall', '309:MPIR_Waitall_impl', '145:MPIDI_CH3_Progress_start', '189:<unknown procedure>', '<unknown procedure>', '<unknown procedure>')
# group path:  ('libmonitor.so.0.0.0', 'osu_bw', 'Unkno', 'libmpi.so.12.0.5', 'libpsm_infinipath.so.1.14')
# component path:  ('libpsm_infinipath.so.1.14', '189:<unknown procedure>', '<unknown procedure>', '<unknown procedure>')
# node path:  ('<program root>', 'main', 'Loop@osu_bw.c:112', '122:PMPI_Waitall', '309:MPIR_Waitall_impl', '145:MPIDI_CH3_Progress_start', '189:<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>')
# group path:  ('libmonitor.so.0.0.0', 'osu_bw', 'Unkno', 'libmpi.so.12.0.5', 'libpsm_infinipath.so.1.14')
# component path:  ('libpsm_infinipath.so.1.14', '189:<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>')
# node path:  ('<program root>', 'main', 'Loop@osu_bw.c:112', '122:PMPI_Waitall', '309:MPIR_Waitall_impl', '145:MPIDI_CH3_Progress_start', '189:<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>')
# group path:  ('libmonitor.so.0.0.0', 'osu_bw', 'Unkno', 'libmpi.so.12.0.5', 'libpsm_infinipath.so.1.14')
# component path:  ('libpsm_infinipath.so.1.14', '189:<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>')
# node path:  ('<program root>', 'main', 'Loop@osu_bw.c:112', '122:PMPI_Waitall', '309:MPIR_Waitall_impl', '145:MPIDI_CH3_Progress_start', '189:<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>')
# group path:  ('libmonitor.so.0.0.0', 'osu_bw', 'Unkno', 'libmpi.so.12.0.5', 'libpsm_infinipath.so.1.14')
# component path:  ('libpsm_infinipath.so.1.14', '189:<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>')
# node path:  ('<program root>', 'main', 'Loop@osu_bw.c:112', '122:PMPI_Waitall', '309:MPIR_Waitall_impl', '145:MPIDI_CH3_Progress_start', '189:<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>')
# group path:  ('libmonitor.so.0.0.0', 'osu_bw', 'Unkno', 'libmpi.so.12.0.5', 'libpsm_infinipath.so.1.14')
# component path:  ('libpsm_infinipath.so.1.14', '189:<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>')
# node path:  ('<program root>', 'main', 'Loop@osu_bw.c:112', '122:PMPI_Waitall', '309:MPIR_Waitall_impl', '145:MPIDI_CH3_Progress_start', '189:<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>')
# group path:  ('libmonitor.so.0.0.0', 'osu_bw', 'Unkno', 'libmpi.so.12.0.5', 'libpsm_infinipath.so.1.14')
# component path:  ('libpsm_infinipath.so.1.14', '189:<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>')
# node path:  ('<program root>', 'main', 'Loop@osu_bw.c:112', '122:PMPI_Waitall', '309:MPIR_Waitall_impl')
# group path:  ('libmonitor.so.0.0.0', 'osu_bw', 'Unkno', 'libmpi.so.12.0.5')
# component path:  ('libmpi.so.12.0.5', '122:PMPI_Waitall', '309:MPIR_Waitall_impl')
# node path:  ('<program root>', 'main', 'Loop@osu_bw.c:112', '122:PMPI_Waitall', '309:MPIR_Waitall_impl', '162:MPIDI_CH3_Progress_wait')
# group path:  ('libmonitor.so.0.0.0', 'osu_bw', 'Unkno', 'libmpi.so.12.0.5')
# component path:  ('libmpi.so.12.0.5', '122:PMPI_Waitall', '309:MPIR_Waitall_impl', '162:MPIDI_CH3_Progress_wait')
# node path:  ('<program root>', 'main', 'Loop@osu_bw.c:112', '122:PMPI_Waitall', '309:MPIR_Waitall_impl', '162:MPIDI_CH3_Progress_wait', '220:psm_progress_wait')
# group path:  ('libmonitor.so.0.0.0', 'osu_bw', 'Unkno', 'libmpi.so.12.0.5')
# component path:  ('libmpi.so.12.0.5', '122:PMPI_Waitall', '309:MPIR_Waitall_impl', '162:MPIDI_CH3_Progress_wait', '220:psm_progress_wait')
# node path:  ('<program root>', 'main', 'Loop@osu_bw.c:112', '122:PMPI_Waitall', '309:MPIR_Waitall_impl', '162:MPIDI_CH3_Progress_wait', '220:psm_progress_wait', '232:<unknown procedure>')
# group path:  ('libmonitor.so.0.0.0', 'osu_bw', 'Unkno', 'libmpi.so.12.0.5', 'libpsm_infinipath.so.1.14')
# component path:  ('libpsm_infinipath.so.1.14', '232:<unknown procedure>')
# node path:  ('<program root>', 'main', 'Loop@osu_bw.c:112', '122:PMPI_Waitall', '309:MPIR_Waitall_impl', '162:MPIDI_CH3_Progress_wait', '220:psm_progress_wait', '232:<unknown procedure>', '<unknown procedure>')
# group path:  ('libmonitor.so.0.0.0', 'osu_bw', 'Unkno', 'libmpi.so.12.0.5', 'libpsm_infinipath.so.1.14')
# component path:  ('libpsm_infinipath.so.1.14', '232:<unknown procedure>', '<unknown procedure>')
# node path:  ('<program root>', 'main', 'Loop@osu_bw.c:112', '122:PMPI_Waitall', '309:MPIR_Waitall_impl', '162:MPIDI_CH3_Progress_wait', '220:psm_progress_wait', '232:<unknown procedure>', '<unknown procedure>', '<unknown procedure>')
# group path:  ('libmonitor.so.0.0.0', 'osu_bw', 'Unkno', 'libmpi.so.12.0.5', 'libpsm_infinipath.so.1.14')
# component path:  ('libpsm_infinipath.so.1.14', '232:<unknown procedure>', '<unknown procedure>', '<unknown procedure>')
# node path:  ('<program root>', 'main', 'Loop@osu_bw.c:112', '122:PMPI_Waitall', '309:MPIR_Waitall_impl', '162:MPIDI_CH3_Progress_wait', '220:psm_progress_wait', '232:<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>')
# group path:  ('libmonitor.so.0.0.0', 'osu_bw', 'Unkno', 'libmpi.so.12.0.5', 'libpsm_infinipath.so.1.14')
# component path:  ('libpsm_infinipath.so.1.14', '232:<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>')
# node path:  ('<program root>', 'main', 'Loop@osu_bw.c:112', '122:PMPI_Waitall', '309:MPIR_Waitall_impl', '162:MPIDI_CH3_Progress_wait', '220:psm_progress_wait', '232:<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>')
# group path:  ('libmonitor.so.0.0.0', 'osu_bw', 'Unkno', 'libmpi.so.12.0.5', 'libpsm_infinipath.so.1.14')
# component path:  ('libpsm_infinipath.so.1.14', '232:<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>')
# node path:  ('<program root>', 'main', 'Loop@osu_bw.c:112', '122:PMPI_Waitall', '309:MPIR_Waitall_impl', '162:MPIDI_CH3_Progress_wait', '220:psm_progress_wait', '232:<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>')
# group path:  ('libmonitor.so.0.0.0', 'osu_bw', 'Unkno', 'libmpi.so.12.0.5', 'libpsm_infinipath.so.1.14')
# component path:  ('libpsm_infinipath.so.1.14', '232:<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>')
# node path:  ('<program root>', 'main', 'Loop@osu_bw.c:112', '122:PMPI_Waitall', '309:MPIR_Waitall_impl', '162:MPIDI_CH3_Progress_wait', '220:psm_progress_wait', '232:<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>')
# group path:  ('libmonitor.so.0.0.0', 'osu_bw', 'Unkno', 'libmpi.so.12.0.5', 'libpsm_infinipath.so.1.14')
# component path:  ('libpsm_infinipath.so.1.14', '232:<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>')
# node path:  ('<program root>', 'main', 'Loop@osu_bw.c:112', '122:PMPI_Waitall', '309:MPIR_Waitall_impl', '162:MPIDI_CH3_Progress_wait', '220:psm_progress_wait', '232:<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>')
# group path:  ('libmonitor.so.0.0.0', 'osu_bw', 'Unkno', 'libmpi.so.12.0.5', 'libpsm_infinipath.so.1.14')
# component path:  ('libpsm_infinipath.so.1.14', '232:<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>')
# node path:  ('<program root>', 'main', 'Loop@osu_bw.c:112', '122:PMPI_Waitall', '309:MPIR_Waitall_impl', '162:MPIDI_CH3_Progress_wait', '220:psm_progress_wait', '232:<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>')
# group path:  ('libmonitor.so.0.0.0', 'osu_bw', 'Unkno', 'libmpi.so.12.0.5', 'libpsm_infinipath.so.1.14')
# component path:  ('libpsm_infinipath.so.1.14', '232:<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>')

# %%
for idx, row in g_df.iterrows():
    print(row['name'], row['path'], row['component_path'])
# Out:
# <program root> ('<program root>',) ('osu_bw', 'main')
# <program root> ('<program root>',) ('osu_bw', 'main')
# main ('<program root>', 'main') ('Unkno', 'Loop@osu_bw.c:112')
# main ('<program root>', 'main') ('Unkno', 'Loop@osu_bw.c:112')
# 157:MPI_Finalize ('<program root>', 'main', 'Loop@osu_bw.c:112', 'Loop@osu_bw.c:134', '157:MPI_Finalize') ('libmpi.so.12.0.5', 'PMPI_Finalize')
# 157:MPI_Finalize ('<program root>', 'main', 'Loop@osu_bw.c:112', 'Loop@osu_bw.c:134', '157:MPI_Finalize') ('libmpi.so.12.0.5', 'PMPI_Finalize')
# PMPI_Finalize ('<program root>', 'main', 'Loop@osu_bw.c:112', 'Loop@osu_bw.c:134', '157:MPI_Finalize', 'PMPI_Finalize') ('libmpi.so.12.0.5', 'PMPI_Finalize', '294:MPID_Finalize')
# PMPI_Finalize ('<program root>', 'main', 'Loop@osu_bw.c:112', 'Loop@osu_bw.c:134', '157:MPI_Finalize', 'PMPI_Finalize') ('libmpi.so.12.0.5', 'PMPI_Finalize', '294:MPID_Finalize')
# 294:MPID_Finalize ('<program root>', 'main', 'Loop@osu_bw.c:112', 'Loop@osu_bw.c:134', '157:MPI_Finalize', 'PMPI_Finalize', '294:MPID_Finalize') ('libmpi.so.12.0.5', 'PMPI_Finalize', '294:MPID_Finalize', '162:MPIDI_CH3_Finalize')
# 294:MPID_Finalize ('<program root>', 'main', 'Loop@osu_bw.c:112', 'Loop@osu_bw.c:134', '157:MPI_Finalize', 'PMPI_Finalize', '294:MPID_Finalize') ('libmpi.so.12.0.5', 'PMPI_Finalize', '294:MPID_Finalize', '162:MPIDI_CH3_Finalize')
# 162:MPIDI_CH3_Finalize ('<program root>', 'main', 'Loop@osu_bw.c:112', 'Loop@osu_bw.c:134', '157:MPI_Finalize', 'PMPI_Finalize', '294:MPID_Finalize', '162:MPIDI_CH3_Finalize') ('libmpi.so.12.0.5', 'PMPI_Finalize', '294:MPID_Finalize', '162:MPIDI_CH3_Finalize', '230:psm_dofinalize')
# 162:MPIDI_CH3_Finalize ('<program root>', 'main', 'Loop@osu_bw.c:112', 'Loop@osu_bw.c:134', '157:MPI_Finalize', 'PMPI_Finalize', '294:MPID_Finalize', '162:MPIDI_CH3_Finalize') ('libmpi.so.12.0.5', 'PMPI_Finalize', '294:MPID_Finalize', '162:MPIDI_CH3_Finalize', '230:psm_dofinalize')
# 230:psm_dofinalize ('<program root>', 'main', 'Loop@osu_bw.c:112', 'Loop@osu_bw.c:134', '157:MPI_Finalize', 'PMPI_Finalize', '294:MPID_Finalize', '162:MPIDI_CH3_Finalize', '230:psm_dofinalize') ('libpsm_infinipath.so.1.14', '36:<unknown procedure>')
# 230:psm_dofinalize ('<program root>', 'main', 'Loop@osu_bw.c:112', 'Loop@osu_bw.c:134', '157:MPI_Finalize', 'PMPI_Finalize', '294:MPID_Finalize', '162:MPIDI_CH3_Finalize', '230:psm_dofinalize') ('libpsm_infinipath.so.1.14', '36:<unknown procedure>')
# 36:<unknown procedure> ('<program root>', 'main', 'Loop@osu_bw.c:112', 'Loop@osu_bw.c:134', '157:MPI_Finalize', 'PMPI_Finalize', '294:MPID_Finalize', '162:MPIDI_CH3_Finalize', '230:psm_dofinalize', '36:<unknown procedure>') ('libpsm_infinipath.so.1.14', '36:<unknown procedure>', '<unknown procedure>')
# 36:<unknown procedure> ('<program root>', 'main', 'Loop@osu_bw.c:112', 'Loop@osu_bw.c:134', '157:MPI_Finalize', 'PMPI_Finalize', '294:MPID_Finalize', '162:MPIDI_CH3_Finalize', '230:psm_dofinalize', '36:<unknown procedure>') ('libpsm_infinipath.so.1.14', '36:<unknown procedure>', '<unknown procedure>')
# <unknown procedure> ('<program root>', 'main', 'Loop@osu_bw.c:112', 'Loop@osu_bw.c:134', '157:MPI_Finalize', 'PMPI_Finalize', '294:MPID_Finalize', '162:MPIDI_CH3_Finalize', '230:psm_dofinalize', '36:<unknown procedure>', '<unknown procedure>') ('Unkno', 'Loop@osu_bw.c:112', '<unknown file>:0')
# <unknown procedure> ('<program root>', 'main', 'Loop@osu_bw.c:112', 'Loop@osu_bw.c:134', '157:MPI_Finalize', 'PMPI_Finalize', '294:MPID_Finalize', '162:MPIDI_CH3_Finalize', '230:psm_dofinalize', '36:<unknown procedure>', '<unknown procedure>') ('Unkno', 'Loop@osu_bw.c:112', '<unknown file>:0')
# <unknown procedure> ('<program root>', 'main', 'Loop@osu_bw.c:112', 'Loop@osu_bw.c:134', '157:MPI_Finalize', 'PMPI_Finalize', '294:MPID_Finalize', '162:MPIDI_CH3_Finalize', '230:psm_dofinalize', '36:<unknown procedure>', '<unknown procedure>', '<unknown procedure>') ('Unkno', 'Loop@osu_bw.c:112', '<unknown file>:0')
# <unknown procedure> ('<program root>', 'main', 'Loop@osu_bw.c:112', 'Loop@osu_bw.c:134', '157:MPI_Finalize', 'PMPI_Finalize', '294:MPID_Finalize', '162:MPIDI_CH3_Finalize', '230:psm_dofinalize', '36:<unknown procedure>', '<unknown procedure>', '<unknown procedure>') ('Unkno', 'Loop@osu_bw.c:112', '<unknown file>:0')
# <unknown procedure> ('<program root>', 'main', 'Loop@osu_bw.c:112', 'Loop@osu_bw.c:134', '157:MPI_Finalize', 'PMPI_Finalize', '294:MPID_Finalize', '162:MPIDI_CH3_Finalize', '230:psm_dofinalize', '36:<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>') ('Unkno', 'Loop@osu_bw.c:112', '<unknown file>:0')
# <unknown procedure> ('<program root>', 'main', 'Loop@osu_bw.c:112', 'Loop@osu_bw.c:134', '157:MPI_Finalize', 'PMPI_Finalize', '294:MPID_Finalize', '162:MPIDI_CH3_Finalize', '230:psm_dofinalize', '36:<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>') ('Unkno', 'Loop@osu_bw.c:112', '<unknown file>:0')
# <unknown file>:0 ('<program root>', 'main', 'Loop@osu_bw.c:112', 'Loop@osu_bw.c:134', '157:MPI_Finalize', 'PMPI_Finalize', '294:MPID_Finalize', '162:MPIDI_CH3_Finalize', '230:psm_dofinalize', '36:<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown file>:0')
# <unknown file>:0 ('<program root>', 'main', 'Loop@osu_bw.c:112', 'Loop@osu_bw.c:134', '157:MPI_Finalize', 'PMPI_Finalize', '294:MPID_Finalize', '162:MPIDI_CH3_Finalize', '230:psm_dofinalize', '36:<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown file>:0')
# <unknown file>:0 ('<program root>', 'main', 'Loop@osu_bw.c:112', 'Loop@osu_bw.c:134', '157:MPI_Finalize', 'PMPI_Finalize', '294:MPID_Finalize', '162:MPIDI_CH3_Finalize', '230:psm_dofinalize', '36:<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown file>:0')
# <unknown file>:0 ('<program root>', 'main', 'Loop@osu_bw.c:112', 'Loop@osu_bw.c:134', '157:MPI_Finalize', 'PMPI_Finalize', '294:MPID_Finalize', '162:MPIDI_CH3_Finalize', '230:psm_dofinalize', '36:<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown file>:0')
# Loop@osu_bw.c:112 ('<program root>', 'main', 'Loop@osu_bw.c:112') ('libmpi.so.12.0.5', '122:PMPI_Waitall')
# 122:PMPI_Waitall ('<program root>', 'main', 'Loop@osu_bw.c:112', '122:PMPI_Waitall') ('libmpi.so.12.0.5', '122:PMPI_Waitall', '309:MPIR_Waitall_impl')
# 309:MPIR_Waitall_impl ('<program root>', 'main', 'Loop@osu_bw.c:112', '122:PMPI_Waitall', '309:MPIR_Waitall_impl') ('libmpi.so.12.0.5', '122:PMPI_Waitall', '309:MPIR_Waitall_impl', '162:MPIDI_CH3_Progress_wait')
# 145:MPIDI_CH3_Progress_start ('<program root>', 'main', 'Loop@osu_bw.c:112', '122:PMPI_Waitall', '309:MPIR_Waitall_impl', '145:MPIDI_CH3_Progress_start') ('libpsm_infinipath.so.1.14', '189:<unknown procedure>')
# 189:<unknown procedure> ('<program root>', 'main', 'Loop@osu_bw.c:112', '122:PMPI_Waitall', '309:MPIR_Waitall_impl', '145:MPIDI_CH3_Progress_start', '189:<unknown procedure>') ('libpsm_infinipath.so.1.14', '189:<unknown procedure>', '<unknown procedure>')
# <unknown procedure> ('<program root>', 'main', 'Loop@osu_bw.c:112', '122:PMPI_Waitall', '309:MPIR_Waitall_impl', '145:MPIDI_CH3_Progress_start', '189:<unknown procedure>', '<unknown procedure>') ('Unkno', 'Loop@osu_bw.c:112', '<unknown file>:0')
# <unknown procedure> ('<program root>', 'main', 'Loop@osu_bw.c:112', '122:PMPI_Waitall', '309:MPIR_Waitall_impl', '145:MPIDI_CH3_Progress_start', '189:<unknown procedure>', '<unknown procedure>', '<unknown procedure>') ('Unkno', 'Loop@osu_bw.c:112', '<unknown file>:0')
# <unknown procedure> ('<program root>', 'main', 'Loop@osu_bw.c:112', '122:PMPI_Waitall', '309:MPIR_Waitall_impl', '145:MPIDI_CH3_Progress_start', '189:<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>') ('Unkno', 'Loop@osu_bw.c:112', '<unknown file>:0')
# <unknown procedure> ('<program root>', 'main', 'Loop@osu_bw.c:112', '122:PMPI_Waitall', '309:MPIR_Waitall_impl', '145:MPIDI_CH3_Progress_start', '189:<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>') ('Unkno', 'Loop@osu_bw.c:112', '<unknown file>:0')
# <unknown procedure> ('<program root>', 'main', 'Loop@osu_bw.c:112', '122:PMPI_Waitall', '309:MPIR_Waitall_impl', '145:MPIDI_CH3_Progress_start', '189:<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>') ('Unkno', 'Loop@osu_bw.c:112', '<unknown file>:0')
# <unknown procedure> ('<program root>', 'main', 'Loop@osu_bw.c:112', '122:PMPI_Waitall', '309:MPIR_Waitall_impl', '145:MPIDI_CH3_Progress_start', '189:<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>') ('Unkno', 'Loop@osu_bw.c:112', '<unknown file>:0')
# <unknown procedure> ('<program root>', 'main', 'Loop@osu_bw.c:112', '122:PMPI_Waitall', '309:MPIR_Waitall_impl', '145:MPIDI_CH3_Progress_start', '189:<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>') ('Unkno', 'Loop@osu_bw.c:112', '<unknown file>:0')
# <unknown file>:0 ('<program root>', 'main', 'Loop@osu_bw.c:112', '122:PMPI_Waitall', '309:MPIR_Waitall_impl', '145:MPIDI_CH3_Progress_start', '189:<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown file>:0')
# 162:MPIDI_CH3_Progress_wait ('<program root>', 'main', 'Loop@osu_bw.c:112', '122:PMPI_Waitall', '309:MPIR_Waitall_impl', '162:MPIDI_CH3_Progress_wait') ('libmpi.so.12.0.5', '122:PMPI_Waitall', '309:MPIR_Waitall_impl', '162:MPIDI_CH3_Progress_wait', '220:psm_progress_wait')
# 220:psm_progress_wait ('<program root>', 'main', 'Loop@osu_bw.c:112', '122:PMPI_Waitall', '309:MPIR_Waitall_impl', '162:MPIDI_CH3_Progress_wait', '220:psm_progress_wait') ('libpsm_infinipath.so.1.14', '232:<unknown procedure>')
# 232:<unknown procedure> ('<program root>', 'main', 'Loop@osu_bw.c:112', '122:PMPI_Waitall', '309:MPIR_Waitall_impl', '162:MPIDI_CH3_Progress_wait', '220:psm_progress_wait', '232:<unknown procedure>') ('libpsm_infinipath.so.1.14', '232:<unknown procedure>', '<unknown procedure>')
# <unknown procedure> ('<program root>', 'main', 'Loop@osu_bw.c:112', '122:PMPI_Waitall', '309:MPIR_Waitall_impl', '162:MPIDI_CH3_Progress_wait', '220:psm_progress_wait', '232:<unknown procedure>', '<unknown procedure>') ('Unkno', 'Loop@osu_bw.c:112', '<unknown file>:0')
# <unknown procedure> ('<program root>', 'main', 'Loop@osu_bw.c:112', '122:PMPI_Waitall', '309:MPIR_Waitall_impl', '162:MPIDI_CH3_Progress_wait', '220:psm_progress_wait', '232:<unknown procedure>', '<unknown procedure>', '<unknown procedure>') ('Unkno', 'Loop@osu_bw.c:112', '<unknown file>:0')
# <unknown procedure> ('<program root>', 'main', 'Loop@osu_bw.c:112', '122:PMPI_Waitall', '309:MPIR_Waitall_impl', '162:MPIDI_CH3_Progress_wait', '220:psm_progress_wait', '232:<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>') ('Unkno', 'Loop@osu_bw.c:112', '<unknown file>:0')
# <unknown procedure> ('<program root>', 'main', 'Loop@osu_bw.c:112', '122:PMPI_Waitall', '309:MPIR_Waitall_impl', '162:MPIDI_CH3_Progress_wait', '220:psm_progress_wait', '232:<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>') ('Unkno', 'Loop@osu_bw.c:112', '<unknown file>:0')
# <unknown procedure> ('<program root>', 'main', 'Loop@osu_bw.c:112', '122:PMPI_Waitall', '309:MPIR_Waitall_impl', '162:MPIDI_CH3_Progress_wait', '220:psm_progress_wait', '232:<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>') ('Unkno', 'Loop@osu_bw.c:112', '<unknown file>:0')
# <unknown procedure> ('<program root>', 'main', 'Loop@osu_bw.c:112', '122:PMPI_Waitall', '309:MPIR_Waitall_impl', '162:MPIDI_CH3_Progress_wait', '220:psm_progress_wait', '232:<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>') ('Unkno', 'Loop@osu_bw.c:112', '<unknown file>:0')
# <unknown procedure> ('<program root>', 'main', 'Loop@osu_bw.c:112', '122:PMPI_Waitall', '309:MPIR_Waitall_impl', '162:MPIDI_CH3_Progress_wait', '220:psm_progress_wait', '232:<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>') ('Unkno', 'Loop@osu_bw.c:112', '<unknown file>:0')
# <unknown procedure> ('<program root>', 'main', 'Loop@osu_bw.c:112', '122:PMPI_Waitall', '309:MPIR_Waitall_impl', '162:MPIDI_CH3_Progress_wait', '220:psm_progress_wait', '232:<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>') ('Unkno', 'Loop@osu_bw.c:112', '<unknown file>:0')
# <unknown file>:0 ('<program root>', 'main', 'Loop@osu_bw.c:112', '122:PMPI_Waitall', '309:MPIR_Waitall_impl', '162:MPIDI_CH3_Progress_wait', '220:psm_progress_wait', '232:<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown file>:0')
# Loop@osu_bw.c:134 ('<program root>', 'main', 'Loop@osu_bw.c:112', 'Loop@osu_bw.c:134') ('libmpi.so.12.0.5', '140:PMPI_Waitall')
# 140:PMPI_Waitall ('<program root>', 'main', 'Loop@osu_bw.c:112', 'Loop@osu_bw.c:134', '140:PMPI_Waitall') ('libmpi.so.12.0.5', '140:PMPI_Waitall', '309:MPIR_Waitall_impl')
# 309:MPIR_Waitall_impl ('<program root>', 'main', 'Loop@osu_bw.c:112', 'Loop@osu_bw.c:134', '140:PMPI_Waitall', '309:MPIR_Waitall_impl') ('libmpi.so.12.0.5', '122:PMPI_Waitall', '309:MPIR_Waitall_impl', '162:MPIDI_CH3_Progress_wait')
# 162:MPIDI_CH3_Progress_wait ('<program root>', 'main', 'Loop@osu_bw.c:112', 'Loop@osu_bw.c:134', '140:PMPI_Waitall', '309:MPIR_Waitall_impl', '162:MPIDI_CH3_Progress_wait') ('libmpi.so.12.0.5', '122:PMPI_Waitall', '309:MPIR_Waitall_impl', '162:MPIDI_CH3_Progress_wait', '220:psm_progress_wait')
# 220:psm_progress_wait ('<program root>', 'main', 'Loop@osu_bw.c:112', 'Loop@osu_bw.c:134', '140:PMPI_Waitall', '309:MPIR_Waitall_impl', '162:MPIDI_CH3_Progress_wait', '220:psm_progress_wait') ('libpsm_infinipath.so.1.14', '232:<unknown procedure>')
# 232:<unknown procedure> ('<program root>', 'main', 'Loop@osu_bw.c:112', 'Loop@osu_bw.c:134', '140:PMPI_Waitall', '309:MPIR_Waitall_impl', '162:MPIDI_CH3_Progress_wait', '220:psm_progress_wait', '232:<unknown procedure>') ('libpsm_infinipath.so.1.14', '232:<unknown procedure>', '<unknown procedure>')
# <unknown procedure> ('<program root>', 'main', 'Loop@osu_bw.c:112', 'Loop@osu_bw.c:134', '140:PMPI_Waitall', '309:MPIR_Waitall_impl', '162:MPIDI_CH3_Progress_wait', '220:psm_progress_wait', '232:<unknown procedure>', '<unknown procedure>') ('Unkno', 'Loop@osu_bw.c:112', '<unknown file>:0')
# <unknown procedure> ('<program root>', 'main', 'Loop@osu_bw.c:112', 'Loop@osu_bw.c:134', '140:PMPI_Waitall', '309:MPIR_Waitall_impl', '162:MPIDI_CH3_Progress_wait', '220:psm_progress_wait', '232:<unknown procedure>', '<unknown procedure>', '<unknown procedure>') ('Unkno', 'Loop@osu_bw.c:112', '<unknown file>:0')
# <unknown procedure> ('<program root>', 'main', 'Loop@osu_bw.c:112', 'Loop@osu_bw.c:134', '140:PMPI_Waitall', '309:MPIR_Waitall_impl', '162:MPIDI_CH3_Progress_wait', '220:psm_progress_wait', '232:<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>') ('Unkno', 'Loop@osu_bw.c:112', '<unknown file>:0')
# <unknown procedure> ('<program root>', 'main', 'Loop@osu_bw.c:112', 'Loop@osu_bw.c:134', '140:PMPI_Waitall', '309:MPIR_Waitall_impl', '162:MPIDI_CH3_Progress_wait', '220:psm_progress_wait', '232:<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>') ('Unkno', 'Loop@osu_bw.c:112', '<unknown file>:0')
# <unknown procedure> ('<program root>', 'main', 'Loop@osu_bw.c:112', 'Loop@osu_bw.c:134', '140:PMPI_Waitall', '309:MPIR_Waitall_impl', '162:MPIDI_CH3_Progress_wait', '220:psm_progress_wait', '232:<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>') ('Unkno', 'Loop@osu_bw.c:112', '<unknown file>:0')
# <unknown procedure> ('<program root>', 'main', 'Loop@osu_bw.c:112', 'Loop@osu_bw.c:134', '140:PMPI_Waitall', '309:MPIR_Waitall_impl', '162:MPIDI_CH3_Progress_wait', '220:psm_progress_wait', '232:<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>') ('Unkno', 'Loop@osu_bw.c:112', '<unknown file>:0')
# <unknown file>:0 ('<program root>', 'main', 'Loop@osu_bw.c:112', 'Loop@osu_bw.c:134', '140:PMPI_Waitall', '309:MPIR_Waitall_impl', '162:MPIDI_CH3_Progress_wait', '220:psm_progress_wait', '232:<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown procedure>', '<unknown file>:0')

# %%
print(g_df[['name', 'module', 'change_name']])
print(g_df.columns)
# Out:
#                             name                     module change_name
# 0                 <program root>                     osu_bw       False
# 1                 <program root>                     osu_bw       False
# 2                           main                      Unkno       False
# 3                           main                      Unkno       False
# 4               157:MPI_Finalize           libmpi.so.12.0.5        True
# 5               157:MPI_Finalize           libmpi.so.12.0.5        True
# 6                  PMPI_Finalize           libmpi.so.12.0.5        True
# 7                  PMPI_Finalize           libmpi.so.12.0.5        True
# 8              294:MPID_Finalize           libmpi.so.12.0.5        True
# 9              294:MPID_Finalize           libmpi.so.12.0.5        True
# 10        162:MPIDI_CH3_Finalize           libmpi.so.12.0.5        True
# 11        162:MPIDI_CH3_Finalize           libmpi.so.12.0.5        True
# 12            230:psm_dofinalize  libpsm_infinipath.so.1.14        True
# 13            230:psm_dofinalize  libpsm_infinipath.so.1.14        True
# 14        36:<unknown procedure>  libpsm_infinipath.so.1.14        True
# 15        36:<unknown procedure>  libpsm_infinipath.so.1.14        True
# 16           <unknown procedure>                    Unkno_1        True
# 17           <unknown procedure>                    Unkno_1        True
# 18           <unknown procedure>                    Unkno_1        True
# 19           <unknown procedure>                    Unkno_1        True
# 20           <unknown procedure>                    Unkno_1        True
# 21           <unknown procedure>                    Unkno_1        True
# 22              <unknown file>:0
# 23              <unknown file>:0
# 24              <unknown file>:0
# 25              <unknown file>:0
# 26             Loop@osu_bw.c:112           libmpi.so.12.0.5       False
# 27              122:PMPI_Waitall           libmpi.so.12.0.5       False
# 28         309:MPIR_Waitall_impl           libmpi.so.12.0.5       False
# 29  145:MPIDI_CH3_Progress_start  libpsm_infinipath.so.1.14       False
# 30       189:<unknown procedure>  libpsm_infinipath.so.1.14       False
# 31           <unknown procedure>                    Unkno_1        True
# 32           <unknown procedure>                    Unkno_1        True
# 33           <unknown procedure>                    Unkno_1        True
# 34           <unknown procedure>                    Unkno_1        True
# 35           <unknown procedure>                    Unkno_1        True
# 36           <unknown procedure>                    Unkno_1        True
# 37           <unknown procedure>                    Unkno_1        True
# 38              <unknown file>:0
# 39   162:MPIDI_CH3_Progress_wait           libmpi.so.12.0.5       False
# 40         220:psm_progress_wait  libpsm_infinipath.so.1.14       False
# 41       232:<unknown procedure>  libpsm_infinipath.so.1.14       False
# 42           <unknown procedure>                    Unkno_1        True
# 43           <unknown procedure>                    Unkno_1        True
# 44           <unknown procedure>                    Unkno_1        True
# 45           <unknown procedure>                    Unkno_1        True
# 46           <unknown procedure>                    Unkno_1        True
# 47           <unknown procedure>                    Unkno_1        True
# 48           <unknown procedure>                    Unkno_1        True
# 49           <unknown procedure>                    Unkno_1        True
# 50              <unknown file>:0
# 51             Loop@osu_bw.c:134           libmpi.so.12.0.5       False
# 52              140:PMPI_Waitall           libmpi.so.12.0.5       False
# 53         309:MPIR_Waitall_impl           libmpi.so.12.0.5       False
# 54   162:MPIDI_CH3_Progress_wait           libmpi.so.12.0.5       False
# 55         220:psm_progress_wait  libpsm_infinipath.so.1.14       False
# 56       232:<unknown procedure>  libpsm_infinipath.so.1.14       False
# 57           <unknown procedure>                    Unkno_1        True
# 58           <unknown procedure>                    Unkno_1        True
# 59           <unknown procedure>                    Unkno_1        True
# 60           <unknown procedure>                    Unkno_1        True
# 61           <unknown procedure>                    Unkno_1        True
# 62           <unknown procedure>                    Unkno_1        True
# 63              <unknown file>:0
# Index(['node', 'rank', 'time (inc)', 'time', 'nid', 'rank.1', 'file', 'line',
#        'module', 'name', 'node.1', 'type', 'df_index', 'n_index', 'mod_index',
#        'callees', 'callers', 'show_node', 'vis_node_name', 'max_incTime',
#        'avg_incTime', 'imbalance_perc', 'path', 'group_path', 'component_path',
#        'component_level', 'change_name'],
#       dtype='object')

# %% [markdown]
# # A more generic graph.

# %%
class Action():
    __metaclass__ = ABCMeta
     
    def __init__(self):
        pass
    
    def dfs(self, graph, limit):
        self.level = 0
        
        def dfs_recurse(root):
            for node in root.children:
                if(self.level < limit):
                    print("Node : ", node)
                    self.level += 1
                    dfs_recurse(node)
        
        for root in graph.roots:
            dfs_recurse(root)

    def create_group_path(self, node):
        group_path = []
        temp = None
        path = node.callpath
        for i, elem in enumerate(path):
            elem_df = self.state.lookup_with_nodeName(elem)
            if(elem_df.empty):
                grouping = 'Unkno'
            else:
                grouping = elem_df[self.group_by].tolist()[0]
            if temp == None or grouping != temp:
                group_path.append(grouping)
                temp = grouping
        return tuple(group_path)

    def find_a_good_node_name(self, node):
        node_name = self.state.lookup_with_node(node)[self.group_by].tolist()[0]
        return node_name

    def create_component_path(self, path, group_path):
        component_path = []
        path = list(path)
        component_module = self.state.lookup_with_nodeName(path[-1])[self.group_by].tolist()[0]
        component_path.append(component_module)

        filter_path = [node for node in path if component_module == self.state.lookup_with_nodeName(node)[self.group_by].tolist()[0]]
       
        for i, elem in enumerate(filter_path):            
             component_path.append(elem)                    
        return tuple(component_path)

    def create_component_level(self, component_path):
        return len(component_path) - 1

    # Assign a "Module" name to a given hatchet node. 
    def give_module_name(self, node):
        # start = time.time()
        df = self.state.lookup_with_nodeName(node.callpath[-1])
        unique_modules = df[self.group_by].unique()
        if(len(unique_modules) == 1):
            return unique_modules[0]
        elif(len(unique_modules) == 0): 
            # print('Entry not found in dataframe')
            return 'Unkno'
        else:
            print('Error! Multiple modules for a node.')
            return None

    @abstractmethod
    def run():
        pass
# Out:
# ----------------------------------------
# NameErrorTraceback (most recent call last)
# <ipython-input-18-ea8eb096368c> in <module>
# ----> 1 class Action():
#       2     __metaclass__ = ABCMeta
#       3
#       4     def __init__(self):
#       5         pass
#
# <ipython-input-18-ea8eb096368c> in Action()
#       1 class Action():
# ----> 2     __metaclass__ = ABCMeta
#       3
#       4     def __init__(self):
#       5         pass
#
# NameError: name 'ABCMeta' is not defined

# %%
class groupGraph(Graph):
    """ A group node in the call graph.
    """
    def __init__(self):
        self.nodes = []
        self.edges = []
        # Map to check if such element exist in the graph. 
        self.nodeMap = {}
        self.roots = []
    
    def is_module(self, node_name):
        for idx, module in enumerate(self.nodes):
            if(node_name == module.callpath[-1]):
                return True
        return False

    def add_module(self, module):
        assert isinstance(module, Node)
        self.nodes.append(module)
        self.nodeMap[module.callpath[-1]] = module

    def add_inner_node(self, module_name, inner_node):
        assert isinstance(inner_node, Node)
        group_node = self.nodeMap[module_name]
        self.nodeMap[module_name] = inner_node
        group_node.hierarchy.append(inner_node)

    def print(self):
        print("Nodes: ", self.nodes)
        for idx, node in enumerate(self.nodes):
            print("Node name: {0}, \n hierarchy: {1}".format(node.name, node.hierarchy))
    def split_by_entry_function(self):
        return 

    def split_by_caller_function(self):
        return

    def get_hierarchy():
        return

    def split_level(self):
        return

# %%
class groupNode(Node):
    def __init__(self, nid, name, callpath_tuple, source):
        self.nid = nid
        self.name = name
        self.callpath = callpath_tuple
        self.parents = []
        
        if source is not None:
            self.add_parent(source)
        self.children = []
        self.entry_funcs = []
        self.caller_funcs = []
        self.hierarchy = []

    def add_parent(self, node):
        self.parents.append(node)

    def add_child(self, node):
        assert isinstance(node, groupNode)
        self.children.append(node)

    def add_entry_funcs(self, node):
        assert isinstance(node, Node)
        self.entry_funcs.append(node)

    def __str__(self):
        """ Returns a string representation of the node.
        """
        return '[Node] name: {0}, number_of_parents: {1}, number_of_children: {2}, entry_funcs: {3}'.format(self.callpath, len(self.parents), len(self.children), len(self.entry_funcs))

# %%
class groupBy(Action):
    def __init__(self, state, group_by):
        self.state = state
        self.graph = state.graph
        self.df = state.df
        self.entire_df = state.entire_df
        self.group_by = group_by
        self.node_count = 0
        self.empty_node = Node(-1, (), None)
        self.nodeModuleMap = self.find_mapping_from_df()
        print(self.nodeModuleMap.keys())
        self.run()

    def find_mapping_from_df(self):
        fns = self.df['name'].unique()
        nodeModuleMap = {}
        for idx, fn in enumerate(fns):
            fn_hatchet = self.df[self.df['name'] == fn]['node'].unique()[0]
            nodeModuleMap[fn] = self.df[self.df['name'] == fn]['module'].unique()
        return nodeModuleMap
        
    def add_node(self, source, target, is_root=False):
        count = self.node_count
        
        target_name = target.callpath[-1]
        target_module_name = self.give_module_name(target)
        target_callpath = self.create_group_path(target)
        if (source == self.empty_node):
            pass
        else:
            source_name = source.callpath[-1]
            source_module_name = self.give_module_name(source)
            source_callpath = self.create_group_path(source)

            print(source_callpath, target_callpath)
        # hatchet_hash = self.state.lookup_with_node(node.callpath[-1])['node'].unique()

 
        if(is_root):
            source_module_name = None
            source_callpath = None
            group_node = groupNode(count, target_module_name, source_callpath, source_module_name)
            self.group_graph.roots.append(group_node)
            
        else:
            if(self.group_graph.is_module(target_module_name)):
                self.group_graph.add_inner_node(target_module_name, target)
            else:
                if(len(self.group_graph.nodes) == 0):
                    source_module = None
                else:
                    source_module = self.nodeModuleMap[source_name]
                    group_node = groupNode(count, target_module_name, target_callpath, source_module_name)
            self.group_graph.add_module(target)
        
    def run(self):         
        roots = self.graph.roots
        # New roots of the grouped graph.
        new_roots = []
        self.group_graph = groupGraph()
        
        for root in roots:
            level = 0
            node_gen = root.traverse()  
            self.add_node(self.empty_node, root, True)
#             print(self.group_graph.nodeMap)

            try:
                while root.callpath != None:
                    source = root
                    target = next(node_gen)
                    self.add_node(source, target, False)
                    # self.add_edge(target, source)
                    root = target

            except StopIteration:
                pass
            finally:
                del root

        self.group_graph.print()

        group_roots = self.group_graph.roots
        print(self.group_graph.nodeMap)
#         for root in group_roots:
#             group_node_gen = root.traverse()
#             print(root.callpath)
#             try:
#                 while root.callpath != None:
#                     source = root
#                     target = next(group_node_gen)
#                     print(source, target)
#             except StopIteration:
#                 pass
#             finally: 
#                 del root

# %%
groupBy(states[name], 'module')

# %%
state = states[name]
print(state.df[state.df['name'] == "Loop@<unknown file> [kripke]:0"])

# %%
state = states[name]
fns = state.entire_df['name'].unique()
nodeModuleMap = {}
for idx, fn in enumerate(fns):
    fn_hatchet = state.entire_df[state.entire_df['name'] == fn]['node'].unique()[0]
    nodeModuleMap[fn_hatchet] = state.df[state.df['name'] == fn]['module'].unique()
print(nodeModuleMap)
