# %%
import pandas as pd
import numpy as np
import json
from hatchet import *
import pprint
import sys

# %%
def read_file(jsonfile):
  f = open(jsonfile, 'r')
  path = json.loads(f.read())['path']
  return path

# %%
def create_gf(paths, file_format):
  ret = []
  for i in range(0, len(paths)):
    gf = GraphFrame()
    if file_format == 'hpctoolkit':
      gf.from_hpctoolkit(paths[i])
    elif file_format == 'caliper':
      gf.from_caliper(paths[i])
    ret.append(gf)
  return ret

# %%
def getFileNames(gf):
    ret = []
    file_df = gf.dataframe.groupby('file')
    for key in file_df:
        ret.append(key[0])
    return ret

# %%
 def run(self, gfs):
    ret = {}
    graphID = 0

# %%
def aggregate(df):
    print df.values, type(df.keys)
    print type(df)

# %%
def metrics(df):
    metrics = {}
    print df[['name']], len(df[['name']])
    for key in list(df):
        metrics[key] = []
    for key in list(df):
        for procs in range(0,len(df[['name']])):
            metrics[key].append(df[key][0])
    return metrics

# %%
def node_lookup(gf, node):
    df = gf.dataframe
    return df.loc[df['node'] == node][['name','CPUTIME (usec) (I)']]

# %%
url_path = "/Users/kesavan1/Suraj/llnl/CallFlow/calc-pi.json"
data_paths = read_file(url_path)

# %%
pp = pprint.PrettyPrinter(indent=4)

# %%
for gf in gfs:
    root = gf.graph.roots[0]
    node_gen = gf.graph.roots[0].traverse()
    while root != None:
        root = next(node_gen)
        print root, node_lookup(gf, root)
# Out:
# <hatchet.node.Node instance at 0x10e06fb90>                                                             name  \
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e06fb90> 0     <program root>
#                                             1     <program root>
#                                             2     <program root>
#
#                                                   CPUTIME (usec) (I)
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e06fb90> 0               999238.0
#                                             1              1000306.0
#                                             2               999308.0
# <hatchet.node.Node instance at 0x10e06fd88>                                                   name  CPUTIME (usec) (I)
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e06fd88> 0     main            999238.0
#                                             1     main           1000306.0
#                                             2     main            999308.0
# <hatchet.node.Node instance at 0x10e06fab8>                                                       name  CPUTIME (usec) (I)
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e06fab8> 0     MPI_Init                 0.0
#                                             1     MPI_Init                 0.0
#                                             2     MPI_Init                 0.0
# <hatchet.node.Node instance at 0x10e061ea8>                                                        name  \
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e061ea8> 0     PMPI_Init
#                                             1     PMPI_Init
#                                             2     PMPI_Init
#
#                                                   CPUTIME (usec) (I)
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e061ea8> 0                    0.0
#                                             1                    0.0
#                                             2                    0.0
# <hatchet.node.Node instance at 0x10e061d88>                                                               name  \
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e061d88> 0     MPIR_Init_thread
#                                             1     MPIR_Init_thread
#                                             2     MPIR_Init_thread
#
#                                                   CPUTIME (usec) (I)
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e061d88> 0                    0.0
#                                             1                    0.0
#                                             2                    0.0
# <hatchet.node.Node instance at 0x10e0d3050>                                                        name  \
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e0d3050> 0     MPID_Init
#                                             1     MPID_Init
#                                             2     MPID_Init
#
#                                                   CPUTIME (usec) (I)
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e0d3050> 0                    0.0
#                                             1                    0.0
#                                             2                    0.0
# <hatchet.node.Node instance at 0x10e056488>                                                             name  \
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e056488> 0     MPIDI_CH3_Init
#                                             1     MPIDI_CH3_Init
#                                             2     MPIDI_CH3_Init
#
#                                                   CPUTIME (usec) (I)
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e056488> 0                    0.0
#                                             1                    0.0
#                                             2                    0.0
# <hatchet.node.Node instance at 0x10e056e60>                                                         name  \
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e056e60> 0     psm_doinit
#                                             1     psm_doinit
#                                             2     psm_doinit
#
#                                                   CPUTIME (usec) (I)
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e056e60> 0                    0.0
#                                             1                    0.0
#                                             2                    0.0
# <hatchet.node.Node instance at 0x10e645e60>                                                                  name  \
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e645e60> 0     <unknown procedure>
#                                             1     <unknown procedure>
#                                             2     <unknown procedure>
#
#                                                   CPUTIME (usec) (I)
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e645e60> 0                    0.0
#                                             1                    0.0
#                                             2                    0.0
# <hatchet.node.Node instance at 0x10e645ab8>                                                                  name  \
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e645ab8> 0     <unknown procedure>
#                                             1     <unknown procedure>
#                                             2     <unknown procedure>
#
#                                                   CPUTIME (usec) (I)
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e645ab8> 0                    0.0
#                                             1                    0.0
#                                             2                    0.0
# <hatchet.node.Node instance at 0x10e645248>                                                                  name  \
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e645248> 0     <unknown procedure>
#                                             1     <unknown procedure>
#                                             2     <unknown procedure>
#
#                                                   CPUTIME (usec) (I)
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e645248> 0                    0.0
#                                             1                    0.0
#                                             2                    0.0
# <hatchet.node.Node instance at 0x10e645830>                                                             name  \
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e645830> 0     pthread_create
#                                             1     pthread_create
#                                             2     pthread_create
#
#                                                   CPUTIME (usec) (I)
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e645830> 0                    0.0
#                                             1                    0.0
#                                             2                    0.0
# <hatchet.node.Node instance at 0x10e135170>                                                                        name  \
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e135170> 0     Stmt1745@<unknown file>:0
#                                             1     Stmt1745@<unknown file>:0
#                                             2     Stmt1745@<unknown file>:0
#
#                                                   CPUTIME (usec) (I)
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e135170> 0                    0.0
#                                             1                    0.0
#                                             2                    0.0
# <hatchet.node.Node instance at 0x10e624e60>                                                           name  \
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e624e60> 0     MPI_Finalize
#                                             1     MPI_Finalize
#                                             2     MPI_Finalize
#
#                                                   CPUTIME (usec) (I)
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e624e60> 0               999238.0
#                                             1              1000306.0
#                                             2               999308.0
# <hatchet.node.Node instance at 0x10e6241b8>                                                            name  \
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e6241b8> 0     PMPI_Finalize
#                                             1     PMPI_Finalize
#                                             2     PMPI_Finalize
#
#                                                   CPUTIME (usec) (I)
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e6241b8> 0               999238.0
#                                             1              1000306.0
#                                             2               999308.0
# <hatchet.node.Node instance at 0x10e624998>                                                            name  \
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e624998> 0     MPID_Finalize
#                                             1     MPID_Finalize
#                                             2     MPID_Finalize
#
#                                                   CPUTIME (usec) (I)
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e624998> 0               999238.0
#                                             1              1000306.0
#                                             2               999308.0
# <hatchet.node.Node instance at 0x10e624f80>                                                                 name  \
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e624f80> 0     MPIDI_CH3_Finalize
#                                             1     MPIDI_CH3_Finalize
#                                             2     MPIDI_CH3_Finalize
#
#                                                   CPUTIME (usec) (I)
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e624f80> 0               999238.0
#                                             1              1000306.0
#                                             2               999308.0
# <hatchet.node.Node instance at 0x10e624ef0>                                                             name  \
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e624ef0> 0     psm_dofinalize
#                                             1     psm_dofinalize
#                                             2     psm_dofinalize
#
#                                                   CPUTIME (usec) (I)
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e624ef0> 0               999238.0
#                                             1              1000306.0
#                                             2               999308.0
# <hatchet.node.Node instance at 0x10e624cf8>                                                                  name  \
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e624cf8> 0     <unknown procedure>
#                                             1     <unknown procedure>
#                                             2     <unknown procedure>
#
#                                                   CPUTIME (usec) (I)
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e624cf8> 0               999238.0
#                                             1              1000306.0
#                                             2               999308.0
# <hatchet.node.Node instance at 0x10e624290>                                                                  name  \
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e624290> 0     <unknown procedure>
#                                             1     <unknown procedure>
#                                             2     <unknown procedure>
#
#                                                   CPUTIME (usec) (I)
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e624290> 0               999238.0
#                                             1              1000306.0
#                                             2               999308.0
# <hatchet.node.Node instance at 0x10e624050>                                                                  name  \
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e624050> 0     <unknown procedure>
#                                             1     <unknown procedure>
#                                             2     <unknown procedure>
#
#                                                   CPUTIME (usec) (I)
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e624050> 0               999238.0
#                                             1              1000306.0
#                                             2               999308.0
# <hatchet.node.Node instance at 0x10e6244d0>                                                                  name  \
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e6244d0> 0     <unknown procedure>
#                                             1     <unknown procedure>
#                                             2     <unknown procedure>
#
#                                                   CPUTIME (usec) (I)
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e6244d0> 0               298806.0
#                                             1               317865.0
#                                             2               310812.0
# <hatchet.node.Node instance at 0x10e6249e0>                                                                        name  \
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e6249e0> 0     Stmt1746@<unknown file>:0
#                                             1     Stmt1746@<unknown file>:0
#                                             2     Stmt1746@<unknown file>:0
#
#                                                   CPUTIME (usec) (I)
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e6249e0> 0               298806.0
#                                             1               317865.0
#                                             2               310812.0
# <hatchet.node.Node instance at 0x10e624b90>                                                                  name  \
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e624b90> 0     <unknown procedure>
#                                             1     <unknown procedure>
#                                             2     <unknown procedure>
#
#                                                   CPUTIME (usec) (I)
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e624b90> 0               316840.0
#                                             1               376650.0
#                                             2               377648.0
# <hatchet.node.Node instance at 0x10e624c20>                                                                        name  \
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e624c20> 0     Stmt1747@<unknown file>:0
#                                             1     Stmt1747@<unknown file>:0
#                                             2     Stmt1747@<unknown file>:0
#
#                                                   CPUTIME (usec) (I)
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e624c20> 0               316840.0
#                                             1               376650.0
#                                             2               377648.0
# <hatchet.node.Node instance at 0x10e624758>                                                                  name  \
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e624758> 0     <unknown procedure>
#                                             1     <unknown procedure>
#                                             2     <unknown procedure>
#
#                                                   CPUTIME (usec) (I)
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e624758> 0               305643.0
#                                             1               245830.0
#                                             2               286872.0
# <hatchet.node.Node instance at 0x10e624638>                                                                  name  \
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e624638> 0     <unknown procedure>
#                                             1     <unknown procedure>
#                                             2     <unknown procedure>
#
#                                                   CPUTIME (usec) (I)
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e624638> 0                59960.0
#                                             1                 5996.0
#                                             2                35974.0
# <hatchet.node.Node instance at 0x10e624320>                                                                        name  \
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e624320> 0     Stmt1748@<unknown file>:0
#                                             1     Stmt1748@<unknown file>:0
#                                             2     Stmt1748@<unknown file>:0
#
#                                                   CPUTIME (usec) (I)
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e624320> 0                59960.0
#                                             1                 5996.0
#                                             2                35974.0
# <hatchet.node.Node instance at 0x10e624680>                                                                  name  \
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e624680> 0     <unknown procedure>
#                                             1     <unknown procedure>
#                                             2     <unknown procedure>
#
#                                                   CPUTIME (usec) (I)
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e624680> 0               197718.0
#                                             1               221846.0
#                                             2               173876.0
# <hatchet.node.Node instance at 0x10e624e18>                                                                        name  \
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e624e18> 0     Stmt1749@<unknown file>:0
#                                             1     Stmt1749@<unknown file>:0
#                                             2     Stmt1749@<unknown file>:0
#
#                                                   CPUTIME (usec) (I)
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e624e18> 0               197718.0
#                                             1               221846.0
#                                             2               173876.0
# <hatchet.node.Node instance at 0x10e624bd8>                                                                        name  \
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e624bd8> 0     Stmt1750@<unknown file>:0
#                                             1     Stmt1750@<unknown file>:0
#                                             2     Stmt1750@<unknown file>:0
#
#                                                   CPUTIME (usec) (I)
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e624bd8> 0                47965.0
#                                             1                17988.0
#                                             2                77022.0
# <hatchet.node.Node instance at 0x10e112b90>                                                               name  \
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e112b90> 0     __GI_sched_yield
#                                             1     __GI_sched_yield
#                                             2     __GI_sched_yield
#
#                                                   CPUTIME (usec) (I)
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e112b90> 0                17989.0
#                                             1                    0.0
#                                             2                    0.0
# <hatchet.node.Node instance at 0x10e1120e0>                                                                  name  \
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e1120e0> 0     Stmt1751@interp.c:0
#                                             1     Stmt1751@interp.c:0
#                                             2     Stmt1751@interp.c:0
#
#                                                   CPUTIME (usec) (I)
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e1120e0> 0                17989.0
#                                             1                    0.0
#                                             2                    0.0
# <hatchet.node.Node instance at 0x10e6d6950>                                                                  name  \
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e6d6950> 0     Stmt1752@interp.c:0
#                                             1     Stmt1752@interp.c:0
#                                             2     Stmt1752@interp.c:0
#
#                                                   CPUTIME (usec) (I)
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e6d6950> 0                59960.0
#                                             1                59961.0
#                                             2                23976.0
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-439-7217e2d63f0c> in <module>()
#       3     node_gen = gf.graph.roots[0].traverse()
#       4     while root != None:
# ----> 5         root = next(node_gen)
#       6         print root, node_lookup(gf, root)
#
# StopIteration:

# %%
for gf in gfs:
    name_df = gf.dataframe.groupby(['module','name'])
    nodes_map = {}
    max_inclusive_time = 0
    max_exclusive_time = 0
    num_pes = 3
    
    for key, item in name_df:
        max_inclusive_time = max(max_inclusive_time, item[['CPUTIME (usec) (I)']].max()[0])

    print max_inclusive_time
    
    print len(name_df.groups)      
    name_df.filter(lambda x: sys.stdout.write(str(x[['CPUTIME (usec) (I)']].max()[0])))
    name_df.filter(lambda x: x[['CPUTIME (usec) (I)']].max()[0] > 0.1*max_inclusive_time)
                   #x[['CPUTIME (usec) (E)']].sum()[0]/num_pes > 0.1*max_inclusive_time)    
    print len(name_df.groups)
# Out:
# 1000306.0
# 24
# 1000306.01000306.00.00.017989.01000306.01000306.00.01000306.00.00.01000306.00.01000306.00.01000306.024

# %%
for gf in gfs:
    # Structure creation
    for key, item in name_df:
        node_key = key[0]
        nodes_map[node_key] = {}
        nodes_map[node_key]["fns"] = []
        print item[['CPUTIME (usec) (E)']].sum()

    for key, item in name_df:
        node_key = key[0]
        metrics_pes = []
        for rank_keys, rank_items in item.groupby(['rank']):
            metrics_pes.append(metrics(rank_items))

        nodes_map[node_key]["fns"].append({
            "fn_name": key[1],
            "metrics": metrics_pes
        })
    #print len(nodes_map[node_key]["fns"])

    nodes = []
    for key, item in nodes_map.iteritems():
        nodes.append({
            'module': key,
            'props': item
        })
# Out:
# CPUTIME (usec) (E)    0.0
# dtype: float64
# CPUTIME (usec) (E)    0.0
# dtype: float64
# CPUTIME (usec) (E)    0.0
# dtype: float64
# CPUTIME (usec) (E)    0.0
# dtype: float64
# CPUTIME (usec) (E)    17989.0
# dtype: float64
# CPUTIME (usec) (E)    2980863.0
# dtype: float64
# CPUTIME (usec) (E)    0.0
# dtype: float64
# CPUTIME (usec) (E)    0.0
# dtype: float64
# CPUTIME (usec) (E)    0.0
# dtype: float64
# CPUTIME (usec) (E)    0.0
# dtype: float64
# CPUTIME (usec) (E)    0.0
# dtype: float64
# CPUTIME (usec) (E)    0.0
# dtype: float64
# CPUTIME (usec) (E)    0.0
# dtype: float64
# CPUTIME (usec) (E)    0.0
# dtype: float64
# CPUTIME (usec) (E)    0.0
# dtype: float64
# CPUTIME (usec) (E)    0.0
# dtype: float64
#                                                             name
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e06fb90> 0     <program root> 1
#                                                             name
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e06fb90> 1     <program root> 1
#                                                             name
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e06fb90> 2     <program root> 1
#                                                           name
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e624e60> 0     MPI_Finalize 1
#                                                           name
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e624e60> 1     MPI_Finalize 1
#                                                           name
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e624e60> 2     MPI_Finalize 1
#                                                       name
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e06fab8> 0     MPI_Init 1
#                                                       name
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e06fab8> 1     MPI_Init 1
#                                                       name
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e06fab8> 2     MPI_Init 1
#                                                             name
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e645830> 0     pthread_create 1
#                                                             name
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e645830> 1     pthread_create 1
#                                                             name
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e645830> 2     pthread_create 1
#                                                               name
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e112b90> 0     __GI_sched_yield 1
#                                                               name
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e112b90> 1     __GI_sched_yield 1
#                                                               name
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e112b90> 2     __GI_sched_yield 1
#                                                                  name
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e645e60> 0     <unknown procedure>
# <hatchet.node.Node instance at 0x10e645ab8> 0     <unknown procedure>
# <hatchet.node.Node instance at 0x10e645248> 0     <unknown procedure>
# <hatchet.node.Node instance at 0x10e624cf8> 0     <unknown procedure>
# <hatchet.node.Node instance at 0x10e624290> 0     <unknown procedure>
# <hatchet.node.Node instance at 0x10e624050> 0     <unknown procedure>
# <hatchet.node.Node instance at 0x10e6244d0> 0     <unknown procedure>
# <hatchet.node.Node instance at 0x10e624b90> 0     <unknown procedure>
# <hatchet.node.Node instance at 0x10e624758> 0     <unknown procedure>
# <hatchet.node.Node instance at 0x10e624638> 0     <unknown procedure>
# <hatchet.node.Node instance at 0x10e624680> 0     <unknown procedure> 11
#                                                                  name
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e645e60> 1     <unknown procedure>
# <hatchet.node.Node instance at 0x10e645ab8> 1     <unknown procedure>
# <hatchet.node.Node instance at 0x10e645248> 1     <unknown procedure>
# <hatchet.node.Node instance at 0x10e624cf8> 1     <unknown procedure>
# <hatchet.node.Node instance at 0x10e624290> 1     <unknown procedure>
# <hatchet.node.Node instance at 0x10e624050> 1     <unknown procedure>
# <hatchet.node.Node instance at 0x10e6244d0> 1     <unknown procedure>
# <hatchet.node.Node instance at 0x10e624b90> 1     <unknown procedure>
# <hatchet.node.Node instance at 0x10e624758> 1     <unknown procedure>
# <hatchet.node.Node instance at 0x10e624638> 1     <unknown procedure>
# <hatchet.node.Node instance at 0x10e624680> 1     <unknown procedure> 11
#                                                                  name
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e645e60> 2     <unknown procedure>
# <hatchet.node.Node instance at 0x10e645ab8> 2     <unknown procedure>
# <hatchet.node.Node instance at 0x10e645248> 2     <unknown procedure>
# <hatchet.node.Node instance at 0x10e624cf8> 2     <unknown procedure>
# <hatchet.node.Node instance at 0x10e624290> 2     <unknown procedure>
# <hatchet.node.Node instance at 0x10e624050> 2     <unknown procedure>
# <hatchet.node.Node instance at 0x10e6244d0> 2     <unknown procedure>
# <hatchet.node.Node instance at 0x10e624b90> 2     <unknown procedure>
# <hatchet.node.Node instance at 0x10e624758> 2     <unknown procedure>
# <hatchet.node.Node instance at 0x10e624638> 2     <unknown procedure>
# <hatchet.node.Node instance at 0x10e624680> 2     <unknown procedure> 11
#                                                                 name
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e624f80> 0     MPIDI_CH3_Finalize 1
#                                                                 name
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e624f80> 1     MPIDI_CH3_Finalize 1
#                                                                 name
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e624f80> 2     MPIDI_CH3_Finalize 1
#                                                             name
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e056488> 0     MPIDI_CH3_Init 1
#                                                             name
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e056488> 1     MPIDI_CH3_Init 1
#                                                             name
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e056488> 2     MPIDI_CH3_Init 1
#                                                            name
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e624998> 0     MPID_Finalize 1
#                                                            name
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e624998> 1     MPID_Finalize 1
#                                                            name
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e624998> 2     MPID_Finalize 1
#                                                        name
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e0d3050> 0     MPID_Init 1
#                                                        name
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e0d3050> 1     MPID_Init 1
#                                                        name
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e0d3050> 2     MPID_Init 1
#                                                               name
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e061d88> 0     MPIR_Init_thread 1
#                                                               name
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e061d88> 1     MPIR_Init_thread 1
#                                                               name
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e061d88> 2     MPIR_Init_thread 1
#                                                            name
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e6241b8> 0     PMPI_Finalize 1
#                                                            name
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e6241b8> 1     PMPI_Finalize 1
#                                                            name
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e6241b8> 2     PMPI_Finalize 1
#                                                        name
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e061ea8> 0     PMPI_Init 1
#                                                        name
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e061ea8> 1     PMPI_Init 1
#                                                        name
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e061ea8> 2     PMPI_Init 1
#                                                             name
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e624ef0> 0     psm_dofinalize 1
#                                                             name
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e624ef0> 1     psm_dofinalize 1
#                                                             name
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e624ef0> 2     psm_dofinalize 1
#                                                         name
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e056e60> 0     psm_doinit 1
#                                                         name
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e056e60> 1     psm_doinit 1
#                                                         name
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e056e60> 2     psm_doinit 1
#                                                   name
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e06fd88> 0     main 1
#                                                   name
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e06fd88> 1     main 1
#                                                   name
# callpath                                    rank
# <hatchet.node.Node instance at 0x10e06fd88> 2     main 1

# %%
getFileNames(gfs[0])
# Out:
# <pandas.core.groupby.groupby.DataFrameGroupBy object at 0x10dbca8d0>
# ['./src/cpi.c', '/tmp/dpkg-mkdeb.gouoc49UG7/src/mvapich/src/build/../src/mpi/init/finalize.c', '/tmp/dpkg-mkdeb.gouoc49UG7/src/mvapich/src/build/../src/mpi/init/init.c', '/tmp/dpkg-mkdeb.gouoc49UG7/src/mvapich/src/build/../src/mpi/init/initthread.c', '/tmp/dpkg-mkdeb.gouoc49UG7/src/mvapich/src/build/../src/mpid/ch3/channels/psm/src/mpidi_calls.c', '/tmp/dpkg-mkdeb.gouoc49UG7/src/mvapich/src/build/../src/mpid/ch3/channels/psm/src/psm_entry.c', '/tmp/dpkg-mkdeb.gouoc49UG7/src/mvapich/src/build/../src/mpid/ch3/channels/psm/src/psm_exit.c', '/tmp/dpkg-mkdeb.gouoc49UG7/src/mvapich/src/build/../src/mpid/ch3/src/mpid_finalize.c', '/tmp/dpkg-mkdeb.gouoc49UG7/src/mvapich/src/build/../src/mpid/ch3/src/mpid_init.c', '<unknown file>', 'interp.c']
