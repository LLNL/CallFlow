# %%
import pandas as pd
import numpy as np
from hatchet import *
from state import State
import os
import json
from abc import ABCMeta, abstractmethod

# %%
name = 'kripke-impi'
dir_name = "/home/vidi/Work/llnl/CallFlow/data/kripke/"

# %%
def replace_str_with_Node(df, graph):
        mapper = {}
        def dfs_recurse(root):
            for node in root.children: 
                mapper[node.callpath[-1]] = Node(node.nid, node.callpath, None)
                dfs_recurse(node)
        for root in graph.roots:
            mapper[root.callpath[-1]] = Node(root.nid, root.callpath, None)
            dfs_recurse(root)
        df['node'] = df['node'].apply(lambda node: mapper[node] if node in mapper else '')
        return df

# %%
def read_gf(name):
        state = State()
        path = dir_name + 'impi'
        df_filepath = path + '/df.csv'
        entire_df_filepath = path + '/entire_df.csv'
        graph_filepath = path + '/graph.json'
        entire_graph_filepath = path + '/entire_graph.json'   

        with open(graph_filepath, 'r') as graphFile:
            data = json.load(graphFile)

        state.gf = GraphFrame()
        state.gf.from_literal(data)

        with open(entire_graph_filepath, 'r') as entire_graphFile:
            entire_data = json.load(entire_graphFile)
            
        state.entire_gf = GraphFrame()
        state.entire_gf.from_literal(entire_data)

        state.df = pd.read_csv(df_filepath)
        state.entire_df = pd.read_csv(entire_df_filepath)

        state.graph = state.gf.graph
        state.entire_graph = state.entire_gf.graph

        state.map = state.node_hash_mapper()

        # Print the module group by information. 
        # print(state.df.groupby(['module']).agg(['mean','count']))

        # replace df['node'] from str to the Node object.
        state.df = replace_str_with_Node(state.df, state.graph)
        state.entire_df = replace_str_with_Node(state.entire_df, state.entire_graph)

        # add path to the dataframes. 
        # state.df['path'] = state.df['node'].apply(lambda node: node.callpath)
        # state.entire_df['path'] = state.entire_df['node'].apply(lambda node: node.callpath if node else [])

        return state

# %%
states = {}
states[name] = read_gf(name)

# %%
class Action():
    __metaclass__ = ABCMeta
     
    def __init__(self):
        pass
    
    def dfs(self, graph, limit):
        self.level = 0
        
        def dfs_recurse(root):
            for node in root.children:
                if(self.level < limit):
                    print("Node : ", node)
                    self.level += 1
                    dfs_recurse(node)
        
        for root in graph.roots:
            dfs_recurse(root)

    def create_group_path(self, node):
        group_path = []
        temp = None
        path = node.callpath
        for i, elem in enumerate(path):
            elem_df = self.state.lookup_with_nodeName(elem)
            if(elem_df.empty):
                grouping = 'Unkno'
            else:
                grouping = elem_df[self.group_by].tolist()[0]
            if temp == None or grouping != temp:
                group_path.append(grouping)
                temp = grouping
        return tuple(group_path)

    def find_a_good_node_name(self, node):
        node_name = self.state.lookup_with_node(node)[self.group_by].tolist()[0]
        return node_name

    def create_component_path(self, path, group_path):
        component_path = []
        path = list(path)
        component_module = self.state.lookup_with_nodeName(path[-1])[self.group_by].tolist()[0]
        component_path.append(component_module)

        filter_path = [node for node in path if component_module == self.state.lookup_with_nodeName(node)[self.group_by].tolist()[0]]
       
        for i, elem in enumerate(filter_path):            
             component_path.append(elem)                    
        return tuple(component_path)

    def create_component_level(self, component_path):
        return len(component_path) - 1

    # Assign a "Module" name to a given hatchet node. 
    def give_module_name(self, node):
        # start = time.time()
        df = self.state.lookup_with_nodeName(node.callpath[-1])
        unique_modules = df[self.group_by].unique()
        if(len(unique_modules) == 1):
            return unique_modules[0]
        elif(len(unique_modules) == 0): 
            # print('Entry not found in dataframe')
            return 'Unkno'
        else:
            print('Error! Multiple modules for a node.')
            return None

    @abstractmethod
    def run():
        pass

# %%
class groupGraph(Graph):
    """ A group node in the call graph.
    """
    def __init__(self):
        self.nodes = []
        self.edges = []
        # Map to check if such element exist in the graph. 
        self.nodeMap = {}
        self.roots = []
    
    def is_module(self, node_name):
        for idx, module in enumerate(self.nodes):
            if(node_name == module.callpath[-1]):
                return True
        return False

    def add_module(self, module):
        assert isinstance(module, Node)
        self.nodes.append(module)
        self.nodeMap[module.callpath[-1]] = module

    def add_inner_node(self, module_name, inner_node):
        assert isinstance(inner_node, Node)
        group_node = self.nodeMap[module_name]
        self.nodeMap[module_name] = inner_node
        group_node.hierarchy.append(inner_node)

    def print(self):
        print("Nodes: ", self.nodes)
        for idx, node in enumerate(self.nodes):
            print("Node name: {0}, \n hierarchy: {1}".format(node.name, node.hierarchy))
    def split_by_entry_function(self):
        return 

    def split_by_caller_function(self):
        return

    def get_hierarchy():
        return

    def split_level(self):
        return

# %%
class groupNode(Node):
    def __init__(self, nid, name, callpath_tuple, source):
        self.nid = nid
        self.name = name
        self.callpath = callpath_tuple
        self.parents = []
        
        if source is not None:
            self.add_parent(source)
        self.children = []
        self.entry_funcs = []
        self.caller_funcs = []
        self.hierarchy = []

    def add_parent(self, node):
        self.parents.append(node)

    def add_child(self, node):
        assert isinstance(node, groupNode)
        self.children.append(node)

    def add_entry_funcs(self, node):
        assert isinstance(node, Node)
        self.entry_funcs.append(node)

    def __str__(self):
        """ Returns a string representation of the node.
        """
        return '[Node] name: {0}, number_of_parents: {1}, number_of_children: {2}, entry_funcs: {3}'.format(self.callpath, len(self.parents), len(self.children), len(self.entry_funcs))

# %%
class groupBy(Action):
    def __init__(self, state, group_by):
        self.state = state
        self.graph = state.graph
        self.df = state.df
        self.entire_df = state.entire_df
        self.group_by = group_by
        self.node_count = 0
        self.empty_node = Node(-1, (), None)
        self.nodeModuleMap = self.find_mapping_from_df()
        print(self.nodeModuleMap.keys())
        self.run()

    def find_mapping_from_df(self):
        fns = self.df['name'].unique()
        nodeModuleMap = {}
        for idx, fn in enumerate(fns):
            fn_hatchet = self.df[self.df['name'] == fn]['node'].unique()[0]
            nodeModuleMap[fn] = self.df[self.df['name'] == fn]['module'].unique()
        return nodeModuleMap
        
    def add_node(self, source, target, is_root=False):
        count = self.node_count
        
        target_name = target.callpath[-1]
        target_module_name = self.give_module_name(target)
        target_callpath = self.create_group_path(target)
        if (source == self.empty_node):
            pass
        else:
            source_name = source.callpath[-1]
            source_module_name = self.give_module_name(source)
            source_callpath = self.create_group_path(source)

            print(source_callpath, target_callpath)
        # hatchet_hash = self.state.lookup_with_node(node.callpath[-1])['node'].unique()

 
        if(is_root):
            source_module_name = None
            source_callpath = None
            group_node = groupNode(count, target_module_name, source_callpath, source_module_name)
            self.group_graph.roots.append(group_node)
            
        else:
            if(self.group_graph.is_module(target_module_name)):
                self.group_graph.add_inner_node(target_module_name, target)
            else:
                if(len(self.group_graph.nodes) == 0):
                    source_module = None
                else:
                    source_module = self.nodeModuleMap[source_name]
                    group_node = groupNode(count, target_module_name, target_callpath, source_module_name)
            self.group_graph.add_module(target)
        
    def run(self):         
        roots = self.graph.roots
        # New roots of the grouped graph.
        new_roots = []
        self.group_graph = groupGraph()
        
        for root in roots:
            level = 0
            node_gen = root.traverse()  
            self.add_node(self.empty_node, root, True)
#             print(self.group_graph.nodeMap)

            try:
                while root.callpath != None:
                    source = root
                    target = next(node_gen)
                    self.add_node(source, target, False)
                    # self.add_edge(target, source)
                    root = target

            except StopIteration:
                pass
            finally:
                del root

        self.group_graph.print()

        group_roots = self.group_graph.roots
        print(self.group_graph.nodeMap)
#         for root in group_roots:
#             group_node_gen = root.traverse()
#             print(root.callpath)
#             try:
#                 while root.callpath != None:
#                     source = root
#                     target = next(group_node_gen)
#                     print(source, target)
#             except StopIteration:
#                 pass
#             finally: 
#                 del root

# %%
groupBy(states[name], 'module')
# Out:
# dict_keys(['<program root>', 'main', 'SweepSolver', 'Loop@<unknown file> [kripke]:0', 'Grid_Data::particleEdit', 'MPIDI_SHM_mpi_reduce', '247:MPIDI_SHMGR_Release', '900:MPIDI_SHMGR_release_generic', '<unknown file> [libmpi.so.12.0.0]:329', 'Kernel_3d_DGZ::LPlusTimes', '<unknown file> [kripke]:0', 'Kernel_3d_DGZ::LTimes', '__memset_sse2', 'Kernel_3d_DGZ::scattering', 'SweepSubdomains', 'Kernel_3d_DGZ::sweep', 'SweepComm::readySubdomains', 'ParallelComm::testRecieves', 'MPID_Progress_test'])
# ('libmonitor.so.0.0.0',) ('libmonitor.so.0.0.0',)
# ('libmonitor.so.0.0.0',) ('libmonitor.so.0.0.0', 'kripke')
# ('libmonitor.so.0.0.0', 'kripke') ('libmonitor.so.0.0.0', 'kripke')
# ('libmonitor.so.0.0.0', 'kripke') ('libmonitor.so.0.0.0', 'kripke', 'Unkno')
# ('libmonitor.so.0.0.0', 'kripke', 'Unkno') ('libmonitor.so.0.0.0', 'kripke', 'Unkno', 'kripke')
# ('libmonitor.so.0.0.0', 'kripke', 'Unkno', 'kripke') ('libmonitor.so.0.0.0', 'kripke', 'Unkno', 'kripke', 'Unkno')
# ('libmonitor.so.0.0.0', 'kripke', 'Unkno', 'kripke', 'Unkno') ('libmonitor.so.0.0.0', 'kripke', 'Unkno', 'kripke', 'Unkno', 'libc-2.17.so')
# ('libmonitor.so.0.0.0', 'kripke', 'Unkno', 'kripke', 'Unkno', 'libc-2.17.so') ('libmonitor.so.0.0.0', 'kripke', 'Unkno', 'kripke', 'Unkno', 'libc-2.17.so', 'Unkno')
# ('libmonitor.so.0.0.0', 'kripke', 'Unkno', 'kripke', 'Unkno', 'libc-2.17.so', 'Unkno') ('libmonitor.so.0.0.0', 'kripke', 'Unkno', 'kripke', 'Unkno', 'libc-2.17.so', 'Unkno')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-71-24c3a4ac68f8> in <module>
# ----> 1 groupBy(states[name], 'module')
#
# <ipython-input-70-4ea960807bad> in __init__(self, state, group_by)
#      10         self.nodeModuleMap = self.find_mapping_from_df()
#      11         print(self.nodeModuleMap.keys())
# ---> 12         self.run()
#      13
#      14     def find_mapping_from_df(self):
#
# <ipython-input-70-4ea960807bad> in run(self)
#      70                     source = root
#      71                     target = next(node_gen)
# ---> 72                     self.add_node(source, target, False)
#      73                     # self.add_edge(target, source)
#      74                     root = target
#
# <ipython-input-70-4ea960807bad> in add_node(self, source, target, is_root)
#      50                     source_module = None
#      51                 else:
# ---> 52                     source_module = self.nodeModuleMap[source_name]
#      53                     group_node = groupNode(count, target_module_name, target_callpath, source_module_name)
#      54             self.group_graph.add_module(target)
#
# KeyError: 'memset.S:98'

# %%
state = states[name]
print(state.df[state.df['name'] == "Loop@<unknown file> [kripke]:0"])
# Out:
#                                               node  rank   time (inc)  time  \
# 384   <hatchet.node.Node object at 0x7f13d34d8e80>     0  193933103.0   0.0
# 385   <hatchet.node.Node object at 0x7f13d34d8e80>     1  193941625.0   0.0
# 386   <hatchet.node.Node object at 0x7f13d34d8e80>     2  193981015.0   0.0
# 387   <hatchet.node.Node object at 0x7f13d34d8e80>     3  194023154.0   0.0
# 388   <hatchet.node.Node object at 0x7f13d34d8e80>     4  193957846.0   0.0
# 389   <hatchet.node.Node object at 0x7f13d34d8e80>     5  193955999.0   0.0
# 390   <hatchet.node.Node object at 0x7f13d34d8e80>     6  193994342.0   0.0
# 391   <hatchet.node.Node object at 0x7f13d34d8e80>     7  193916176.0   0.0
# 392   <hatchet.node.Node object at 0x7f13d34d8e80>     8  193881701.0   0.0
# 393   <hatchet.node.Node object at 0x7f13d34d8e80>     9  193881630.0   0.0
# 394   <hatchet.node.Node object at 0x7f13d34d8e80>    10  194041468.0   0.0
# 395   <hatchet.node.Node object at 0x7f13d34d8e80>    11  193912281.0   0.0
# 396   <hatchet.node.Node object at 0x7f13d34d8e80>    12  193963535.0   0.0
# 397   <hatchet.node.Node object at 0x7f13d34d8e80>    13  193895065.0   0.0
# 398   <hatchet.node.Node object at 0x7f13d34d8e80>    14  193949618.0   0.0
# 399   <hatchet.node.Node object at 0x7f13d34d8e80>    15  193968132.0   0.0
# 400   <hatchet.node.Node object at 0x7f13d34d8e80>    16  193960368.0   0.0
# 401   <hatchet.node.Node object at 0x7f13d34d8e80>    17  193960489.0   0.0
# 402   <hatchet.node.Node object at 0x7f13d34d8e80>    18  193937872.0   0.0
# 403   <hatchet.node.Node object at 0x7f13d34d8e80>    19  193952385.0   0.0
# 404   <hatchet.node.Node object at 0x7f13d34d8e80>    20  193950938.0   0.0
# 405   <hatchet.node.Node object at 0x7f13d34d8e80>    21  193971716.0   0.0
# 406   <hatchet.node.Node object at 0x7f13d34d8e80>    22  193924290.0   0.0
# 407   <hatchet.node.Node object at 0x7f13d34d8e80>    23  193908764.0   0.0
# 408   <hatchet.node.Node object at 0x7f13d34d8e80>    24  193941964.0   0.0
# 409   <hatchet.node.Node object at 0x7f13d34d8e80>    25  193915928.0   0.0
# 410   <hatchet.node.Node object at 0x7f13d34d8e80>    26  193939762.0   0.0
# 411   <hatchet.node.Node object at 0x7f13d34d8e80>    27  193954204.0   0.0
# 412   <hatchet.node.Node object at 0x7f13d34d8e80>    28  193900557.0   0.0
# 413   <hatchet.node.Node object at 0x7f13d34d8e80>    29  193995634.0   0.0
# ...                                            ...   ...          ...   ...
# 5048  <hatchet.node.Node object at 0x7f13d34d8e80>    98    5178335.0   0.0
# 5049  <hatchet.node.Node object at 0x7f13d34d8e80>    99    5292519.0   0.0
# 5050  <hatchet.node.Node object at 0x7f13d34d8e80>   100    4209337.0   0.0
# 5051  <hatchet.node.Node object at 0x7f13d34d8e80>   101    4229998.0   0.0
# 5052  <hatchet.node.Node object at 0x7f13d34d8e80>   102    4819610.0   0.0
# 5053  <hatchet.node.Node object at 0x7f13d34d8e80>   103    5404193.0   0.0
# 5054  <hatchet.node.Node object at 0x7f13d34d8e80>   104    4750903.0   0.0
# 5055  <hatchet.node.Node object at 0x7f13d34d8e80>   105    4741393.0   0.0
# 5056  <hatchet.node.Node object at 0x7f13d34d8e80>   106    4903511.0   0.0
# 5057  <hatchet.node.Node object at 0x7f13d34d8e80>   107    4785128.0   0.0
# 5058  <hatchet.node.Node object at 0x7f13d34d8e80>   108    4031467.0   0.0
# 5059  <hatchet.node.Node object at 0x7f13d34d8e80>   109    5083162.0   0.0
# 5060  <hatchet.node.Node object at 0x7f13d34d8e80>   110    5399970.0   0.0
# 5061  <hatchet.node.Node object at 0x7f13d34d8e80>   111    5561318.0   0.0
# 5062  <hatchet.node.Node object at 0x7f13d34d8e80>   112    3348519.0   0.0
# 5063  <hatchet.node.Node object at 0x7f13d34d8e80>   113    3767327.0   0.0
# 5064  <hatchet.node.Node object at 0x7f13d34d8e80>   114    4432003.0   0.0
# 5065  <hatchet.node.Node object at 0x7f13d34d8e80>   115    4742906.0   0.0
# 5066  <hatchet.node.Node object at 0x7f13d34d8e80>   116    3187879.0   0.0
# 5067  <hatchet.node.Node object at 0x7f13d34d8e80>   117    3563899.0   0.0
# 5068  <hatchet.node.Node object at 0x7f13d34d8e80>   118    4214463.0   0.0
# 5069  <hatchet.node.Node object at 0x7f13d34d8e80>   119    4919589.0   0.0
# 5070  <hatchet.node.Node object at 0x7f13d34d8e80>   120    3925633.0   0.0
# 5071  <hatchet.node.Node object at 0x7f13d34d8e80>   121    4484997.0   0.0
# 5072  <hatchet.node.Node object at 0x7f13d34d8e80>   122    4483166.0   0.0
# 5073  <hatchet.node.Node object at 0x7f13d34d8e80>   123    4173903.0   0.0
# 5074  <hatchet.node.Node object at 0x7f13d34d8e80>   124    3524000.0   0.0
# 5075  <hatchet.node.Node object at 0x7f13d34d8e80>   125    4626065.0   0.0
# 5076  <hatchet.node.Node object at 0x7f13d34d8e80>   126    4771562.0   0.0
# 5077  <hatchet.node.Node object at 0x7f13d34d8e80>   127    4922848.0   0.0
#
#       nid  rank.1                     file  line module  \
# 384     3       0  <unknown file> [kripke]     0  Unkno
# 385     3       1  <unknown file> [kripke]     0  Unkno
# 386     3       2  <unknown file> [kripke]     0  Unkno
# 387     3       3  <unknown file> [kripke]     0  Unkno
# 388     3       4  <unknown file> [kripke]     0  Unkno
# 389     3       5  <unknown file> [kripke]     0  Unkno
# 390     3       6  <unknown file> [kripke]     0  Unkno
# 391     3       7  <unknown file> [kripke]     0  Unkno
# 392     3       8  <unknown file> [kripke]     0  Unkno
# 393     3       9  <unknown file> [kripke]     0  Unkno
# 394     3      10  <unknown file> [kripke]     0  Unkno
# 395     3      11  <unknown file> [kripke]     0  Unkno
# 396     3      12  <unknown file> [kripke]     0  Unkno
# 397     3      13  <unknown file> [kripke]     0  Unkno
# 398     3      14  <unknown file> [kripke]     0  Unkno
# 399     3      15  <unknown file> [kripke]     0  Unkno
# 400     3      16  <unknown file> [kripke]     0  Unkno
# 401     3      17  <unknown file> [kripke]     0  Unkno
# 402     3      18  <unknown file> [kripke]     0  Unkno
# 403     3      19  <unknown file> [kripke]     0  Unkno
# 404     3      20  <unknown file> [kripke]     0  Unkno
# 405     3      21  <unknown file> [kripke]     0  Unkno
# 406     3      22  <unknown file> [kripke]     0  Unkno
# 407     3      23  <unknown file> [kripke]     0  Unkno
# 408     3      24  <unknown file> [kripke]     0  Unkno
# 409     3      25  <unknown file> [kripke]     0  Unkno
# 410     3      26  <unknown file> [kripke]     0  Unkno
# 411     3      27  <unknown file> [kripke]     0  Unkno
# 412     3      28  <unknown file> [kripke]     0  Unkno
# 413     3      29  <unknown file> [kripke]     0  Unkno
# ...   ...     ...                      ...   ...    ...
# 5048   33      98  <unknown file> [kripke]     0  Unkno
# 5049   33      99  <unknown file> [kripke]     0  Unkno
# 5050   33     100  <unknown file> [kripke]     0  Unkno
# 5051   33     101  <unknown file> [kripke]     0  Unkno
# 5052   33     102  <unknown file> [kripke]     0  Unkno
# 5053   33     103  <unknown file> [kripke]     0  Unkno
# 5054   33     104  <unknown file> [kripke]     0  Unkno
# 5055   33     105  <unknown file> [kripke]     0  Unkno
# 5056   33     106  <unknown file> [kripke]     0  Unkno
# 5057   33     107  <unknown file> [kripke]     0  Unkno
# 5058   33     108  <unknown file> [kripke]     0  Unkno
# 5059   33     109  <unknown file> [kripke]     0  Unkno
# 5060   33     110  <unknown file> [kripke]     0  Unkno
# 5061   33     111  <unknown file> [kripke]     0  Unkno
# 5062   33     112  <unknown file> [kripke]     0  Unkno
# 5063   33     113  <unknown file> [kripke]     0  Unkno
# 5064   33     114  <unknown file> [kripke]     0  Unkno
# 5065   33     115  <unknown file> [kripke]     0  Unkno
# 5066   33     116  <unknown file> [kripke]     0  Unkno
# 5067   33     117  <unknown file> [kripke]     0  Unkno
# 5068   33     118  <unknown file> [kripke]     0  Unkno
# 5069   33     119  <unknown file> [kripke]     0  Unkno
# 5070   33     120  <unknown file> [kripke]     0  Unkno
# 5071   33     121  <unknown file> [kripke]     0  Unkno
# 5072   33     122  <unknown file> [kripke]     0  Unkno
# 5073   33     123  <unknown file> [kripke]     0  Unkno
# 5074   33     124  <unknown file> [kripke]     0  Unkno
# 5075   33     125  <unknown file> [kripke]     0  Unkno
# 5076   33     126  <unknown file> [kripke]     0  Unkno
# 5077   33     127  <unknown file> [kripke]     0  Unkno
#
#                                 name       ...                   df_index  \
# 384   Loop@<unknown file> [kripke]:0       ...       -2851062117835099867
# 385   Loop@<unknown file> [kripke]:0       ...       -2851062117835099867
# 386   Loop@<unknown file> [kripke]:0       ...       -2851062117835099867
# 387   Loop@<unknown file> [kripke]:0       ...       -2851062117835099867
# 388   Loop@<unknown file> [kripke]:0       ...       -2851062117835099867
# 389   Loop@<unknown file> [kripke]:0       ...       -2851062117835099867
# 390   Loop@<unknown file> [kripke]:0       ...       -2851062117835099867
# 391   Loop@<unknown file> [kripke]:0       ...       -2851062117835099867
# 392   Loop@<unknown file> [kripke]:0       ...       -2851062117835099867
# 393   Loop@<unknown file> [kripke]:0       ...       -2851062117835099867
# 394   Loop@<unknown file> [kripke]:0       ...       -2851062117835099867
# 395   Loop@<unknown file> [kripke]:0       ...       -2851062117835099867
# 396   Loop@<unknown file> [kripke]:0       ...       -2851062117835099867
# 397   Loop@<unknown file> [kripke]:0       ...       -2851062117835099867
# 398   Loop@<unknown file> [kripke]:0       ...       -2851062117835099867
# 399   Loop@<unknown file> [kripke]:0       ...       -2851062117835099867
# 400   Loop@<unknown file> [kripke]:0       ...       -2851062117835099867
# 401   Loop@<unknown file> [kripke]:0       ...       -2851062117835099867
# 402   Loop@<unknown file> [kripke]:0       ...       -2851062117835099867
# 403   Loop@<unknown file> [kripke]:0       ...       -2851062117835099867
# 404   Loop@<unknown file> [kripke]:0       ...       -2851062117835099867
# 405   Loop@<unknown file> [kripke]:0       ...       -2851062117835099867
# 406   Loop@<unknown file> [kripke]:0       ...       -2851062117835099867
# 407   Loop@<unknown file> [kripke]:0       ...       -2851062117835099867
# 408   Loop@<unknown file> [kripke]:0       ...       -2851062117835099867
# 409   Loop@<unknown file> [kripke]:0       ...       -2851062117835099867
# 410   Loop@<unknown file> [kripke]:0       ...       -2851062117835099867
# 411   Loop@<unknown file> [kripke]:0       ...       -2851062117835099867
# 412   Loop@<unknown file> [kripke]:0       ...       -2851062117835099867
# 413   Loop@<unknown file> [kripke]:0       ...       -2851062117835099867
# ...                              ...       ...                        ...
# 5048  Loop@<unknown file> [kripke]:0       ...       -2851062117835099867
# 5049  Loop@<unknown file> [kripke]:0       ...       -2851062117835099867
# 5050  Loop@<unknown file> [kripke]:0       ...       -2851062117835099867
# 5051  Loop@<unknown file> [kripke]:0       ...       -2851062117835099867
# 5052  Loop@<unknown file> [kripke]:0       ...       -2851062117835099867
# 5053  Loop@<unknown file> [kripke]:0       ...       -2851062117835099867
# 5054  Loop@<unknown file> [kripke]:0       ...       -2851062117835099867
# 5055  Loop@<unknown file> [kripke]:0       ...       -2851062117835099867
# 5056  Loop@<unknown file> [kripke]:0       ...       -2851062117835099867
# 5057  Loop@<unknown file> [kripke]:0       ...       -2851062117835099867
# 5058  Loop@<unknown file> [kripke]:0       ...       -2851062117835099867
# 5059  Loop@<unknown file> [kripke]:0       ...       -2851062117835099867
# 5060  Loop@<unknown file> [kripke]:0       ...       -2851062117835099867
# 5061  Loop@<unknown file> [kripke]:0       ...       -2851062117835099867
# 5062  Loop@<unknown file> [kripke]:0       ...       -2851062117835099867
# 5063  Loop@<unknown file> [kripke]:0       ...       -2851062117835099867
# 5064  Loop@<unknown file> [kripke]:0       ...       -2851062117835099867
# 5065  Loop@<unknown file> [kripke]:0       ...       -2851062117835099867
# 5066  Loop@<unknown file> [kripke]:0       ...       -2851062117835099867
# 5067  Loop@<unknown file> [kripke]:0       ...       -2851062117835099867
# 5068  Loop@<unknown file> [kripke]:0       ...       -2851062117835099867
# 5069  Loop@<unknown file> [kripke]:0       ...       -2851062117835099867
# 5070  Loop@<unknown file> [kripke]:0       ...       -2851062117835099867
# 5071  Loop@<unknown file> [kripke]:0       ...       -2851062117835099867
# 5072  Loop@<unknown file> [kripke]:0       ...       -2851062117835099867
# 5073  Loop@<unknown file> [kripke]:0       ...       -2851062117835099867
# 5074  Loop@<unknown file> [kripke]:0       ...       -2851062117835099867
# 5075  Loop@<unknown file> [kripke]:0       ...       -2851062117835099867
# 5076  Loop@<unknown file> [kripke]:0       ...       -2851062117835099867
# 5077  Loop@<unknown file> [kripke]:0       ...       -2851062117835099867
#
#      n_index  mod_index                                            callees  \
# 384        3         -1  ['Kernel_3d_DGZ::LTimes', 'Loop@<unknown file>...
# 385        3         -1  ['Kernel_3d_DGZ::LTimes', 'Loop@<unknown file>...
# 386        3         -1  ['Kernel_3d_DGZ::LTimes', 'Loop@<unknown file>...
# 387        3         -1  ['Kernel_3d_DGZ::LTimes', 'Loop@<unknown file>...
# 388        3         -1  ['Kernel_3d_DGZ::LTimes', 'Loop@<unknown file>...
# 389        3         -1  ['Kernel_3d_DGZ::LTimes', 'Loop@<unknown file>...
# 390        3         -1  ['Kernel_3d_DGZ::LTimes', 'Loop@<unknown file>...
# 391        3         -1  ['Kernel_3d_DGZ::LTimes', 'Loop@<unknown file>...
# 392        3         -1  ['Kernel_3d_DGZ::LTimes', 'Loop@<unknown file>...
# 393        3         -1  ['Kernel_3d_DGZ::LTimes', 'Loop@<unknown file>...
# 394        3         -1  ['Kernel_3d_DGZ::LTimes', 'Loop@<unknown file>...
# 395        3         -1  ['Kernel_3d_DGZ::LTimes', 'Loop@<unknown file>...
# 396        3         -1  ['Kernel_3d_DGZ::LTimes', 'Loop@<unknown file>...
# 397        3         -1  ['Kernel_3d_DGZ::LTimes', 'Loop@<unknown file>...
# 398        3         -1  ['Kernel_3d_DGZ::LTimes', 'Loop@<unknown file>...
# 399        3         -1  ['Kernel_3d_DGZ::LTimes', 'Loop@<unknown file>...
# 400        3         -1  ['Kernel_3d_DGZ::LTimes', 'Loop@<unknown file>...
# 401        3         -1  ['Kernel_3d_DGZ::LTimes', 'Loop@<unknown file>...
# 402        3         -1  ['Kernel_3d_DGZ::LTimes', 'Loop@<unknown file>...
# 403        3         -1  ['Kernel_3d_DGZ::LTimes', 'Loop@<unknown file>...
# 404        3         -1  ['Kernel_3d_DGZ::LTimes', 'Loop@<unknown file>...
# 405        3         -1  ['Kernel_3d_DGZ::LTimes', 'Loop@<unknown file>...
# 406        3         -1  ['Kernel_3d_DGZ::LTimes', 'Loop@<unknown file>...
# 407        3         -1  ['Kernel_3d_DGZ::LTimes', 'Loop@<unknown file>...
# 408        3         -1  ['Kernel_3d_DGZ::LTimes', 'Loop@<unknown file>...
# 409        3         -1  ['Kernel_3d_DGZ::LTimes', 'Loop@<unknown file>...
# 410        3         -1  ['Kernel_3d_DGZ::LTimes', 'Loop@<unknown file>...
# 411        3         -1  ['Kernel_3d_DGZ::LTimes', 'Loop@<unknown file>...
# 412        3         -1  ['Kernel_3d_DGZ::LTimes', 'Loop@<unknown file>...
# 413        3         -1  ['Kernel_3d_DGZ::LTimes', 'Loop@<unknown file>...
# ...      ...        ...                                                ...
# 5048      33         -1  ['Kernel_3d_DGZ::LTimes', 'Loop@<unknown file>...
# 5049      33         -1  ['Kernel_3d_DGZ::LTimes', 'Loop@<unknown file>...
# 5050      33         -1  ['Kernel_3d_DGZ::LTimes', 'Loop@<unknown file>...
# 5051      33         -1  ['Kernel_3d_DGZ::LTimes', 'Loop@<unknown file>...
# 5052      33         -1  ['Kernel_3d_DGZ::LTimes', 'Loop@<unknown file>...
# 5053      33         -1  ['Kernel_3d_DGZ::LTimes', 'Loop@<unknown file>...
# 5054      33         -1  ['Kernel_3d_DGZ::LTimes', 'Loop@<unknown file>...
# 5055      33         -1  ['Kernel_3d_DGZ::LTimes', 'Loop@<unknown file>...
# 5056      33         -1  ['Kernel_3d_DGZ::LTimes', 'Loop@<unknown file>...
# 5057      33         -1  ['Kernel_3d_DGZ::LTimes', 'Loop@<unknown file>...
# 5058      33         -1  ['Kernel_3d_DGZ::LTimes', 'Loop@<unknown file>...
# 5059      33         -1  ['Kernel_3d_DGZ::LTimes', 'Loop@<unknown file>...
# 5060      33         -1  ['Kernel_3d_DGZ::LTimes', 'Loop@<unknown file>...
# 5061      33         -1  ['Kernel_3d_DGZ::LTimes', 'Loop@<unknown file>...
# 5062      33         -1  ['Kernel_3d_DGZ::LTimes', 'Loop@<unknown file>...
# 5063      33         -1  ['Kernel_3d_DGZ::LTimes', 'Loop@<unknown file>...
# 5064      33         -1  ['Kernel_3d_DGZ::LTimes', 'Loop@<unknown file>...
# 5065      33         -1  ['Kernel_3d_DGZ::LTimes', 'Loop@<unknown file>...
# 5066      33         -1  ['Kernel_3d_DGZ::LTimes', 'Loop@<unknown file>...
# 5067      33         -1  ['Kernel_3d_DGZ::LTimes', 'Loop@<unknown file>...
# 5068      33         -1  ['Kernel_3d_DGZ::LTimes', 'Loop@<unknown file>...
# 5069      33         -1  ['Kernel_3d_DGZ::LTimes', 'Loop@<unknown file>...
# 5070      33         -1  ['Kernel_3d_DGZ::LTimes', 'Loop@<unknown file>...
# 5071      33         -1  ['Kernel_3d_DGZ::LTimes', 'Loop@<unknown file>...
# 5072      33         -1  ['Kernel_3d_DGZ::LTimes', 'Loop@<unknown file>...
# 5073      33         -1  ['Kernel_3d_DGZ::LTimes', 'Loop@<unknown file>...
# 5074      33         -1  ['Kernel_3d_DGZ::LTimes', 'Loop@<unknown file>...
# 5075      33         -1  ['Kernel_3d_DGZ::LTimes', 'Loop@<unknown file>...
# 5076      33         -1  ['Kernel_3d_DGZ::LTimes', 'Loop@<unknown file>...
# 5077      33         -1  ['Kernel_3d_DGZ::LTimes', 'Loop@<unknown file>...
#
#                                                 callers show_node  \
# 384   ['SweepSolver', 'Kernel_3d_DGZ::LTimes', 'Loop...      True
# 385   ['SweepSolver', 'Kernel_3d_DGZ::LTimes', 'Loop...      True
# 386   ['SweepSolver', 'Kernel_3d_DGZ::LTimes', 'Loop...      True
# 387   ['SweepSolver', 'Kernel_3d_DGZ::LTimes', 'Loop...      True
# 388   ['SweepSolver', 'Kernel_3d_DGZ::LTimes', 'Loop...      True
# 389   ['SweepSolver', 'Kernel_3d_DGZ::LTimes', 'Loop...      True
# 390   ['SweepSolver', 'Kernel_3d_DGZ::LTimes', 'Loop...      True
# 391   ['SweepSolver', 'Kernel_3d_DGZ::LTimes', 'Loop...      True
# 392   ['SweepSolver', 'Kernel_3d_DGZ::LTimes', 'Loop...      True
# 393   ['SweepSolver', 'Kernel_3d_DGZ::LTimes', 'Loop...      True
# 394   ['SweepSolver', 'Kernel_3d_DGZ::LTimes', 'Loop...      True
# 395   ['SweepSolver', 'Kernel_3d_DGZ::LTimes', 'Loop...      True
# 396   ['SweepSolver', 'Kernel_3d_DGZ::LTimes', 'Loop...      True
# 397   ['SweepSolver', 'Kernel_3d_DGZ::LTimes', 'Loop...      True
# 398   ['SweepSolver', 'Kernel_3d_DGZ::LTimes', 'Loop...      True
# 399   ['SweepSolver', 'Kernel_3d_DGZ::LTimes', 'Loop...      True
# 400   ['SweepSolver', 'Kernel_3d_DGZ::LTimes', 'Loop...      True
# 401   ['SweepSolver', 'Kernel_3d_DGZ::LTimes', 'Loop...      True
# 402   ['SweepSolver', 'Kernel_3d_DGZ::LTimes', 'Loop...      True
# 403   ['SweepSolver', 'Kernel_3d_DGZ::LTimes', 'Loop...      True
# 404   ['SweepSolver', 'Kernel_3d_DGZ::LTimes', 'Loop...      True
# 405   ['SweepSolver', 'Kernel_3d_DGZ::LTimes', 'Loop...      True
# 406   ['SweepSolver', 'Kernel_3d_DGZ::LTimes', 'Loop...      True
# 407   ['SweepSolver', 'Kernel_3d_DGZ::LTimes', 'Loop...      True
# 408   ['SweepSolver', 'Kernel_3d_DGZ::LTimes', 'Loop...      True
# 409   ['SweepSolver', 'Kernel_3d_DGZ::LTimes', 'Loop...      True
# 410   ['SweepSolver', 'Kernel_3d_DGZ::LTimes', 'Loop...      True
# 411   ['SweepSolver', 'Kernel_3d_DGZ::LTimes', 'Loop...      True
# 412   ['SweepSolver', 'Kernel_3d_DGZ::LTimes', 'Loop...      True
# 413   ['SweepSolver', 'Kernel_3d_DGZ::LTimes', 'Loop...      True
# ...                                                 ...       ...
# 5048  ['SweepSolver', 'Kernel_3d_DGZ::LTimes', 'Loop...      True
# 5049  ['SweepSolver', 'Kernel_3d_DGZ::LTimes', 'Loop...      True
# 5050  ['SweepSolver', 'Kernel_3d_DGZ::LTimes', 'Loop...      True
# 5051  ['SweepSolver', 'Kernel_3d_DGZ::LTimes', 'Loop...      True
# 5052  ['SweepSolver', 'Kernel_3d_DGZ::LTimes', 'Loop...      True
# 5053  ['SweepSolver', 'Kernel_3d_DGZ::LTimes', 'Loop...      True
# 5054  ['SweepSolver', 'Kernel_3d_DGZ::LTimes', 'Loop...      True
# 5055  ['SweepSolver', 'Kernel_3d_DGZ::LTimes', 'Loop...      True
# 5056  ['SweepSolver', 'Kernel_3d_DGZ::LTimes', 'Loop...      True
# 5057  ['SweepSolver', 'Kernel_3d_DGZ::LTimes', 'Loop...      True
# 5058  ['SweepSolver', 'Kernel_3d_DGZ::LTimes', 'Loop...      True
# 5059  ['SweepSolver', 'Kernel_3d_DGZ::LTimes', 'Loop...      True
# 5060  ['SweepSolver', 'Kernel_3d_DGZ::LTimes', 'Loop...      True
# 5061  ['SweepSolver', 'Kernel_3d_DGZ::LTimes', 'Loop...      True
# 5062  ['SweepSolver', 'Kernel_3d_DGZ::LTimes', 'Loop...      True
# 5063  ['SweepSolver', 'Kernel_3d_DGZ::LTimes', 'Loop...      True
# 5064  ['SweepSolver', 'Kernel_3d_DGZ::LTimes', 'Loop...      True
# 5065  ['SweepSolver', 'Kernel_3d_DGZ::LTimes', 'Loop...      True
# 5066  ['SweepSolver', 'Kernel_3d_DGZ::LTimes', 'Loop...      True
# 5067  ['SweepSolver', 'Kernel_3d_DGZ::LTimes', 'Loop...      True
# 5068  ['SweepSolver', 'Kernel_3d_DGZ::LTimes', 'Loop...      True
# 5069  ['SweepSolver', 'Kernel_3d_DGZ::LTimes', 'Loop...      True
# 5070  ['SweepSolver', 'Kernel_3d_DGZ::LTimes', 'Loop...      True
# 5071  ['SweepSolver', 'Kernel_3d_DGZ::LTimes', 'Loop...      True
# 5072  ['SweepSolver', 'Kernel_3d_DGZ::LTimes', 'Loop...      True
# 5073  ['SweepSolver', 'Kernel_3d_DGZ::LTimes', 'Loop...      True
# 5074  ['SweepSolver', 'Kernel_3d_DGZ::LTimes', 'Loop...      True
# 5075  ['SweepSolver', 'Kernel_3d_DGZ::LTimes', 'Loop...      True
# 5076  ['SweepSolver', 'Kernel_3d_DGZ::LTimes', 'Loop...      True
# 5077  ['SweepSolver', 'Kernel_3d_DGZ::LTimes', 'Loop...      True
#
#                        vis_node_name  max_incTime   avg_incTime  \
# 384   Loop@<unknown file> [kripke]:0  194041468.0  1.939363e+08
# 385   Loop@<unknown file> [kripke]:0  194041468.0  1.939363e+08
# 386   Loop@<unknown file> [kripke]:0  194041468.0  1.939363e+08
# 387   Loop@<unknown file> [kripke]:0  194041468.0  1.939363e+08
# 388   Loop@<unknown file> [kripke]:0  194041468.0  1.939363e+08
# 389   Loop@<unknown file> [kripke]:0  194041468.0  1.939363e+08
# 390   Loop@<unknown file> [kripke]:0  194041468.0  1.939363e+08
# 391   Loop@<unknown file> [kripke]:0  194041468.0  1.939363e+08
# 392   Loop@<unknown file> [kripke]:0  194041468.0  1.939363e+08
# 393   Loop@<unknown file> [kripke]:0  194041468.0  1.939363e+08
# 394   Loop@<unknown file> [kripke]:0  194041468.0  1.939363e+08
# 395   Loop@<unknown file> [kripke]:0  194041468.0  1.939363e+08
# 396   Loop@<unknown file> [kripke]:0  194041468.0  1.939363e+08
# 397   Loop@<unknown file> [kripke]:0  194041468.0  1.939363e+08
# 398   Loop@<unknown file> [kripke]:0  194041468.0  1.939363e+08
# 399   Loop@<unknown file> [kripke]:0  194041468.0  1.939363e+08
# 400   Loop@<unknown file> [kripke]:0  194041468.0  1.939363e+08
# 401   Loop@<unknown file> [kripke]:0  194041468.0  1.939363e+08
# 402   Loop@<unknown file> [kripke]:0  194041468.0  1.939363e+08
# 403   Loop@<unknown file> [kripke]:0  194041468.0  1.939363e+08
# 404   Loop@<unknown file> [kripke]:0  194041468.0  1.939363e+08
# 405   Loop@<unknown file> [kripke]:0  194041468.0  1.939363e+08
# 406   Loop@<unknown file> [kripke]:0  194041468.0  1.939363e+08
# 407   Loop@<unknown file> [kripke]:0  194041468.0  1.939363e+08
# 408   Loop@<unknown file> [kripke]:0  194041468.0  1.939363e+08
# 409   Loop@<unknown file> [kripke]:0  194041468.0  1.939363e+08
# 410   Loop@<unknown file> [kripke]:0  194041468.0  1.939363e+08
# 411   Loop@<unknown file> [kripke]:0  194041468.0  1.939363e+08
# 412   Loop@<unknown file> [kripke]:0  194041468.0  1.939363e+08
# 413   Loop@<unknown file> [kripke]:0  194041468.0  1.939363e+08
# ...                              ...          ...           ...
# 5048  Loop@<unknown file> [kripke]:0    5713792.0  3.659743e+06
# 5049  Loop@<unknown file> [kripke]:0    5713792.0  3.659743e+06
# 5050  Loop@<unknown file> [kripke]:0    5713792.0  3.659743e+06
# 5051  Loop@<unknown file> [kripke]:0    5713792.0  3.659743e+06
# 5052  Loop@<unknown file> [kripke]:0    5713792.0  3.659743e+06
# 5053  Loop@<unknown file> [kripke]:0    5713792.0  3.659743e+06
# 5054  Loop@<unknown file> [kripke]:0    5713792.0  3.659743e+06
# 5055  Loop@<unknown file> [kripke]:0    5713792.0  3.659743e+06
# 5056  Loop@<unknown file> [kripke]:0    5713792.0  3.659743e+06
# 5057  Loop@<unknown file> [kripke]:0    5713792.0  3.659743e+06
# 5058  Loop@<unknown file> [kripke]:0    5713792.0  3.659743e+06
# 5059  Loop@<unknown file> [kripke]:0    5713792.0  3.659743e+06
# 5060  Loop@<unknown file> [kripke]:0    5713792.0  3.659743e+06
# 5061  Loop@<unknown file> [kripke]:0    5713792.0  3.659743e+06
# 5062  Loop@<unknown file> [kripke]:0    5713792.0  3.659743e+06
# 5063  Loop@<unknown file> [kripke]:0    5713792.0  3.659743e+06
# 5064  Loop@<unknown file> [kripke]:0    5713792.0  3.659743e+06
# 5065  Loop@<unknown file> [kripke]:0    5713792.0  3.659743e+06
# 5066  Loop@<unknown file> [kripke]:0    5713792.0  3.659743e+06
# 5067  Loop@<unknown file> [kripke]:0    5713792.0  3.659743e+06
# 5068  Loop@<unknown file> [kripke]:0    5713792.0  3.659743e+06
# 5069  Loop@<unknown file> [kripke]:0    5713792.0  3.659743e+06
# 5070  Loop@<unknown file> [kripke]:0    5713792.0  3.659743e+06
# 5071  Loop@<unknown file> [kripke]:0    5713792.0  3.659743e+06
# 5072  Loop@<unknown file> [kripke]:0    5713792.0  3.659743e+06
# 5073  Loop@<unknown file> [kripke]:0    5713792.0  3.659743e+06
# 5074  Loop@<unknown file> [kripke]:0    5713792.0  3.659743e+06
# 5075  Loop@<unknown file> [kripke]:0    5713792.0  3.659743e+06
# 5076  Loop@<unknown file> [kripke]:0    5713792.0  3.659743e+06
# 5077  Loop@<unknown file> [kripke]:0    5713792.0  3.659743e+06
#
#       imbalance_perc
# 384         0.000542
# 385         0.000542
# 386         0.000542
# 387         0.000542
# 388         0.000542
# 389         0.000542
# 390         0.000542
# 391         0.000542
# 392         0.000542
# 393         0.000542
# 394         0.000542
# 395         0.000542
# 396         0.000542
# 397         0.000542
# 398         0.000542
# 399         0.000542
# 400         0.000542
# 401         0.000542
# 402         0.000542
# 403         0.000542
# 404         0.000542
# 405         0.000542
# 406         0.000542
# 407         0.000542
# 408         0.000542
# 409         0.000542
# 410         0.000542
# 411         0.000542
# 412         0.000542
# 413         0.000542
# ...              ...
# 5048        0.359490
# 5049        0.359490
# 5050        0.359490
# 5051        0.359490
# 5052        0.359490
# 5053        0.359490
# 5054        0.359490
# 5055        0.359490
# 5056        0.359490
# 5057        0.359490
# 5058        0.359490
# 5059        0.359490
# 5060        0.359490
# 5061        0.359490
# 5062        0.359490
# 5063        0.359490
# 5064        0.359490
# 5065        0.359490
# 5066        0.359490
# 5067        0.359490
# 5068        0.359490
# 5069        0.359490
# 5070        0.359490
# 5071        0.359490
# 5072        0.359490
# 5073        0.359490
# 5074        0.359490
# 5075        0.359490
# 5076        0.359490
# 5077        0.359490
#
# [2815 rows x 22 columns]

# %%
state = states[name]
fns = state.entire_df['name'].unique()
nodeModuleMap = {}
for idx, fn in enumerate(fns):
    fn_hatchet = state.entire_df[state.entire_df['name'] == fn]['node'].unique()[0]
    nodeModuleMap[fn_hatchet] = state.df[state.df['name'] == fn]['module'].unique()
print(nodeModuleMap)
# Out:
# {<hatchet.node.Node object at 0x7f34a57eb320>: array([], dtype=object), <hatchet.node.Node object at 0x7f34a57eb438>: array([], dtype=object), <hatchet.node.Node object at 0x7f34a57ebc18>: array([], dtype=object), <hatchet.node.Node object at 0x7f34a57eb2e8>: array(['libmonitor.so.0.0.0'], dtype=object), <hatchet.node.Node object at 0x7f34a57eb828>: array(['kripke'], dtype=object), <hatchet.node.Node object at 0x7f34a57eb550>: array([], dtype=object), <hatchet.node.Node object at 0x7f34a5913080>: array([], dtype=object), <hatchet.node.Node object at 0x7f34a59130f0>: array([], dtype=object), <hatchet.node.Node object at 0x7f34a5913198>: array([], dtype=object), <hatchet.node.Node object at 0x7f34a5913208>: array([], dtype=object), <hatchet.node.Node object at 0x7f34a5913278>: array([], dtype=object), <hatchet.node.Node object at 0x7f34a59132e8>: array([], dtype=object), <hatchet.node.Node object at 0x7f34a5913358>: array([], dtype=object), <hatchet.node.Node object at 0x7f34a59133c8>: array([], dtype=object), <hatchet.node.Node object at 0x7f34a5913438>: array([], dtype=object), <hatchet.node.Node object at 0x7f34a59134a8>: array([], dtype=object), <hatchet.node.Node object at 0x7f34a57eb3c8>: array([], dtype=object), <hatchet.node.Node object at 0x7f34a57ebfd0>: array([], dtype=object), <hatchet.node.Node object at 0x7f34a57ebe10>: array(['libmpi.so.12.0.0'], dtype=object), <hatchet.node.Node object at 0x7f34a57ebf28>: array([], dtype=object), <hatchet.node.Node object at 0x7f34a57ebe80>: array([], dtype=object), <hatchet.node.Node object at 0x7f34a57ebef0>: array([], dtype=object), '': array([], dtype=object), <hatchet.node.Node object at 0x7f34a57ebdd8>: array([], dtype=object), <hatchet.node.Node object at 0x7f34a57ebe48>: array([], dtype=object), <hatchet.node.Node object at 0x7f34a57ebda0>: array([], dtype=object), <hatchet.node.Node object at 0x7f34a57eb908>: array([], dtype=object), <hatchet.node.Node object at 0x7f34a57ebd30>: array([], dtype=object), <hatchet.node.Node object at 0x7f34a57ebc50>: array([], dtype=object), <hatchet.node.Node object at 0x7f34a57ebb00>: array([], dtype=object), <hatchet.node.Node object at 0x7f34a57ebac8>: array([], dtype=object), <hatchet.node.Node object at 0x7f34a57eb9b0>: array([], dtype=object), <hatchet.node.Node object at 0x7f34a57ebb38>: array([], dtype=object), <hatchet.node.Node object at 0x7f34a57eb588>: array([], dtype=object), <hatchet.node.Node object at 0x7f34a57eb860>: array([], dtype=object), <hatchet.node.Node object at 0x7f34a57eba58>: array([], dtype=object), <hatchet.node.Node object at 0x7f34a57eb748>: array([], dtype=object), <hatchet.node.Node object at 0x7f34a57eb710>: array([], dtype=object), <hatchet.node.Node object at 0x7f34a57eb7f0>: array([], dtype=object), <hatchet.node.Node object at 0x7f34a57eb7b8>: array([], dtype=object), <hatchet.node.Node object at 0x7f34a57eb6d8>: array([], dtype=object), <hatchet.node.Node object at 0x7f34a57eb5f8>: array([], dtype=object), <hatchet.node.Node object at 0x7f34a57eb630>: array([], dtype=object), <hatchet.node.Node object at 0x7f34a57eb6a0>: array([], dtype=object), <hatchet.node.Node object at 0x7f34a57eb780>: array([], dtype=object), <hatchet.node.Node object at 0x7f34a59130b8>: array([], dtype=object), <hatchet.node.Node object at 0x7f34a5913048>: array([], dtype=object), <hatchet.node.Node object at 0x7f34a57ebc88>: array([], dtype=object), <hatchet.node.Node object at 0x7f34a5913240>: array([], dtype=object), <hatchet.node.Node object at 0x7f34a59131d0>: array([], dtype=object), <hatchet.node.Node object at 0x7f34a57eba90>: array([], dtype=object), <hatchet.node.Node object at 0x7f34a5913320>: array([], dtype=object), <hatchet.node.Node object at 0x7f34a59132b0>: array([], dtype=object), <hatchet.node.Node object at 0x7f34a5913400>: array([], dtype=object), <hatchet.node.Node object at 0x7f34a5913470>: array([], dtype=object), <hatchet.node.Node object at 0x7f34a5913390>: array([], dtype=object), <hatchet.node.Node ...
