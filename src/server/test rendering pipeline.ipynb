# %%
import networkx as nx
import math
import json
from ast import literal_eval as make_tuple
from networkx.readwrite import json_graph

# %%
from logger import log
import utils
from pipeline import Pipeline

# %% [markdown]
# # Read Config file

# %%
from configFileReader import *
# configFileName = '/home/vidi/Work/llnl/CallFlow/config_files/scatter vs scatterv.json'
configFileName = '/home/vidi/Work/llnl/CallFlow/config_files/lulesh-annotation-profile.json'
config = configFileReader(configFileName)

# %%
print(config.callflow_path)
# Out:
# /home/vidi/Work/llnl/CallFlow/

# %% [markdown]
# # Converting to final NetworkX graph format

# %%
states = {}
datasets = config.datasets
pipeline = Pipeline(config)
states['ensemble'] = pipeline.read_ensemble_gf()
for idx, dataset in enumerate(datasets):
    dataset_name = dataset['name']
    states[dataset_name] = pipeline.read_dataset_gf(dataset_name)
# Out:
#  #  [Process] Reading the union dataframe and graph
#  #  [Process] Reading the dataframe and graph of state: 1-core
#  #  [Process] Reading the dataframe and graph of state: 27-cores
#  #  [Process] Reading the dataframe and graph of state: 512-cores

# %%
print(states)
# Out:
# {'ensemble': <state.State object at 0x7f3215f41358>, '1-core': <state.State object at 0x7f3215f41400>, '27-cores': <state.State object at 0x7f3215f413c8>, '512-cores': <state.State object at 0x7f3215f417f0>}

# %%
print(states['512-cores'].df[['name','time (inc)']].groupby('name').mean())
# Out:
#                                    time (inc)
# name
# ApplyMaterialPropertiesForElems  5.215690e+06
# CalcCourantConstraintForElems    1.570734e+05
# CalcEnergyForElems               2.788083e+06
# CalcFBHourglassForceForElems     4.832240e+06
# CalcForceForNodes                2.367263e+07
# CalcHourglassControlForElems     1.814385e+07
# CalcHydroConstraintForElems      3.324241e+04
# CalcKinematicsForElems           4.029242e+06
# CalcLagrangeElements             4.429387e+06
# CalcMonotonicQGradientsForElems  1.793327e+06
# CalcMonotonicQRegionForElems     1.482072e+06
# CalcPressureForElems             1.226399e+06
# CalcQForElems                    6.675364e+06
# CalcSoundSpeedForElems           1.127088e+05
# CalcTimeConstraintsForElems      1.950236e+05
# CalcVolumeForceForElems          2.262529e+07
# EvalEOSForElems                  5.101354e+06
# IntegrateStressForElems          3.973302e+06
# LagrangeElements                 1.636953e+07
# LagrangeLeapFrog                 4.251660e+07
# LagrangeNodal                    2.595108e+07
# MPI_Allreduce                    1.081706e+07
# MPI_Barrier                      4.686619e+03
# MPI_Finalize                     1.016377e+05
# MPI_Irecv                        2.933603e+03
# MPI_Isend                        1.152396e+04
# MPI_Reduce                       1.313506e+04
# MPI_Wait                         6.260998e+04
# MPI_Waitall                      9.271743e+05
# TimeIncrement                    1.081825e+07
# UpdateVolumesForElems            4.607265e+04
# lulesh.cycle                     5.333560e+07
# main                             5.354906e+07

# %%
class DistGraph(nx.Graph):
    # Attributes:
    # 1. State => Pass the state which needs to be handled.
    # 2. path => '', 'path', 'group_path' or 'component_path'
    # 3. construct_graph -> To decide if we should construct graph from path
    # 4. add_data => To 
    def __init__(self, state, path, group_by_attr='module', construct_graph=True, add_data=True):
        super(DistGraph, self).__init__()
        self.state = state
        self.path = path
        self.df = self.state.df
        self.group_by = group_by_attr
#         self.columns = ['time']
        self.columns = ['time (inc)', 'group_path', 'name', 'time', 'callers', 'callees', 'vis_name']
        
        if construct_graph:
            print('Creating a Graph for {0}.'.format(self.state.name))
            self.g = nx.DiGraph()
            self.add_paths(path)
        else:
            print('Using the existing graph from state {0}'.format(state.name))
            self.g = state.g

        self.adj_matrix = nx.adjacency_matrix(self.g)
        self.dense_adj_matrix = self.adj_matrix.todense()

        self.callbacks = []
        self.edge_direction = {}

        if add_data == True:
            self.add_node_attributes()
            self.add_edge_attributes()
        else:
            print('Creating a Graph without node or edge attributes.')
        self.adj_matrix = nx.adjacency_matrix(self.g)
        self.dense_adj_matrix = self.adj_matrix.todense()

    def no_cycle_path(self, path):
        ret = []
        mapper = {}
        for idx, elem in enumerate(path):
            if elem not in mapper:
                mapper[elem] = 1
                ret.append(elem)
            else:
                ret.append(elem + '_' + str(mapper[elem]))
                mapper[elem] += 1

        return tuple(ret)

    def add_paths(self, path):
        for idx, row in self.df.iterrows():
            if row.show_node:
                print(row[path], type(row[path]))
                if isinstance(row[path], list):
                    path_tuple = row[path]
                elif isinstance(row[path], str):
                    path_tuple = make_tuple(row[path])
                corrected_path = self.no_cycle_path(path_tuple)
                self.g.add_path(corrected_path)

    def add_edge_attributes(self):
        number_of_runs_mapping = self.number_of_runs()
        nx.set_edge_attributes(self.g, name="number_of_runs", values=number_of_runs_mapping)
        capacity_mapping = self.calculate_flows(self.g)
        nx.set_edge_attributes((self.g), name='weight', values=capacity_mapping)

    def number_of_runs(self):
        ret = {}
        for idx, name in enumerate(self.runs):           
            for edge in self.runs[name].edges():
                if edge not in ret:
                    ret[edge] = 0
                ret[edge] += 1
        return ret

    def add_union_node_attributes(self):
        for node in self.R.nodes(data=True):
            node_name = node[0]
            node_data = node[1]
            max_inc_time = 0
            max_exc_time = 0
            self.R.nodes[node_name]['ensemble'] = {}
            for dataset in node_data:
                for idx, key in enumerate(node_data[dataset]):
                    if(key == 'name'):
                        self.R.nodes[node_name]['union']['name'] = node_data[dataset][key]
                    elif(key == 'time (inc)'):
                        max_inc_time = max(max_inc_time, node_data[dataset][key])
                    elif(key == 'time'):
                        max_exc_time = max(max_exc_time, node_data[dataset][key])
                    elif(key == 'entry_functions'):
                        entry_functions = node_data[dataset][key]

            self.R.nodes[node_name]['ensemble']['time (inc)'] = max_inc_time
            self.R.nodes[node_name]['ensemble']['time'] = max_exc_time
            self.R.nodes[node_name]['ensemble']['entry_functions'] = entry_functions

    def add_node_attributes(self):
        ensemble_mapping = self.ensemble_map(self.g.nodes())
        
        for idx, key in enumerate(ensemble_mapping):
            nx.set_node_attributes(self.g, name=key, values=ensemble_mapping[key])
        
        dataset_mapping = {}
        for dataset in self.df['dataset'].unique():
            dataset_mapping[dataset] = self.dataset_map(self.g.nodes(), dataset)
            
            nx.set_node_attributes(self.g, name=dataset, values=dataset_mapping[dataset])

    def tailhead(self, edge):
        return (
         edge[0], edge[1])

    def tailheadDir(self, edge):
        return (
         str(edge[0]), str(edge[1]), self.edge_direction[edge])

    def add_edge_attributes(self):
        capacity_mapping = self.calculate_flows(self.g)
        nx.set_edge_attributes((self.g), name='weight', values=capacity_mapping)

    def leaves_below(self, graph, node):
        return set(sum(([vv for vv in v if graph.out_degree(vv) == 0] for k, v in nx.dfs_successors(graph, node).items()), []))

    def calculate_flows(self, graph):
        ret = {}
        edges = graph.edges()
        additional_flow = {}
        for edge in edges:
            source = edge[0]
            target = edge[1]
 
            source_inc = self.df.loc[(self.df['name'] == source)]["time (inc)"].max()
            target_inc = self.df.loc[(self.df['name'] == target)]["time (inc)"].max()
            if source_inc == target_inc:
                ret[edge] = source_inc
            else:
                ret[edge] = target_inc

        return ret
    
    def ensemble_map(self, nodes):
        ret = {}
        # loop through the nodes
        for node in self.g.nodes():

            # Get their dataframe
            node_df = self.df.loc[self.df["name"] == node]

            for column in self.columns:
                if column not in ret:
                    ret[column] = {}

                column_data = node_df[column]

                if column == "time (inc)" or column == "time" or column == "component_level":
                    if len(column_data.value_counts() > 0):
                        ret[column][node] = column_data.max()
                    else:
                        ret[column][node] = -1

                elif column == "callers" or column == "callees":
                    
                    if len(column_data.value_counts()) > 0:
                        ret[column][node] = make_tuple(column_data.tolist()[0])
                    else:
                        ret[column][node] = []

                elif column == "name" or column == "vis_name":
                    
                    if len(column_data.value_counts() > 0):
                        ret[column][node] = column_data.tolist()[0]
                    else:
                        ret[column][node] = "None"

                elif column == 'component_path' or column == 'group_path':

                    if len(column_data.value_counts() > 0):
                        ret[column][node] = list(make_tuple(column_data.tolist()[0]))
                    else:
                        ret[column][node] = []
        return ret

    def dataset_map(self, nodes, dataset):
        ret = {}
        for node in self.g.nodes():
            if node not in ret:
                ret[node] = {}

            node_df = self.df.loc[
                (self.df["name"] == node) & (self.df["dataset"] == dataset)
            ]

            for column in self.columns:
                column_data = node_df[column]

                if column == "time (inc)" or column == "time" or column == 'component_level':
                    if len(column_data.value_counts()) > 0:
                        ret[node][column] = column_data.max()
                    else:
                        ret[node][column] = -1

                elif column == "callers" or column == "callees":
                    if len(column_data.value_counts()) > 0:
                        ret[node][column] = make_tuple(column_data.tolist()[0])
                    else:
                        ret[node][column] = []

                elif column == "name" or column == "vis_name":
                    if len(column_data.value_counts()) > 0:
                        ret[node][column] = column_data.tolist()[0]

                    else:
                        ret[node][column] = "None"

                elif column == 'component_path' or column == 'group_path':

                    if len(column_data.value_counts() > 0):
                        ret[node][column] = list(make_tuple(column_data.tolist()[0]))
                    else:
                        ret[node][column] = []
        return ret

# %%
final_graph = DistGraph(states['ensemble'], '', construct_graph=False, add_data=True)
# Out:
# Using the existing graph from state ensemble

# %%
result = json_graph.node_link_data(final_graph.g)
final_result = json.dumps(result)

print(final_result)
# Out:
# {"directed": true, "multigraph": false, "graph": {}, "nodes": [{"show_node": true, "module": "<unknown load module>", "group_path": ["<unknown load module>=<partial call paths>"], "component_path": ["<unknown load module>=<partial call paths>", "<partial call paths>"], "time (inc)": 12918.0, "name": "<partial call paths>", "time": 0.0, "callers": [], "callees": ["<unknown procedure>"], "vis_name": "<unknown load module>=<partial call paths>", "osu_bcast.1.18.2019-09-03_11-33-15": {"time (inc)": 6987.0, "group_path": ["<unknown load module>=<partial call paths>"], "name": "<partial call paths>", "time": 0.0, "callers": [], "callees": ["<unknown procedure>"], "vis_name": "<unknown load module>=<partial call paths>"}, "osu_bcast.1.18.2019-09-03_12-29-49": {"time (inc)": 5948.0, "group_path": ["<unknown load module>=<partial call paths>"], "name": "<partial call paths>", "time": 0.0, "callers": [], "callees": ["<unknown procedure>"], "vis_name": "<unknown load module>=<partial call paths>"}, "osu_bcast.1.18.2019-09-03_10-33-44": {"time (inc)": 12918.0, "group_path": ["<unknown load module>=<partial call paths>"], "name": "<partial call paths>", "time": 0.0, "callers": [], "callees": ["<unknown procedure>"], "vis_name": "<unknown load module>=<partial call paths>"}, "id": "<partial call paths>"}, {"show_node": false, "module": "Unknown (NA)", "group_path": [], "component_path": [], "time (inc)": 12918.0, "name": "<unknown procedure>", "time": 0.0, "callers": [], "callees": ["<unknown file>"], "vis_name": "None", "osu_bcast.1.18.2019-09-03_11-33-15": {"time (inc)": 6987.0, "group_path": [], "name": "<unknown procedure>", "time": 0.0, "callers": [], "callees": ["<unknown file>"], "vis_name": "None"}, "osu_bcast.1.18.2019-09-03_12-29-49": {"time (inc)": 5948.0, "group_path": [], "name": "<unknown procedure>", "time": 0.0, "callers": [], "callees": ["<unknown file>"], "vis_name": "None"}, "osu_bcast.1.18.2019-09-03_10-33-44": {"time (inc)": 12918.0, "group_path": [], "name": "<unknown procedure>", "time": 0.0, "callers": [], "callees": ["<unknown file>"], "vis_name": "None"}, "id": "<unknown procedure>"}, {"show_node": true, "module": "libmonitor.so.0.0.0", "group_path": ["libmonitor.so.0.0.0=<program root>"], "component_path": ["libmonitor.so.0.0.0=<program root>", "<program root>"], "time (inc)": 1147289.0, "name": "<program root>", "time": 0.0, "callers": [], "callees": ["main"], "vis_name": "libmonitor.so.0.0.0=<program root>", "osu_bcast.1.18.2019-09-03_11-33-15": {"time (inc)": 1139918.0, "group_path": ["libmonitor.so.0.0.0=<program root>"], "name": "<program root>", "time": 0.0, "callers": [], "callees": ["main"], "vis_name": "libmonitor.so.0.0.0=<program root>"}, "osu_bcast.1.18.2019-09-03_12-29-49": {"time (inc)": 1140997.0, "group_path": ["libmonitor.so.0.0.0=<program root>"], "name": "<program root>", "time": 0.0, "callers": [], "callees": ["main"], "vis_name": "libmonitor.so.0.0.0=<program root>"}, "osu_bcast.1.18.2019-09-03_10-33-44": {"time (inc)": 1147289.0, "group_path": ["libmonitor.so.0.0.0=<program root>"], "name": "<program root>", "time": 0.0, "callers": [], "callees": ["main"], "vis_name": "libmonitor.so.0.0.0=<program root>"}, "id": "<program root>"}, {"show_node": true, "module": "osu_bcast", "group_path": ["libmonitor.so.0.0.0=<program root>", "osu_bcast=main"], "component_path": ["osu_bcast=main", "main"], "time (inc)": 1147289.0, "name": "main", "time": 0.0, "callers": [], "callees": ["117:free_buffer", "119:MPI_Finalize", "36:MPI_Init", "92:PMPI_Bcast", "98:PMPI_Barrier"], "vis_name": "osu_bcast=main", "osu_bcast.1.18.2019-09-03_11-33-15": {"time (inc)": 1139918.0, "group_path": ["libmonitor.so.0.0.0=<program root>", "osu_bcast=main"], "name": "main", "time": 0.0, "callers": [], "callees": ["117:free_buffer", "119:MPI_Finalize", "36:MPI_Init", "92:PMPI_Bcast", "98:PMPI_Barrier"], "vis_name": "osu_bcast=main"}, "osu_bcast.1.18.2019-09-03_12-29-49": {"time (inc)": 1140997.0, "group_path": ["libmonitor.so.0.0.0 ...

# %%
df  = states['ensemble'].df
# name_grouped = df.groupby(['name'])

def addID(name):
    if(":" in name and '[' not in name):
        name = name.split(':')[len(name.split(':')) - 1]
    elif('[' in name and ':' not in name):
        name = name.split('[')[0]
    elif('[' in name and ':' in name):
        name = name.split(':')[len(name.split(':')) - 1]
        name = name.split('[')[0]
    else:
        name = name
        
    name = name.replace(' ', '_')
    return name


df['id'] = df['name'].apply(addID)
print(df['id'].unique())
# Out:
# ['<partial_call_paths>' '<unknown_procedure>' '0' '<program_root>' 'main'
#  'free_buffer' '__GI___vsyslog_chk' '244' 'MPI_Finalize' 'PMPI_Finalize'
#  'MPID_Finalize' 'psm_dofinalize' '<unknown_procedure>_0x1e450_'
#  '<unknown_procedure>_0x1e82f_' '_int_free' '3986'
#  '<unknown_procedure>_0x188b1_' '<unknown_procedure>_0xff82_'
#  '<unknown_procedure>_0xf774_' '_getopt_internal_r' '716'
#  '<unknown_procedure>_0x188fe_' '<unknown_procedure>_0x20e9e_'
#  '<unknown_procedure>_0x26030_' '<unknown_procedure>_0x2604e_'
#  '<unknown_procedure>_0x26058_' '<unknown_procedure>_0x1c060_'
#  '<unknown_procedure>_0x1c075_' '<unknown_procedure>_0x1c083_'
#  '<unknown_procedure>_0x1c088_' '<unknown_procedure>_0x1c08c_'
#  '<unknown_procedure>_0x1c096_' '<unknown_procedure>_0x1c09c_'
#  '<unknown_procedure>_0x1c0a3_' '<unknown_procedure>_0x9c90_'
#  '<unknown_procedure>_0x2605e_' '<unknown_procedure>_0x26068_'
#  '<unknown_procedure>_0x1c080_' '<unknown_procedure>_0x2606e_'
#  '<unknown_procedure>_0x26072_' '<unknown_procedure>_0x2607b_'
#  '<unknown_procedure>_0x33e30_' '<unknown_procedure>_0x33e35_'
#  '<unknown_procedure>_0x33e38_' '<unknown_procedure>_0x33e68_'
#  '<unknown_procedure>_0x33e76_' '<unknown_procedure>_0x33fa0_'
#  '<unknown_procedure>_0x33fa2_' '<unknown_procedure>_0x33fa5_'
#  '<unknown_procedure>_0x33fa9_' '<unknown_procedure>_0x33faf_'
#  '<unknown_procedure>_0x33fb6_' '<unknown_procedure>_0x33fc2_'
#  '<unknown_procedure>_0x33fdf_' '<unknown_procedure>_0x3400a_'
#  '<unknown_procedure>_0x3401f_' '<unknown_procedure>_0x3402f_'
#  '<unknown_procedure>_0x3403f_' '<unknown_procedure>_0x34042_'
#  '<unknown_procedure>_0x34045_' '<unknown_procedure>_0x34048_'
#  '<unknown_procedure>_0x3404b_' '<unknown_procedure>_0x3404f_'
#  '<unknown_procedure>_0x340e0_' '<unknown_procedure>_0x340ec_'
#  '<unknown_procedure>_0x340fd_' '<unknown_procedure>_0x3416d_'
#  '<unknown_procedure>_0x3417d_' '<unknown_procedure>_0x34186_'
#  '<unknown_procedure>_0x34189_' '<unknown_procedure>_0x33e77_'
#  '<unknown_procedure>_0x33e88_' '<unknown_procedure>_0x33e8a_'
#  '<unknown_procedure>_0x33e96_' '<unknown_procedure>_0x13b60_'
#  '<unknown_procedure>_0x13b66_' '<unknown_procedure>_0x13b68_'
#  '<unknown_procedure>_0x13b6d_' '<unknown_procedure>_0x13b74_'
#  '<unknown_procedure>_0x13b85_' '<unknown_procedure>_0x13b87_'
#  '<unknown_procedure>_0x13b8f_' '<unknown_procedure>_0x13b96_'
#  '<unknown_procedure>_0x13db9_' '<unknown_procedure>_0x13dc1_'
#  '<unknown_procedure>_0x13dd5_' '<unknown_procedure>_0x13ddb_'
#  '<unknown_procedure>_0x13de4_' '<unknown_procedure>_0x13df9_'
#  '<unknown_procedure>_0x13dff_' '<unknown_procedure>_0x13e0a_'
#  '<unknown_procedure>_0x33e97_' '<unknown_procedure>_0x33eae_'
#  '<unknown_procedure>_0x33eb5_' '<unknown_procedure>_0x9890_'
#  '<unknown_procedure>_0x260eb_' '<unknown_procedure>_0x23501_'
#  '<unknown_procedure>_0x2610f_' '<unknown_procedure>_0x2b3b8_'
#  '<unknown_procedure>_0x26130_' '<unknown_procedure>_0x26155_'
#  '<unknown_procedure>_0x26156_' '<unknown_procedure>_0x26167_'
#  'PMPI_Bcast' 'MPIR_Bcast_impl' 'MPIR_Bcast_MV2' '3141'
#  'MPIR_Bcast_index_tuned_intra_MV2' '2594' '2667' '2808' '__libm_exp2f_e7'
#  'MPIR_Bcast_tune_inter_node_helper_MV2' '1972' '1994' '2068'
#  'MPIR_Pipelined_Bcast_MV2' 'MPIR_Shmem_Bcast_MV2' 'mv2_shm_bcast' '3806'
#  '__intel_ssse3_rep_memcpy' 'MPIR_Knomial_Bcast_inter_node_wrapper_MV2'
#  'MPIR_Knomial_Bcast_inter_node_MV2' 'mv2_shm_barrier' '3611' '1172'
#  'MPIR_Type_get_true_extent_impl' '39' 'MPIR_Type_get_true_extent_x_impl'
#  '41' '3789' '3793' '3807' '3808' '_intel_fast_memcpy.P' '3624'
#  'mv2_shm_progress' 'psm_progress_wait' '274'
#  '<unknown_procedure>_0x32647_' '<unknown_procedure>_0x326b8_'
#  '<unknown_procedure>_0x326c9_' '<unknown_procedure>_0x33fad_'
#  '<unknown_procedure>_0x34017_' '3589' '275' '299' 'psm_no_lock' '417'
#  '<unknown_procedure>_0x32697_' '<unknown_procedure>_0x326c5_'
#  'MPIR_Bcast_binomial_MV2' 'MPIC_Recv' 'MPID_Recv' 'psm_recv'
#  'psm_try_complete' '267' '<unknown_procedure>_0x33e7c_'
#  '<unknown_procedure>_0x13eab_' '<unknown_procedure>_0xabb7_'
#  '<unknown_procedure>_0x147a6_' '<unknown_procedure>_0x33300_'
#  '<unknown_procedure>_0x3285e_' '<unknown_procedure>_0x1da64_'
#  '<unknown_procedure>_0xa128_' 'MPIC_Send' 'MPID_Send'
#  'MPIDI_CH3_EagerContigSend' 'psm_istartmsgv' 'psm_send_pkt'
#  '<unknown_procedure>_0x3227a_' '<unknown_procedure>_0x10160_'
#  '<unknown_procedure>_0x103ef_' '<unknown_procedure>_0xe7bd_'
#  '<unknown_procedure>_0x1045e_' '<unknown_procedure>_0xe83e_'
#  '<unknown_procedure>_0xe8da_' '__pthread_cond_broadcast_2_0' '35'
#  'PMPI_Barrier' 'MPIR_Barrier_impl' 'MPIR_Barrier_MV2'
#  'MPIR_shmem_barrier_MV2' 'MPIDI_CH3I_SHMEM_COLL_Barrier_gather' '262'
#  'MPIDI_CH3I_SHMEM_COLL_Barrier_bcast' '1802' '1807' '1840'
#  '<unknown_procedure>_0x142f10_' '234' '289'
#  '<unknown_procedure>_0x32640_' '<unknown_procedure>_0x32691_'
#  '<unknown_procedure>_0x326b0_' '<unknown_procedure>_0x13dc9_'
#  'PMPI_Reduce' 'MPIR_Reduce_impl' 'MPIR_Reduce_MV2'
#  'MPIR_Reduce_index_tuned_intra_MV2' '1961'
#  '<unknown_procedure>_0x144b10_' '<unknown_procedure>_0x1c086_'
#  '<unknown_procedure>_0x33fa4_' '<unknown_procedure>_0x34103_'
#  '<unknown_procedure>_0x13b69_' '<unknown_procedure>_0x13b91_'
#  '<unknown_procedure>_0x2350f_' '<unknown_procedure>_0x26143_'
#  'psm_deallocate_vbuf' '2509' '__libm_log2_e7' '1970' '1193' '3623'
#  '<unknown_procedure>_0x3264f_' '3584' '247'
#  '<unknown_procedure>_0x33fbf_' '<unknown_procedure>_0xa12f_'
#  '<unknown_procedure>_0x326ce_' '438' '123' '1738' '1810' '1835' '273'
#  '293' '<unknown_procedure>_0x326a0_' '90' '<unknown_procedure>_0x2614a_'
#  'MPIDI_PG_Finalize' 'snprintf' 'PMIi_ReadCommand' '__write_nocancel' '81'
#  'MPIDI_RMA_finalize' '2553' '2567' '1960' 'int_mallinfo' '4596' '3613'
#  '1163' '3625' 'PMPI_Wtime' '60' 'MPIU_Wtime_todouble' '102'
#  '<unknown_procedure>_0x34020_' 'MPIDI_CH3_Progress_test' '241'
#  'mv2_increment_shmem_coll_counter' '1894']

# %%
print(df.sort_values(['time'], ascending=[False])[['name','time', 'module']])
# Out:
#                                                    name      time  \
# 3002       <unknown file> [libpsm_infinipath.so.1.16]:0  305470.0
# 593        <unknown file> [libpsm_infinipath.so.1.16]:0  287599.0
# 588        <unknown file> [libpsm_infinipath.so.1.16]:0  287585.0
# 5986       <unknown file> [libpsm_infinipath.so.1.16]:0  281594.0
# 5989       <unknown file> [libpsm_infinipath.so.1.16]:0  275647.0
# 5979       <unknown file> [libpsm_infinipath.so.1.16]:0  275570.0
# 3237       <unknown file> [libpsm_infinipath.so.1.16]:0  270107.0
# 597        <unknown file> [libpsm_infinipath.so.1.16]:0  263622.0
# 5972       <unknown file> [libpsm_infinipath.so.1.16]:0  263603.0
# 5988       <unknown file> [libpsm_infinipath.so.1.16]:0  257642.0
# 5978       <unknown file> [libpsm_infinipath.so.1.16]:0  257627.0
# 2997       <unknown file> [libpsm_infinipath.so.1.16]:0  257439.0
# 329        <unknown file> [libpsm_infinipath.so.1.16]:0  251661.0
# 327        <unknown file> [libpsm_infinipath.so.1.16]:0  245675.0
# 5987       <unknown file> [libpsm_infinipath.so.1.16]:0  245670.0
# 3010       <unknown file> [libpsm_infinipath.so.1.16]:0  245658.0
# 338        <unknown file> [libpsm_infinipath.so.1.16]:0  245658.0
# 5730       <unknown file> [libpsm_infinipath.so.1.16]:0  245646.0
# 5973       <unknown file> [libpsm_infinipath.so.1.16]:0  245638.0
# 5985       <unknown file> [libpsm_infinipath.so.1.16]:0  245633.0
# 5721       <unknown file> [libpsm_infinipath.so.1.16]:0  245482.0
# 3009       <unknown file> [libpsm_infinipath.so.1.16]:0  239647.0
# 3000       <unknown file> [libpsm_infinipath.so.1.16]:0  239609.0
# 5982       <unknown file> [libpsm_infinipath.so.1.16]:0  239609.0
# 3005       <unknown file> [libpsm_infinipath.so.1.16]:0  239601.0
# 340        <unknown file> [libpsm_infinipath.so.1.16]:0  239595.0
# 3006       <unknown file> [libpsm_infinipath.so.1.16]:0  233656.0
# 5732       <unknown file> [libpsm_infinipath.so.1.16]:0  233652.0
# 3233       <unknown file> [libpsm_infinipath.so.1.16]:0  233628.0
# 326        <unknown file> [libpsm_infinipath.so.1.16]:0  233475.0
# ...                                                 ...       ...
# 4601                             105:__GI___vsyslog_chk       0.0
# 4611                                      92:PMPI_Bcast       0.0
# 4600                             56:psm_deallocate_vbuf       0.0
# 4599                             56:psm_deallocate_vbuf       0.0
# 4598                             56:psm_deallocate_vbuf       0.0
# 4597                             56:psm_deallocate_vbuf       0.0
# 1916                                      92:PMPI_Bcast       0.0
# 4595  <unknown procedure> 0x26167 [libpsm_infinipath...       0.0
# 1917                                      92:PMPI_Bcast       0.0
# 4610                                      92:PMPI_Bcast       0.0
# 4612                                      92:PMPI_Bcast       0.0
# 4630                               1592:MPIR_Bcast_impl       0.0
# 4622                                      92:PMPI_Bcast       0.0
# 4629                               1592:MPIR_Bcast_impl       0.0
# 4628                               1592:MPIR_Bcast_impl       0.0
# 4627                               1592:MPIR_Bcast_impl       0.0
# 4626                                      92:PMPI_Bcast       0.0
# 4625                                      92:PMPI_Bcast       0.0
# 4624                                      92:PMPI_Bcast       0.0
# 4623                                      92:PMPI_Bcast       0.0
# 4621                                      92:PMPI_Bcast       0.0
# 4613                                      92:PMPI_Bcast       0.0
# 4620                                      92:PMPI_Bcast       0.0
# 4619                                      92:PMPI_Bcast       0.0
# 4618                                      92:PMPI_Bcast       0.0
# 4617                                      92:PMPI_Bcast       0.0
# 4616                                      92:PMPI_Bcast       0.0
# 4615                                      92:PMPI_Bcast       0.0
# 4614                                      92:PMPI_Bcast       0.0
# 0                                  <partial call paths>       0.0
#
#                          module
# 3002                Unknown(NA)
# 593                 Unknown(NA)
# 588                 Unknown(NA)
# 5986                Unknown(NA)
# 5989                Unknown(NA)
# 5979                Unknown(NA)
# 3237                Unknown(NA)
# 597                 Unknown(NA)
# 5972                Unknown(NA)
# 5988                Unknown(NA)
# 5978                Unknown(NA)
# 2997                Unknown(NA)
# 329                 Unknown(NA)
# 327                 Unknown(NA)
# 5987                Unknown(NA)
# 3010                Unknown(NA)
# 338                 Unknown(NA)
# 5730                Unknown(NA)
# 5973                Unknown(NA)
# 5985                Unknown(NA)
# 5721                Unknown(NA)
# 3009                Unknown(NA)
# 3000                Unknown(NA)
# 5982                Unknown(NA)
# 3005                Unknown(NA)
# 340                 Unknown(NA)
# 3006                Unknown(NA)
# 5732                Unknown(NA)
# 3233                Unknown(NA)
# 326                 Unknown(NA)
# ...                         ...
# 4601               libc-2.17.so
# 4611           libmpi.so.12.1.1
# 4600           libmpi.so.12.1.1
# 4599           libmpi.so.12.1.1
# 4598           libmpi.so.12.1.1
# 4597           libmpi.so.12.1.1
# 1916           libmpi.so.12.1.1
# 4595  libpsm_infinipath.so.1.16
# 1917           libmpi.so.12.1.1
# 4610           libmpi.so.12.1.1
# 4612           libmpi.so.12.1.1
# 4630           libmpi.so.12.1.1
# 4622           libmpi.so.12.1.1
# 4629           libmpi.so.12.1.1
# 4628           libmpi.so.12.1.1
# 4627           libmpi.so.12.1.1
# 4626           libmpi.so.12.1.1
# 4625           libmpi.so.12.1.1
# 4624           libmpi.so.12.1.1
# 4623           libmpi.so.12.1.1
# 4621           libmpi.so.12.1.1
# 4613           libmpi.so.12.1.1
# 4620           libmpi.so.12.1.1
# 4619           libmpi.so.12.1.1
# 4618           libmpi.so.12.1.1
# 4617           libmpi.so.12.1.1
# 4616           libmpi.so.12.1.1
# 4615           libmpi.so.12.1.1
# 4614           libmpi.so.12.1.1
# 0         <unknown load module>
#
# [8090 rows x 3 columns]
