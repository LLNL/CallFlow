# %%
import networkx as nx
import math
import json
from ast import literal_eval as make_tuple
from networkx.readwrite import json_graph

# %%
from logger import log
import utils
from pipeline import Pipeline

# %% [markdown]
# # Read Config file

# %%
from configFileReader import *
# configFileName = '/home/vidi/Work/llnl/CallFlow/config_files/scatter vs scatterv.json'
configFileName = '/home/vidi/Work/llnl/CallFlow/config_files/osu_bcast-rank=18.json'
config = configFileReader(configFileName)

# %%
print(config.callflow_path)
# Out:
# /home/vidi/Work/llnl/CallFlow/

# %% [markdown]
# # Converting to final NetworkX graph format

# %%
states = {}
datasets = config.datasets
pipeline = Pipeline(config)
states['ensemble'] = pipeline.read_ensemble_gf()
for idx, dataset in enumerate(datasets):
    dataset_name = dataset['name']
    states[dataset_name] = pipeline.read_dataset_gf(dataset_name)
# Out:
#  #  [Process] Reading the union dataframe and graph
#  #  [Process] Reading the dataframe and graph of state: osu_bcast.1.18.2019-09-03_11-33-15
#  #  [Process] Reading the dataframe and graph of state: osu_bcast.1.18.2019-09-03_12-29-49
#  #  [Process] Reading the dataframe and graph of state: osu_bcast.1.18.2019-09-03_10-33-44

# %%
print(states)
# Out:
# {'ensemble': <state.State object at 0x7f2214084438>, 'osu_bcast.1.18.2019-09-03_11-33-15': <state.State object at 0x7f21c033c4a8>, 'osu_bcast.1.18.2019-09-03_12-29-49': <state.State object at 0x7f21c033c470>, 'osu_bcast.1.18.2019-09-03_10-33-44': <state.State object at 0x7f21c033c710>}

# %%
class DistGraph(nx.Graph):
    # Attributes:
    # 1. State => Pass the state which needs to be handled.
    # 2. path => '', 'path', 'group_path' or 'component_path'
    # 3. construct_graph -> To decide if we should construct graph from path
    # 4. add_data => To 
    def __init__(self, state, path, group_by_attr='module', construct_graph=True, add_data=True):
        super(DistGraph, self).__init__()
        self.state = state
        self.path = path
        self.df = self.state.df
        self.group_by = group_by_attr
#         self.columns = ['time']
        self.columns = ['time (inc)', 'group_path', 'name', 'time', 'callers', 'callees', 'vis_name']
        
        if construct_graph:
            print('Creating a Graph for {0}.'.format(self.state.name))
            self.g = nx.DiGraph()
            self.add_paths(path)
        else:
            print('Using the existing graph from state {0}'.format(state.name))
            self.g = state.g

        self.adj_matrix = nx.adjacency_matrix(self.g)
        self.dense_adj_matrix = self.adj_matrix.todense()

        self.callbacks = []
        self.edge_direction = {}

        if add_data == True:
            self.add_node_attributes()
            self.add_edge_attributes()
        else:
            print('Creating a Graph without node or edge attributes.')
        self.adj_matrix = nx.adjacency_matrix(self.g)
        self.dense_adj_matrix = self.adj_matrix.todense()

    def no_cycle_path(self, path):
        ret = []
        mapper = {}
        for idx, elem in enumerate(path):
            if elem not in mapper:
                mapper[elem] = 1
                ret.append(elem)
            else:
                ret.append(elem + '_' + str(mapper[elem]))
                mapper[elem] += 1

        return tuple(ret)

    def add_paths(self, path):
        for idx, row in self.df.iterrows():
            if row.show_node:
                print(row[path], type(row[path]))
                if isinstance(row[path], list):
                    path_tuple = row[path]
                elif isinstance(row[path], str):
                    path_tuple = make_tuple(row[path])
                corrected_path = self.no_cycle_path(path_tuple)
                self.g.add_path(corrected_path)

    def add_edge_attributes(self):
        number_of_runs_mapping = self.number_of_runs()
        nx.set_edge_attributes(self.g, name="number_of_runs", values=number_of_runs_mapping)
        capacity_mapping = self.calculate_flows(self.g)
        nx.set_edge_attributes((self.g), name='weight', values=capacity_mapping)

    def number_of_runs(self):
        ret = {}
        for idx, name in enumerate(self.runs):           
            for edge in self.runs[name].edges():
                if edge not in ret:
                    ret[edge] = 0
                ret[edge] += 1
        return ret

    def add_union_node_attributes(self):
        for node in self.R.nodes(data=True):
            node_name = node[0]
            node_data = node[1]
            max_inc_time = 0
            max_exc_time = 0
            self.R.nodes[node_name]['ensemble'] = {}
            for dataset in node_data:
                for idx, key in enumerate(node_data[dataset]):
                    if(key == 'name'):
                        self.R.nodes[node_name]['union']['name'] = node_data[dataset][key]
                    elif(key == 'time (inc)'):
                        max_inc_time = max(max_inc_time, node_data[dataset][key])
                    elif(key == 'time'):
                        max_exc_time = max(max_exc_time, node_data[dataset][key])
                    elif(key == 'entry_functions'):
                        entry_functions = node_data[dataset][key]

            self.R.nodes[node_name]['ensemble']['time (inc)'] = max_inc_time
            self.R.nodes[node_name]['ensemble']['time'] = max_exc_time
            self.R.nodes[node_name]['ensemble']['entry_functions'] = entry_functions

    def add_node_attributes(self):
        ensemble_mapping = self.ensemble_map(self.g.nodes())
        
        for idx, key in enumerate(ensemble_mapping):
            nx.set_node_attributes(self.g, name=key, values=ensemble_mapping[key])
        
        dataset_mapping = {}
        for dataset in self.df['dataset'].unique():
            dataset_mapping[dataset] = self.dataset_map(self.g.nodes(), dataset)
            
            nx.set_node_attributes(self.g, name=dataset, values=dataset_mapping[dataset])

    def tailhead(self, edge):
        return (
         edge[0], edge[1])

    def tailheadDir(self, edge):
        return (
         str(edge[0]), str(edge[1]), self.edge_direction[edge])

    def add_edge_attributes(self):
        capacity_mapping = self.calculate_flows(self.g)
        nx.set_edge_attributes((self.g), name='weight', values=capacity_mapping)

    def leaves_below(self, graph, node):
        return set(sum(([vv for vv in v if graph.out_degree(vv) == 0] for k, v in nx.dfs_successors(graph, node).items()), []))

    def calculate_flows(self, graph):
        ret = {}
        edges = graph.edges()
        additional_flow = {}
        for edge in edges:
            source = edge[0]
            target = edge[1]
 
            source_inc = self.df.loc[(self.df['name'] == source)]["time (inc)"].max()
            target_inc = self.df.loc[(self.df['name'] == target)]["time (inc)"].max()
            if source_inc == target_inc:
                ret[edge] = source_inc
            else:
                ret[edge] = target_inc

        return ret
    
    def ensemble_map(self, nodes):
        ret = {}
        # loop through the nodes
        for node in self.g.nodes():

            # Get their dataframe
            node_df = self.df.loc[self.df["name"] == node]

            for column in self.columns:
                if column not in ret:
                    ret[column] = {}

                column_data = node_df[column]

                if column == "time (inc)" or column == "time" or column == "component_level":
                    if len(column_data.value_counts() > 0):
                        ret[column][node] = column_data.max()
                    else:
                        ret[column][node] = -1

                elif column == "callers" or column == "callees":
                    
                    if len(column_data.value_counts()) > 0:
                        ret[column][node] = make_tuple(column_data.tolist()[0])
                    else:
                        ret[column][node] = []

                elif column == "name" or column == "vis_name":
                    
                    if len(column_data.value_counts() > 0):
                        ret[column][node] = column_data.tolist()[0]
                    else:
                        ret[column][node] = "None"

                elif column == 'component_path' or column == 'group_path':

                    if len(column_data.value_counts() > 0):
                        ret[column][node] = list(make_tuple(column_data.tolist()[0]))
                    else:
                        ret[column][node] = []
        return ret

    def dataset_map(self, nodes, dataset):
        ret = {}
        for node in self.g.nodes():
            if node not in ret:
                ret[node] = {}

            node_df = self.df.loc[
                (self.df["name"] == node) & (self.df["dataset"] == dataset)
            ]

            for column in self.columns:
                column_data = node_df[column]

                if column == "time (inc)" or column == "time" or column == 'component_level':
                    if len(column_data.value_counts()) > 0:
                        ret[node][column] = column_data.max()
                    else:
                        ret[node][column] = -1

                elif column == "callers" or column == "callees":
                    if len(column_data.value_counts()) > 0:
                        ret[node][column] = make_tuple(column_data.tolist()[0])
                    else:
                        ret[node][column] = []

                elif column == "name" or column == "vis_name":
                    if len(column_data.value_counts()) > 0:
                        ret[node][column] = column_data.tolist()[0]

                    else:
                        ret[node][column] = "None"

                elif column == 'component_path' or column == 'group_path':

                    if len(column_data.value_counts() > 0):
                        ret[node][column] = list(make_tuple(column_data.tolist()[0]))
                    else:
                        ret[node][column] = []
        return ret

# %%
final_graph = DistGraph(states['ensemble'], '', construct_graph=False, add_data=True)
# Out:
# Using the existing graph from state ensemble

# %%
result = json_graph.node_link_data(final_graph.g)
final_result = json.dumps(result)

print(final_result)
# Out:
# {"directed": true, "multigraph": false, "graph": {}, "nodes": [{"show_node": true, "module": "libmonitor.so.0.0.0", "group_path": ["libmonitor.so.0.0.0=<program root>"], "component_path": ["libmonitor.so.0.0.0=<program root>", "<program root>"], "time (inc)": 1147289.0, "name": "<program root>", "time": 0.0, "callers": [], "callees": ["main"], "vis_name": "libmonitor.so.0.0.0=<program root>", "osu_bcast.1.18.2019-09-03_11-33-15": {"time (inc)": 1139918.0, "group_path": ["libmonitor.so.0.0.0=<program root>"], "name": "<program root>", "time": 0.0, "callers": [], "callees": ["main"], "vis_name": "libmonitor.so.0.0.0=<program root>"}, "osu_bcast.1.18.2019-09-03_12-29-49": {"time (inc)": 1140997.0, "group_path": ["libmonitor.so.0.0.0=<program root>"], "name": "<program root>", "time": 0.0, "callers": [], "callees": ["main"], "vis_name": "libmonitor.so.0.0.0=<program root>"}, "osu_bcast.1.18.2019-09-03_10-33-44": {"time (inc)": 1147289.0, "group_path": ["libmonitor.so.0.0.0=<program root>"], "name": "<program root>", "time": 0.0, "callers": [], "callees": ["main"], "vis_name": "libmonitor.so.0.0.0=<program root>"}, "id": "<program root>"}, {"show_node": true, "module": "osu_bcast", "group_path": ["libmonitor.so.0.0.0=<program root>", "osu_bcast=main"], "component_path": ["osu_bcast=main", "main"], "time (inc)": 1147289.0, "name": "main", "time": 0.0, "callers": [], "callees": ["117:free_buffer", "119:MPI_Finalize", "36:MPI_Init", "92:PMPI_Bcast", "98:PMPI_Barrier"], "vis_name": "osu_bcast=main", "osu_bcast.1.18.2019-09-03_11-33-15": {"time (inc)": 1139918.0, "group_path": ["libmonitor.so.0.0.0=<program root>", "osu_bcast=main"], "name": "main", "time": 0.0, "callers": [], "callees": ["117:free_buffer", "119:MPI_Finalize", "36:MPI_Init", "92:PMPI_Bcast", "98:PMPI_Barrier"], "vis_name": "osu_bcast=main"}, "osu_bcast.1.18.2019-09-03_12-29-49": {"time (inc)": 1140997.0, "group_path": ["libmonitor.so.0.0.0=<program root>", "osu_bcast=main"], "name": "main", "time": 0.0, "callers": [], "callees": ["106:PMPI_Reduce", "119:MPI_Finalize", "36:MPI_Init", "92:PMPI_Bcast", "98:PMPI_Barrier"], "vis_name": "osu_bcast=main"}, "osu_bcast.1.18.2019-09-03_10-33-44": {"time (inc)": 1147289.0, "group_path": ["libmonitor.so.0.0.0=<program root>", "osu_bcast=main"], "name": "main", "time": 0.0, "callers": [], "callees": ["/builddir/build/BUILD/mvapich2-2.3/src/mpi/coll/ch3_shmem_coll.c", "119:MPI_Finalize", "36:MPI_Init", "92:PMPI_Bcast", "93:PMPI_Wtime", "98:PMPI_Barrier"], "vis_name": "osu_bcast=main"}, "id": "main"}, {"show_node": false, "module": "libmonitor.so.0.0.0", "group_path": ["libmonitor.so.0.0.0=<program root>", "osu_bcast=main", "libmonitor.so.0.0.0=119:MPI_Finalize"], "component_path": ["libmonitor.so.0.0.0=119:MPI_Finalize", "<program root>", "119:MPI_Finalize"], "time (inc)": 1007833.0, "name": "119:MPI_Finalize", "time": 0.0, "callers": [], "callees": ["PMPI_Finalize"], "vis_name": "libmonitor.so.0.0.0=119:MPI_Finalize", "osu_bcast.1.18.2019-09-03_11-33-15": {"time (inc)": 1006561.0, "group_path": ["libmonitor.so.0.0.0=<program root>", "osu_bcast=main", "libmonitor.so.0.0.0=119:MPI_Finalize"], "name": "119:MPI_Finalize", "time": 0.0, "callers": [], "callees": ["PMPI_Finalize"], "vis_name": "libmonitor.so.0.0.0=119:MPI_Finalize"}, "osu_bcast.1.18.2019-09-03_12-29-49": {"time (inc)": 1007833.0, "group_path": ["libmonitor.so.0.0.0=<program root>", "osu_bcast=main", "libmonitor.so.0.0.0=119:MPI_Finalize"], "name": "119:MPI_Finalize", "time": 0.0, "callers": [], "callees": ["PMPI_Finalize"], "vis_name": "libmonitor.so.0.0.0=119:MPI_Finalize"}, "osu_bcast.1.18.2019-09-03_10-33-44": {"time (inc)": 1007467.0, "group_path": ["libmonitor.so.0.0.0=<program root>", "osu_bcast=main", "libmonitor.so.0.0.0=119:MPI_Finalize"], "name": "119:MPI_Finalize", "time": 0.0, "callers": [], "callees": ["PMPI_Finalize"], "vis_name": "libmonitor.so.0.0.0=119:MPI_Finalize"}, "id": "119:MPI_Finalize"}, {"show_node": true, "module": "libmpi.so.12.1.1", "group_path" ...

# %%
df  = states['ensemble'].df
# name_grouped = df.groupby(['name'])

def addID(name):
    if(":" in name and '[' not in name):
        name = name.split(':')[len(name.split(':')) - 1]
    elif('[' in name and ':' not in name):
        name = name.split('[')[0]
    elif('[' in name and ':' in name):
        name = name.split(':')[len(name.split(':')) - 1]
        name = name.split('[')[0]
    else:
        name = name
        
    name = name.replace(' ', '_')
    return name


df['id'] = df['name'].apply(addID)
print(df['id'].unique())
# Out:
# ['<program_root>' 'main' 'MPI_Finalize' 'PMPI_Finalize' 'MPID_Finalize'
#  'psm_dofinalize' '<unknown_procedure>_0x188fe_'
#  '<unknown_procedure>_0x20e9e_' '<unknown_procedure>_0x26058_'
#  '<unknown_procedure>_0x1c083_' '0' '<unknown_procedure>_0x26068_'
#  '<unknown_procedure>_0x1c088_' '<unknown_procedure>_0x2607b_'
#  '<unknown_procedure>_0x33e76_' '<unknown_procedure>_0x33faf_'
#  '<unknown_procedure>_0x33e96_' '<unknown_procedure>_0x26155_'
#  '_getopt_internal_r' '716' 'PMPI_Bcast' 'MPIR_Bcast_impl'
#  'MPIR_Bcast_MV2' 'MPIR_Bcast_index_tuned_intra_MV2'
#  'MPIR_Bcast_tune_inter_node_helper_MV2'
#  'MPIR_Knomial_Bcast_inter_node_wrapper_MV2'
#  'MPIR_Knomial_Bcast_inter_node_MV2' 'MPIR_Shmem_Bcast_MV2'
#  'mv2_shm_bcast' '__intel_ssse3_rep_memcpy' 'PMPI_Barrier'
#  'MPIR_Barrier_impl' 'MPIR_Barrier_MV2' 'MPIR_shmem_barrier_MV2']

# %%
print(df)
# Out:
#                                                    node  rank  time (inc)  \
# 0        {'name': '<program root>', 'type': 'function'}     0   1137801.0
# 1        {'name': '<program root>', 'type': 'function'}     1   1138697.0
# 2        {'name': '<program root>', 'type': 'function'}     2   1139761.0
# 3        {'name': '<program root>', 'type': 'function'}     3   1138632.0
# 4        {'name': '<program root>', 'type': 'function'}     4   1139897.0
# 5        {'name': '<program root>', 'type': 'function'}     5   1138673.0
# 6        {'name': '<program root>', 'type': 'function'}     6   1138695.0
# 7        {'name': '<program root>', 'type': 'function'}     7   1137887.0
# 8        {'name': '<program root>', 'type': 'function'}     8   1137662.0
# 9        {'name': '<program root>', 'type': 'function'}     9   1139533.0
# 10       {'name': '<program root>', 'type': 'function'}    10   1133592.0
# 11       {'name': '<program root>', 'type': 'function'}    11   1137557.0
# 12       {'name': '<program root>', 'type': 'function'}    12   1139633.0
# 13       {'name': '<program root>', 'type': 'function'}    13   1139652.0
# 14       {'name': '<program root>', 'type': 'function'}    14   1139707.0
# 15       {'name': '<program root>', 'type': 'function'}    15   1138706.0
# 16       {'name': '<program root>', 'type': 'function'}    16   1139789.0
# 17       {'name': '<program root>', 'type': 'function'}    17   1139918.0
# 18                 {'name': 'main', 'type': 'function'}     0   1137801.0
# 19                 {'name': 'main', 'type': 'function'}     1   1138697.0
# 20                 {'name': 'main', 'type': 'function'}     2   1139761.0
# 21                 {'name': 'main', 'type': 'function'}     3   1138632.0
# 22                 {'name': 'main', 'type': 'function'}     4   1139897.0
# 23                 {'name': 'main', 'type': 'function'}     5   1138673.0
# 24                 {'name': 'main', 'type': 'function'}     6   1138695.0
# 25                 {'name': 'main', 'type': 'function'}     7   1137887.0
# 26                 {'name': 'main', 'type': 'function'}     8   1137662.0
# 27                 {'name': 'main', 'type': 'function'}     9   1139533.0
# 28                 {'name': 'main', 'type': 'function'}    10   1133592.0
# 29                 {'name': 'main', 'type': 'function'}    11   1137557.0
# ...                                                 ...   ...         ...
# 1466  {'name': '1197:mv2_shm_bcast', 'type': 'functi...    10    103284.0
# 1467  {'name': '1197:mv2_shm_bcast', 'type': 'functi...    11     96281.0
# 1468  {'name': '1197:mv2_shm_bcast', 'type': 'functi...    12    103211.0
# 1469  {'name': '1197:mv2_shm_bcast', 'type': 'functi...    13     96299.0
# 1470  {'name': '1197:mv2_shm_bcast', 'type': 'functi...    14    103227.0
# 1471  {'name': '1197:mv2_shm_bcast', 'type': 'functi...    15     90234.0
# 1472  {'name': '1197:mv2_shm_bcast', 'type': 'functi...    16     84316.0
# 1473  {'name': '1197:mv2_shm_bcast', 'type': 'functi...    17     91340.0
# 1474  {'name': '3820:__intel_ssse3_rep_memcpy', 'typ...     9     78739.0
# 1475  {'name': '3820:__intel_ssse3_rep_memcpy', 'typ...    10     84817.0
# 1476  {'name': '3820:__intel_ssse3_rep_memcpy', 'typ...    11     77819.0
# 1477  {'name': '3820:__intel_ssse3_rep_memcpy', 'typ...    12     84747.0
# 1478  {'name': '3820:__intel_ssse3_rep_memcpy', 'typ...    13     77817.0
# 1479  {'name': '3820:__intel_ssse3_rep_memcpy', 'typ...    14     84683.0
# 1480  {'name': '3820:__intel_ssse3_rep_memcpy', 'typ...    15     59762.0
# 1481  {'name': '3820:__intel_ssse3_rep_memcpy', 'typ...    16     59766.0
# 1482  {'name': '3820:__intel_ssse3_rep_memcpy', 'typ...    17     66869.0
# 1483  {'file': '<unknown file> [osu_bcast]', 'line':...     9     78739.0
# 1484  {'file': '<unknown file> [osu_bcast]', 'line':...    10     84817.0
# 1485  {'file': '<unknown file> [osu_bcast]', 'line':...    11     77819.0
# 1486  {'file': '<unknown file> [osu_bcast]', 'line':...    12     84747.0
# 1487  {'file': '<unknown file> [osu_bcast]', 'line':...    13     77817.0
# 1488  {'file': '<unknown file> [osu_bcast]', 'line':...    14     84683.0
# 1489  {'file': '<unknown file> [osu_bcast]', 'line':...    15     59762.0
# 1490  {'file': '<unknown file> [osu_bcast]', 'line':...    16     59766.0
# 1491  {'file': '<unknown file> [osu_bcast]', 'line':...    17     66869.0
# 1492    {'name': '98:PMPI_Barrier', 'type': 'function'}     0     71302.0
# 1493  {'name': '421:MPIR_Barrier_impl', 'type': 'fun...     0     71302.0
# 1494  {'name': '331:MPIR_Barrier_MV2', 'type': 'func...     0     71302.0
# 1495  {'name': '210:MPIR_shmem_barrier_MV2', 'type':...     0     71302.0
#
#          time  nid                                               file  line  \
# 0         0.0    6               <unknown file> [libmonitor.so.0.0.0]     0
# 1         0.0    6               <unknown file> [libmonitor.so.0.0.0]     0
# 2         0.0    6               <unknown file> [libmonitor.so.0.0.0]     0
# 3         0.0    6               <unknown file> [libmonitor.so.0.0.0]     0
# 4         0.0    6               <unknown file> [libmonitor.so.0.0.0]     0
# 5         0.0    6               <unknown file> [libmonitor.so.0.0.0]     0
# 6         0.0    6               <unknown file> [libmonitor.so.0.0.0]     0
# 7         0.0    6               <unknown file> [libmonitor.so.0.0.0]     0
# 8         0.0    6               <unknown file> [libmonitor.so.0.0.0]     0
# 9         0.0    6               <unknown file> [libmonitor.so.0.0.0]     0
# 10        0.0    6               <unknown file> [libmonitor.so.0.0.0]     0
# 11        0.0    6               <unknown file> [libmonitor.so.0.0.0]     0
# 12        0.0    6               <unknown file> [libmonitor.so.0.0.0]     0
# 13        0.0    6               <unknown file> [libmonitor.so.0.0.0]     0
# 14        0.0    6               <unknown file> [libmonitor.so.0.0.0]     0
# 15        0.0    6               <unknown file> [libmonitor.so.0.0.0]     0
# 16        0.0    6               <unknown file> [libmonitor.so.0.0.0]     0
# 17        0.0    6               <unknown file> [libmonitor.so.0.0.0]     0
# 18        0.0    8  ./src/g/g92/rahim/repos/osu-micro-benchmarks-5...    36
# 19        0.0    8  ./src/g/g92/rahim/repos/osu-micro-benchmarks-5...    36
# 20        0.0    8  ./src/g/g92/rahim/repos/osu-micro-benchmarks-5...    36
# 21        0.0    8  ./src/g/g92/rahim/repos/osu-micro-benchmarks-5...    36
# 22        0.0    8  ./src/g/g92/rahim/repos/osu-micro-benchmarks-5...    36
# 23        0.0    8  ./src/g/g92/rahim/repos/osu-micro-benchmarks-5...    36
# 24        0.0    8  ./src/g/g92/rahim/repos/osu-micro-benchmarks-5...    36
# 25        0.0    8  ./src/g/g92/rahim/repos/osu-micro-benchmarks-5...    36
# 26        0.0    8  ./src/g/g92/rahim/repos/osu-micro-benchmarks-5...    36
# 27        0.0    8  ./src/g/g92/rahim/repos/osu-micro-benchmarks-5...    36
# 28        0.0    8  ./src/g/g92/rahim/repos/osu-micro-benchmarks-5...    36
# 29        0.0    8  ./src/g/g92/rahim/repos/osu-micro-benchmarks-5...    36
# ...       ...  ...                                                ...   ...
# 1466      0.0  121  /builddir/build/BUILD/mvapich2-2.3/src/mpi/col...  3801
# 1467      0.0  121  /builddir/build/BUILD/mvapich2-2.3/src/mpi/col...  3801
# 1468      0.0  121  /builddir/build/BUILD/mvapich2-2.3/src/mpi/col...  3801
# 1469      0.0  121  /builddir/build/BUILD/mvapich2-2.3/src/mpi/col...  3801
# 1470      0.0  121  /builddir/build/BUILD/mvapich2-2.3/src/mpi/col...  3801
# 1471      0.0  121  /builddir/build/BUILD/mvapich2-2.3/src/mpi/col...  3801
# 1472      0.0  121  /builddir/build/BUILD/mvapich2-2.3/src/mpi/col...  3801
# 1473      0.0  121  /builddir/build/BUILD/mvapich2-2.3/src/mpi/col...  3801
# 1474      0.0  153                         <unknown file> [osu_bcast]     0
# 1475      0.0  153                         <unknown file> [osu_bcast]     0
# 1476      0.0  153                         <unknown file> [osu_bcast]     0
# 1477      0.0  153                         <unknown file> [osu_bcast]     0
# 1478      0.0  153                         <unknown file> [osu_bcast]     0
# 1479      0.0  153                         <unknown file> [osu_bcast]     0
# 1480      0.0  153                         <unknown file> [osu_bcast]     0
# 1481      0.0  153                         <unknown file> [osu_bcast]     0
# 1482      0.0  153                         <unknown file> [osu_bcast]     0
# 1483  78739.0  154                         <unknown file> [osu_bcast]     0
# 1484  84817.0  154                         <unknown file> [osu_bcast]     0
# 1485  77819.0  154                         <unknown file> [osu_bcast]     0
# 1486  84747.0  154                         <unknown file> [osu_bcast]     0
# 1487  77817.0  154                         <unknown file> [osu_bcast]     0
# 1488  84683.0  154                         <unknown file> [osu_bcast]     0
# 1489  59762.0  154                         <unknown file> [osu_bcast]     0
# 1490  59766.0  154                         <unknown file> [osu_bcast]     0
# 1491  66869.0  154                         <unknown file> [osu_bcast]     0
# 1492      0.0  199  /builddir/build/BUILD/mvapich2-2.3/src/mpi/col...   421
# 1493      0.0  201  /builddir/build/BUILD/mvapich2-2.3/src/mpi/col...   331
# 1494      0.0  203  /builddir/build/BUILD/mvapich2-2.3/src/mpi/col...   210
# 1495      0.0  205  /builddir/build/BUILD/mvapich2-2.3/src/mpi/col...   123
#
#                    module                           name type  ...  show_node  \
# 0     libmonitor.so.0.0.0                 <program root>   PF  ...       True
# 1     libmonitor.so.0.0.0                 <program root>   PF  ...       True
# 2     libmonitor.so.0.0.0                 <program root>   PF  ...       True
# 3     libmonitor.so.0.0.0                 <program root>   PF  ...       True
# 4     libmonitor.so.0.0.0                 <program root>   PF  ...       True
# 5     libmonitor.so.0.0.0                 <program root>   PF  ...       True
# 6     libmonitor.so.0.0.0                 <program root>   PF  ...       True
# 7     libmonitor.so.0.0.0                 <program root>   PF  ...       True
# 8     libmonitor.so.0.0.0                 <program root>   PF  ...       True
# 9     libmonitor.so.0.0.0                 <program root>   PF  ...       True
# 10    libmonitor.so.0.0.0                 <program root>   PF  ...       True
# 11    libmonitor.so.0.0.0                 <program root>   PF  ...       True
# 12    libmonitor.so.0.0.0                 <program root>   PF  ...       True
# 13    libmonitor.so.0.0.0                 <program root>   PF  ...       True
# 14    libmonitor.so.0.0.0                 <program root>   PF  ...       True
# 15    libmonitor.so.0.0.0                 <program root>   PF  ...       True
# 16    libmonitor.so.0.0.0                 <program root>   PF  ...       True
# 17    libmonitor.so.0.0.0                 <program root>   PF  ...       True
# 18              osu_bcast                           main   PF  ...       True
# 19              osu_bcast                           main   PF  ...       True
# 20              osu_bcast                           main   PF  ...       True
# 21              osu_bcast                           main   PF  ...       True
# 22              osu_bcast                           main   PF  ...       True
# 23              osu_bcast                           main   PF  ...       True
# 24              osu_bcast                           main   PF  ...       True
# 25              osu_bcast                           main   PF  ...       True
# 26              osu_bcast                           main   PF  ...       True
# 27              osu_bcast                           main   PF  ...       True
# 28              osu_bcast                           main   PF  ...       True
# 29              osu_bcast                           main   PF  ...       True
# ...                   ...                            ...  ...  ...        ...
# 1466     libmpi.so.12.1.1             1197:mv2_shm_bcast   PF  ...      False
# 1467     libmpi.so.12.1.1             1197:mv2_shm_bcast   PF  ...      False
# 1468     libmpi.so.12.1.1             1197:mv2_shm_bcast   PF  ...      False
# 1469     libmpi.so.12.1.1             1197:mv2_shm_bcast   PF  ...      False
# 1470     libmpi.so.12.1.1             1197:mv2_shm_bcast   PF  ...      False
# 1471     libmpi.so.12.1.1             1197:mv2_shm_bcast   PF  ...      False
# 1472     libmpi.so.12.1.1             1197:mv2_shm_bcast   PF  ...      False
# 1473     libmpi.so.12.1.1             1197:mv2_shm_bcast   PF  ...      False
# 1474                  NaN  3820:__intel_ssse3_rep_memcpy   PF  ...        NaN
# 1475                  NaN  3820:__intel_ssse3_rep_memcpy   PF  ...        NaN
# 1476                  NaN  3820:__intel_ssse3_rep_memcpy   PF  ...        NaN
# 1477                  NaN  3820:__intel_ssse3_rep_memcpy   PF  ...        NaN
# 1478                  NaN  3820:__intel_ssse3_rep_memcpy   PF  ...        NaN
# 1479                  NaN  3820:__intel_ssse3_rep_memcpy   PF  ...        NaN
# 1480                  NaN  3820:__intel_ssse3_rep_memcpy   PF  ...        NaN
# 1481                  NaN  3820:__intel_ssse3_rep_memcpy   PF  ...        NaN
# 1482                  NaN  3820:__intel_ssse3_rep_memcpy   PF  ...        NaN
# 1483                  NaN   <unknown file> [osu_bcast]:0    S  ...        NaN
# 1484                  NaN   <unknown file> [osu_bcast]:0    S  ...        NaN
# 1485                  NaN   <unknown file> [osu_bcast]:0    S  ...        NaN
# 1486                  NaN   <unknown file> [osu_bcast]:0    S  ...        NaN
# 1487                  NaN   <unknown file> [osu_bcast]:0    S  ...        NaN
# 1488                  NaN   <unknown file> [osu_bcast]:0    S  ...        NaN
# 1489                  NaN   <unknown file> [osu_bcast]:0    S  ...        NaN
# 1490                  NaN   <unknown file> [osu_bcast]:0    S  ...        NaN
# 1491                  NaN   <unknown file> [osu_bcast]:0    S  ...        NaN
# 1492     libmpi.so.12.1.1                98:PMPI_Barrier   PF  ...       True
# 1493     libmpi.so.12.1.1          421:MPIR_Barrier_impl   PF  ...      False
# 1494     libmpi.so.12.1.1           331:MPIR_Barrier_MV2   PF  ...      False
# 1495                  NaN     210:MPIR_shmem_barrier_MV2   PF  ...        NaN
#
#                       vis_node_name                             dataset  \
# 0                    <program root>  osu_bcast.1.18.2019-09-03_11-33-15
# 1                    <program root>  osu_bcast.1.18.2019-09-03_11-33-15
# 2                    <program root>  osu_bcast.1.18.2019-09-03_11-33-15
# 3                    <program root>  osu_bcast.1.18.2019-09-03_11-33-15
# 4                    <program root>  osu_bcast.1.18.2019-09-03_11-33-15
# 5                    <program root>  osu_bcast.1.18.2019-09-03_11-33-15
# 6                    <program root>  osu_bcast.1.18.2019-09-03_11-33-15
# 7                    <program root>  osu_bcast.1.18.2019-09-03_11-33-15
# 8                    <program root>  osu_bcast.1.18.2019-09-03_11-33-15
# 9                    <program root>  osu_bcast.1.18.2019-09-03_11-33-15
# 10                   <program root>  osu_bcast.1.18.2019-09-03_11-33-15
# 11                   <program root>  osu_bcast.1.18.2019-09-03_11-33-15
# 12                   <program root>  osu_bcast.1.18.2019-09-03_11-33-15
# 13                   <program root>  osu_bcast.1.18.2019-09-03_11-33-15
# 14                   <program root>  osu_bcast.1.18.2019-09-03_11-33-15
# 15                   <program root>  osu_bcast.1.18.2019-09-03_11-33-15
# 16                   <program root>  osu_bcast.1.18.2019-09-03_11-33-15
# 17                   <program root>  osu_bcast.1.18.2019-09-03_11-33-15
# 18                             main  osu_bcast.1.18.2019-09-03_11-33-15
# 19                             main  osu_bcast.1.18.2019-09-03_11-33-15
# 20                             main  osu_bcast.1.18.2019-09-03_11-33-15
# 21                             main  osu_bcast.1.18.2019-09-03_11-33-15
# 22                             main  osu_bcast.1.18.2019-09-03_11-33-15
# 23                             main  osu_bcast.1.18.2019-09-03_11-33-15
# 24                             main  osu_bcast.1.18.2019-09-03_11-33-15
# 25                             main  osu_bcast.1.18.2019-09-03_11-33-15
# 26                             main  osu_bcast.1.18.2019-09-03_11-33-15
# 27                             main  osu_bcast.1.18.2019-09-03_11-33-15
# 28                             main  osu_bcast.1.18.2019-09-03_11-33-15
# 29                             main  osu_bcast.1.18.2019-09-03_11-33-15
# ...                             ...                                 ...
# 1466             1197:mv2_shm_bcast  osu_bcast.1.18.2019-09-03_10-33-44
# 1467             1197:mv2_shm_bcast  osu_bcast.1.18.2019-09-03_10-33-44
# 1468             1197:mv2_shm_bcast  osu_bcast.1.18.2019-09-03_10-33-44
# 1469             1197:mv2_shm_bcast  osu_bcast.1.18.2019-09-03_10-33-44
# 1470             1197:mv2_shm_bcast  osu_bcast.1.18.2019-09-03_10-33-44
# 1471             1197:mv2_shm_bcast  osu_bcast.1.18.2019-09-03_10-33-44
# 1472             1197:mv2_shm_bcast  osu_bcast.1.18.2019-09-03_10-33-44
# 1473             1197:mv2_shm_bcast  osu_bcast.1.18.2019-09-03_10-33-44
# 1474  3820:__intel_ssse3_rep_memcpy  osu_bcast.1.18.2019-09-03_10-33-44
# 1475  3820:__intel_ssse3_rep_memcpy  osu_bcast.1.18.2019-09-03_10-33-44
# 1476  3820:__intel_ssse3_rep_memcpy  osu_bcast.1.18.2019-09-03_10-33-44
# 1477  3820:__intel_ssse3_rep_memcpy  osu_bcast.1.18.2019-09-03_10-33-44
# 1478  3820:__intel_ssse3_rep_memcpy  osu_bcast.1.18.2019-09-03_10-33-44
# 1479  3820:__intel_ssse3_rep_memcpy  osu_bcast.1.18.2019-09-03_10-33-44
# 1480  3820:__intel_ssse3_rep_memcpy  osu_bcast.1.18.2019-09-03_10-33-44
# 1481  3820:__intel_ssse3_rep_memcpy  osu_bcast.1.18.2019-09-03_10-33-44
# 1482  3820:__intel_ssse3_rep_memcpy  osu_bcast.1.18.2019-09-03_10-33-44
# 1483   <unknown file> [osu_bcast]:0  osu_bcast.1.18.2019-09-03_10-33-44
# 1484   <unknown file> [osu_bcast]:0  osu_bcast.1.18.2019-09-03_10-33-44
# 1485   <unknown file> [osu_bcast]:0  osu_bcast.1.18.2019-09-03_10-33-44
# 1486   <unknown file> [osu_bcast]:0  osu_bcast.1.18.2019-09-03_10-33-44
# 1487   <unknown file> [osu_bcast]:0  osu_bcast.1.18.2019-09-03_10-33-44
# 1488   <unknown file> [osu_bcast]:0  osu_bcast.1.18.2019-09-03_10-33-44
# 1489   <unknown file> [osu_bcast]:0  osu_bcast.1.18.2019-09-03_10-33-44
# 1490   <unknown file> [osu_bcast]:0  osu_bcast.1.18.2019-09-03_10-33-44
# 1491   <unknown file> [osu_bcast]:0  osu_bcast.1.18.2019-09-03_10-33-44
# 1492                98:PMPI_Barrier  osu_bcast.1.18.2019-09-03_10-33-44
# 1493          421:MPIR_Barrier_impl  osu_bcast.1.18.2019-09-03_10-33-44
# 1494           331:MPIR_Barrier_MV2  osu_bcast.1.18.2019-09-03_10-33-44
# 1495     210:MPIR_shmem_barrier_MV2  osu_bcast.1.18.2019-09-03_10-33-44
#
#                                              group_path  \
# 0               ('libmonitor.so.0.0.0=<program root>',)
# 1               ('libmonitor.so.0.0.0=<program root>',)
# 2               ('libmonitor.so.0.0.0=<program root>',)
# 3               ('libmonitor.so.0.0.0=<program root>',)
# 4               ('libmonitor.so.0.0.0=<program root>',)
# 5               ('libmonitor.so.0.0.0=<program root>',)
# 6               ('libmonitor.so.0.0.0=<program root>',)
# 7               ('libmonitor.so.0.0.0=<program root>',)
# 8               ('libmonitor.so.0.0.0=<program root>',)
# 9               ('libmonitor.so.0.0.0=<program root>',)
# 10              ('libmonitor.so.0.0.0=<program root>',)
# 11              ('libmonitor.so.0.0.0=<program root>',)
# 12              ('libmonitor.so.0.0.0=<program root>',)
# 13              ('libmonitor.so.0.0.0=<program root>',)
# 14              ('libmonitor.so.0.0.0=<program root>',)
# 15              ('libmonitor.so.0.0.0=<program root>',)
# 16              ('libmonitor.so.0.0.0=<program root>',)
# 17              ('libmonitor.so.0.0.0=<program root>',)
# 18    ('libmonitor.so.0.0.0=<program root>', 'osu_bc...
# 19    ('libmonitor.so.0.0.0=<program root>', 'osu_bc...
# 20    ('libmonitor.so.0.0.0=<program root>', 'osu_bc...
# 21    ('libmonitor.so.0.0.0=<program root>', 'osu_bc...
# 22    ('libmonitor.so.0.0.0=<program root>', 'osu_bc...
# 23    ('libmonitor.so.0.0.0=<program root>', 'osu_bc...
# 24    ('libmonitor.so.0.0.0=<program root>', 'osu_bc...
# 25    ('libmonitor.so.0.0.0=<program root>', 'osu_bc...
# 26    ('libmonitor.so.0.0.0=<program root>', 'osu_bc...
# 27    ('libmonitor.so.0.0.0=<program root>', 'osu_bc...
# 28    ('libmonitor.so.0.0.0=<program root>', 'osu_bc...
# 29    ('libmonitor.so.0.0.0=<program root>', 'osu_bc...
# ...                                                 ...
# 1466  ('libmonitor.so.0.0.0=<program root>', 'osu_bc...
# 1467  ('libmonitor.so.0.0.0=<program root>', 'osu_bc...
# 1468  ('libmonitor.so.0.0.0=<program root>', 'osu_bc...
# 1469  ('libmonitor.so.0.0.0=<program root>', 'osu_bc...
# 1470  ('libmonitor.so.0.0.0=<program root>', 'osu_bc...
# 1471  ('libmonitor.so.0.0.0=<program root>', 'osu_bc...
# 1472  ('libmonitor.so.0.0.0=<program root>', 'osu_bc...
# 1473  ('libmonitor.so.0.0.0=<program root>', 'osu_bc...
# 1474                                                NaN
# 1475                                                NaN
# 1476                                                NaN
# 1477                                                NaN
# 1478                                                NaN
# 1479                                                NaN
# 1480                                                NaN
# 1481                                                NaN
# 1482                                                NaN
# 1483                                                NaN
# 1484                                                NaN
# 1485                                                NaN
# 1486                                                NaN
# 1487                                                NaN
# 1488                                                NaN
# 1489                                                NaN
# 1490                                                NaN
# 1491                                                NaN
# 1492  ('libmonitor.so.0.0.0=<program root>', 'osu_bc...
# 1493  ('libmonitor.so.0.0.0=<program root>', 'osu_bc...
# 1494  ('libmonitor.so.0.0.0=<program root>', 'osu_bc...
# 1495                                                NaN
#
#                                          component_path  \
# 0     ('libmonitor.so.0.0.0=<program root>', '<progr...
# 1     ('libmonitor.so.0.0.0=<program root>', '<progr...
# 2     ('libmonitor.so.0.0.0=<program root>', '<progr...
# 3     ('libmonitor.so.0.0.0=<program root>', '<progr...
# 4     ('libmonitor.so.0.0.0=<program root>', '<progr...
# 5     ('libmonitor.so.0.0.0=<program root>', '<progr...
# 6     ('libmonitor.so.0.0.0=<program root>', '<progr...
# 7     ('libmonitor.so.0.0.0=<program root>', '<progr...
# 8     ('libmonitor.so.0.0.0=<program root>', '<progr...
# 9     ('libmonitor.so.0.0.0=<program root>', '<progr...
# 10    ('libmonitor.so.0.0.0=<program root>', '<progr...
# 11    ('libmonitor.so.0.0.0=<program root>', '<progr...
# 12    ('libmonitor.so.0.0.0=<program root>', '<progr...
# 13    ('libmonitor.so.0.0.0=<program root>', '<progr...
# 14    ('libmonitor.so.0.0.0=<program root>', '<progr...
# 15    ('libmonitor.so.0.0.0=<program root>', '<progr...
# 16    ('libmonitor.so.0.0.0=<program root>', '<progr...
# 17    ('libmonitor.so.0.0.0=<program root>', '<progr...
# 18                           ('osu_bcast=main', 'main')
# 19                           ('osu_bcast=main', 'main')
# 20                           ('osu_bcast=main', 'main')
# 21                           ('osu_bcast=main', 'main')
# 22                           ('osu_bcast=main', 'main')
# 23                           ('osu_bcast=main', 'main')
# 24                           ('osu_bcast=main', 'main')
# 25                           ('osu_bcast=main', 'main')
# 26                           ('osu_bcast=main', 'main')
# 27                           ('osu_bcast=main', 'main')
# 28                           ('osu_bcast=main', 'main')
# 29                           ('osu_bcast=main', 'main')
# ...                                                 ...
# 1466  ('libmpi.so.12.1.1=92:PMPI_Bcast', '92:PMPI_Bc...
# 1467  ('libmpi.so.12.1.1=92:PMPI_Bcast', '92:PMPI_Bc...
# 1468  ('libmpi.so.12.1.1=92:PMPI_Bcast', '92:PMPI_Bc...
# 1469  ('libmpi.so.12.1.1=92:PMPI_Bcast', '92:PMPI_Bc...
# 1470  ('libmpi.so.12.1.1=92:PMPI_Bcast', '92:PMPI_Bc...
# 1471  ('libmpi.so.12.1.1=92:PMPI_Bcast', '92:PMPI_Bc...
# 1472  ('libmpi.so.12.1.1=92:PMPI_Bcast', '92:PMPI_Bc...
# 1473  ('libmpi.so.12.1.1=92:PMPI_Bcast', '92:PMPI_Bc...
# 1474                                                NaN
# 1475                                                NaN
# 1476                                                NaN
# 1477                                                NaN
# 1478                                                NaN
# 1479                                                NaN
# 1480                                                NaN
# 1481                                                NaN
# 1482                                                NaN
# 1483                                                NaN
# 1484                                                NaN
# 1485                                                NaN
# 1486                                                NaN
# 1487                                                NaN
# 1488                                                NaN
# 1489                                                NaN
# 1490                                                NaN
# 1491                                                NaN
# 1492  ('libmpi.so.12.1.1=98:PMPI_Barrier', '98:PMPI_...
# 1493  ('libmpi.so.12.1.1=98:PMPI_Barrier', '98:PMPI_...
# 1494  ('libmpi.so.12.1.1=98:PMPI_Barrier', '98:PMPI_...
# 1495                                                NaN
#
#                                     vis_name component_level change_name  \
# 0         libmonitor.so.0.0.0=<program root>             2.0       False
# 1         libmonitor.so.0.0.0=<program root>             2.0       False
# 2         libmonitor.so.0.0.0=<program root>             2.0       False
# 3         libmonitor.so.0.0.0=<program root>             2.0       False
# 4         libmonitor.so.0.0.0=<program root>             2.0       False
# 5         libmonitor.so.0.0.0=<program root>             2.0       False
# 6         libmonitor.so.0.0.0=<program root>             2.0       False
# 7         libmonitor.so.0.0.0=<program root>             2.0       False
# 8         libmonitor.so.0.0.0=<program root>             2.0       False
# 9         libmonitor.so.0.0.0=<program root>             2.0       False
# 10        libmonitor.so.0.0.0=<program root>             2.0       False
# 11        libmonitor.so.0.0.0=<program root>             2.0       False
# 12        libmonitor.so.0.0.0=<program root>             2.0       False
# 13        libmonitor.so.0.0.0=<program root>             2.0       False
# 14        libmonitor.so.0.0.0=<program root>             2.0       False
# 15        libmonitor.so.0.0.0=<program root>             2.0       False
# 16        libmonitor.so.0.0.0=<program root>             2.0       False
# 17        libmonitor.so.0.0.0=<program root>             2.0       False
# 18                            osu_bcast=main             2.0       False
# 19                            osu_bcast=main             2.0       False
# 20                            osu_bcast=main             2.0       False
# 21                            osu_bcast=main             2.0       False
# 22                            osu_bcast=main             2.0       False
# 23                            osu_bcast=main             2.0       False
# 24                            osu_bcast=main             2.0       False
# 25                            osu_bcast=main             2.0       False
# 26                            osu_bcast=main             2.0       False
# 27                            osu_bcast=main             2.0       False
# 28                            osu_bcast=main             2.0       False
# 29                            osu_bcast=main             2.0       False
# ...                                      ...             ...         ...
# 1466     libmpi.so.12.1.1=1197:mv2_shm_bcast             7.0       False
# 1467     libmpi.so.12.1.1=1197:mv2_shm_bcast             7.0       False
# 1468     libmpi.so.12.1.1=1197:mv2_shm_bcast             7.0       False
# 1469     libmpi.so.12.1.1=1197:mv2_shm_bcast             7.0       False
# 1470     libmpi.so.12.1.1=1197:mv2_shm_bcast             7.0       False
# 1471     libmpi.so.12.1.1=1197:mv2_shm_bcast             7.0       False
# 1472     libmpi.so.12.1.1=1197:mv2_shm_bcast             7.0       False
# 1473     libmpi.so.12.1.1=1197:mv2_shm_bcast             7.0       False
# 1474                                     NaN             NaN         NaN
# 1475                                     NaN             NaN         NaN
# 1476                                     NaN             NaN         NaN
# 1477                                     NaN             NaN         NaN
# 1478                                     NaN             NaN         NaN
# 1479                                     NaN             NaN         NaN
# 1480                                     NaN             NaN         NaN
# 1481                                     NaN             NaN         NaN
# 1482                                     NaN             NaN         NaN
# 1483                                     NaN             NaN         NaN
# 1484                                     NaN             NaN         NaN
# 1485                                     NaN             NaN         NaN
# 1486                                     NaN             NaN         NaN
# 1487                                     NaN             NaN         NaN
# 1488                                     NaN             NaN         NaN
# 1489                                     NaN             NaN         NaN
# 1490                                     NaN             NaN         NaN
# 1491                                     NaN             NaN         NaN
# 1492        libmpi.so.12.1.1=98:PMPI_Barrier             2.0       False
# 1493  libmpi.so.12.1.1=421:MPIR_Barrier_impl             3.0       False
# 1494   libmpi.so.12.1.1=331:MPIR_Barrier_MV2             4.0       False
# 1495                                     NaN             NaN         NaN
#
#      entry_function                        id
# 0              True            <program_root>
# 1              True            <program_root>
# 2              True            <program_root>
# 3              True            <program_root>
# 4              True            <program_root>
# 5              True            <program_root>
# 6              True            <program_root>
# 7              True            <program_root>
# 8              True            <program_root>
# 9              True            <program_root>
# 10             True            <program_root>
# 11             True            <program_root>
# 12             True            <program_root>
# 13             True            <program_root>
# 14             True            <program_root>
# 15             True            <program_root>
# 16             True            <program_root>
# 17             True            <program_root>
# 18             True                      main
# 19             True                      main
# 20             True                      main
# 21             True                      main
# 22             True                      main
# 23             True                      main
# 24             True                      main
# 25             True                      main
# 26             True                      main
# 27             True                      main
# 28             True                      main
# 29             True                      main
# ...             ...                       ...
# 1466          False             mv2_shm_bcast
# 1467          False             mv2_shm_bcast
# 1468          False             mv2_shm_bcast
# 1469          False             mv2_shm_bcast
# 1470          False             mv2_shm_bcast
# 1471          False             mv2_shm_bcast
# 1472          False             mv2_shm_bcast
# 1473          False             mv2_shm_bcast
# 1474            NaN  __intel_ssse3_rep_memcpy
# 1475            NaN  __intel_ssse3_rep_memcpy
# 1476            NaN  __intel_ssse3_rep_memcpy
# 1477            NaN  __intel_ssse3_rep_memcpy
# 1478            NaN  __intel_ssse3_rep_memcpy
# 1479            NaN  __intel_ssse3_rep_memcpy
# 1480            NaN  __intel_ssse3_rep_memcpy
# 1481            NaN  __intel_ssse3_rep_memcpy
# 1482            NaN  __intel_ssse3_rep_memcpy
# 1483            NaN                         0
# 1484            NaN                         0
# 1485            NaN                         0
# 1486            NaN                         0
# 1487            NaN                         0
# 1488            NaN                         0
# 1489            NaN                         0
# 1490            NaN                         0
# 1491            NaN                         0
# 1492           True              PMPI_Barrier
# 1493          False         MPIR_Barrier_impl
# 1494          False          MPIR_Barrier_MV2
# 1495            NaN    MPIR_shmem_barrier_MV2
#
# [1496 rows x 25 columns]
